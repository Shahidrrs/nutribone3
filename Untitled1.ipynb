# %% [markdown]
# <a href="https://colab.research.google.com/github/Shahidrrs/nutribone3/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
import matplotlib.pyplot as plt
import numpy as np
import os
import shutil
import random
import seaborn as sns

# %%
import kagglehub

print("Downloading dataset 1 (mohamedgobara)...")
path1 = kagglehub.dataset_download("mohamedgobara/multi-class-knee-osteoporosis-x-ray-dataset")
print("Dataset 1 path:", path1)

print("\nDownloading dataset 2 (stevepython)...")
path2 = kagglehub.dataset_download("stevepython/osteoporosis-knee-xray-dataset")
print("Dataset 2 path:", path2)
# Out:
# Downloading dataset 1 (mohamedgobara)...
# Using Colab cache for faster access to the 'multi-class-knee-osteoporosis-x-ray-dataset' dataset.
# Dataset 1 path: /kaggle/input/multi-class-knee-osteoporosis-x-ray-dataset
#
# Downloading dataset 2 (stevepython)...
# Downloading to /root/.cache/kagglehub/datasets/stevepython/osteoporosis-knee-xray-dataset/2.archive...
# 100%|██████████| 280M/280M [00:16<00:00, 17.7MB/s]
# Extracting files...
# Dataset 2 path: /root/.cache/kagglehub/datasets/stevepython/osteoporosis-knee-xray-dataset/versions/2

# %%
import random
import shutil
import os
import numpy as np
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img

random.seed(42)
np.random.seed(42)

if os.path.exists("/tmp/osteoporosis_merged"):
    shutil.rmtree("/tmp/osteoporosis_merged")
    print("Old merged folder deleted.")

merged_dir = "/tmp/osteoporosis_merged"
splits     = ['train', 'val', 'test']
classes    = ['Normal', 'Osteopenia', 'Osteoporosis']

targets = {
    'train': 724,
    'val':   144,
    'test':  98
}

for split in splits:
    for cls in classes:
        os.makedirs(os.path.join(merged_dir, split, cls), exist_ok=True)

def collect_images(src_dir):
    if not os.path.exists(src_dir):
        print(f"  WARNING: Not found: {src_dir}")
        return []
    return [
        os.path.join(src_dir, f)
        for f in os.listdir(src_dir)
        if f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp'))
    ]

def split_and_copy(image_paths, dst_class_dirs, label_prefix, train=0.75, val=0.15):
    random.shuffle(image_paths)
    n       = len(image_paths)
    n_train = int(n * train)
    n_val   = int(n * val)
    splits_map = {
        'train': image_paths[:n_train],
        'val':   image_paths[n_train:n_train + n_val],
        'test':  image_paths[n_train + n_val:]
    }
    counts = {}
    for split_name, paths in splits_map.items():
        dst = dst_class_dirs[split_name]
        for i, src in enumerate(paths):
            ext = os.path.splitext(src)[1].lower()
            shutil.copy2(src, os.path.join(dst, f"{label_prefix}_{i}{ext}"))
        counts[split_name] = len(paths)
    return counts

def augment_to_exact(src_dir, target_count, label_prefix='aug'):
    existing = [
        os.path.join(src_dir, f)
        for f in os.listdir(src_dir)
        if f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp'))
    ]
    current = len(existing)
    if current > target_count:
        to_remove = random.sample(existing, current - target_count)
        for f in to_remove:
            os.remove(f)
        print(f"  Trimmed {current} → {target_count}")
        return
    if current < target_count:
        aug = ImageDataGenerator(
            rotation_range=20,
            width_shift_range=0.1,
            height_shift_range=0.1,
            zoom_range=0.15,
            horizontal_flip=True,
            brightness_range=[0.8, 1.2],
            shear_range=0.1,
            fill_mode='nearest'
        )
        needed = target_count - current
        idx = 0
        print(f"  Augmenting {current} → {target_count} (need {needed})...")
        while idx < needed:
            src_img_path = random.choice(existing)
            try:
                img = load_img(src_img_path, target_size=(224, 224))
                x   = img_to_array(img).reshape((1, 224, 224, 3))
                for batch in aug.flow(x, batch_size=1):
                    Image.fromarray(batch[0].astype(np.uint8)).save(
                        os.path.join(src_dir, f"{label_prefix}_{idx}.jpg"))
                    idx += 1
                    break
            except Exception as e:
                continue
        print(f"  Done: {len(os.listdir(src_dir))} images")

d1_base    = os.path.join(path1, "OS Collected Data")
d1_sources = {
    'Normal':       os.path.join(d1_base, "Normal"),
    'Osteopenia':   os.path.join(d1_base, "Osteopenia"),
    'Osteoporosis': os.path.join(d1_base, "Osteoporosis"),
}
d2_sources = {
    'Normal':       os.path.join(path2, "normal", "normal"),
    'Osteoporosis': os.path.join(path2, "osteoporosis", "osteoporosis"),
}

for cls in classes:
    dst_dirs = {s: os.path.join(merged_dir, s, cls) for s in splits}
    imgs_d1  = collect_images(d1_sources.get(cls, ""))
    imgs_d2  = collect_images(d2_sources.get(cls, ""))
    counts1  = split_and_copy(imgs_d1, dst_dirs, label_prefix="d1")
    counts2  = split_and_copy(imgs_d2, dst_dirs, label_prefix="d2")
    print(f"\n{cls}: {len(imgs_d1)} D1 + {len(imgs_d2)} D2 = {len(imgs_d1)+len(imgs_d2)}")

print("\nBalancing classes...")
for cls in classes:
    for split_name in splits:
        target    = targets[split_name]
        split_dir = os.path.join(merged_dir, split_name, cls)
        augment_to_exact(split_dir, target, label_prefix=f'aug_{cls[:3].lower()}')

print("\nFinal summary:")
for split in splits:
    print(f"\n{split}/")
    for cls in classes:
        n = len(os.listdir(os.path.join(merged_dir, split, cls)))
        print(f"  {cls}: {n}")
# Out:
# Normal: 780 D1 + 186 D2 = 966
#   WARNING: Not found:
#
# Osteopenia: 374 D1 + 0 D2 = 374
#
# Osteoporosis: 793 D1 + 186 D2 = 979
#
# Balancing classes...
#   Augmenting 280 → 724 (need 444)...
#   Done: 724 images
#   Augmenting 56 → 144 (need 88)...
#   Done: 144 images
#   Augmenting 38 → 98 (need 60)...
#   Done: 98 images
#   Trimmed 733 → 724
#   Trimmed 145 → 144
#   Trimmed 101 → 98
#
# Final summary:
#
# train/
#   Normal: 724
#   Osteopenia: 724
#   Osteoporosis: 724
#
# val/
#   Normal: 144
#   Osteopenia: 144
#   Osteoporosis: 144
#
# test/
#   Normal: 98
#   Osteopenia: 98
#   Osteoporosis: 98

# %%
train_dir = os.path.join(merged_dir, 'train')
val_dir   = os.path.join(merged_dir, 'val')
test_dir  = os.path.join(merged_dir, 'test')

def make_generators(preprocess_fn, batch_size=16):
    train_datagen = ImageDataGenerator(
        rotation_range=15,
        width_shift_range=0.1,
        height_shift_range=0.1,
        zoom_range=0.1,
        horizontal_flip=True,
        brightness_range=[0.85, 1.15],
        fill_mode='nearest',
        preprocessing_function=preprocess_fn
    )
    val_datagen  = ImageDataGenerator(preprocessing_function=preprocess_fn)
    test_datagen = ImageDataGenerator(preprocessing_function=preprocess_fn)

    train_gen = train_datagen.flow_from_directory(
        train_dir, target_size=(224, 224), batch_size=batch_size,
        classes=['Normal', 'Osteopenia', 'Osteoporosis'],
        class_mode='categorical', shuffle=True
    )
    val_gen = val_datagen.flow_from_directory(
        val_dir, target_size=(224, 224), batch_size=batch_size,
        classes=['Normal', 'Osteopenia', 'Osteoporosis'],
        class_mode='categorical', shuffle=False
    )
    test_gen = test_datagen.flow_from_directory(
        test_dir, target_size=(224, 224), batch_size=1,
        classes=['Normal', 'Osteopenia', 'Osteoporosis'],
        class_mode='categorical', shuffle=False
    )
    return train_gen, val_gen, test_gen

def build_model(backbone, preprocess_fn_name):
    inputs     = layers.Input(shape=(224, 224, 3))
    backbone.trainable = False
    x = backbone(inputs, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.5)(x)
    x = layers.Dense(512, activation='relu',
                     kernel_regularizer=tf.keras.regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.4)(x)
    x = layers.Dense(256, activation='relu',
                     kernel_regularizer=tf.keras.regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(3, activation='softmax')(x)
    return models.Model(inputs, outputs)

print("Helper functions ready.")
# Out:
# Helper functions ready.

# %%
print("=" * 50)
print("TRAINING MODEL 1: VGG-19")
print("=" * 50)

preprocess_vgg = tf.keras.applications.vgg19.preprocess_input
train_gen, val_gen, test_gen = make_generators(preprocess_vgg)

class_weights_array = compute_class_weight(
    class_weight='balanced',
    classes=np.array([0, 1, 2]),
    y=train_gen.classes
)
class_weights = dict(enumerate(class_weights_array))

# Build VGG-19
vgg_base = tf.keras.applications.VGG19(
    include_top=False, weights='imagenet', input_shape=(224, 224, 3))
model_vgg = build_model(vgg_base, 'vgg19')

# Stage 1
model_vgg.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss='categorical_crossentropy', metrics=['accuracy'])

cb_s1 = [
    EarlyStopping(monitor='val_loss', patience=8,
                  restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.3,
                      patience=3, min_lr=1e-7, verbose=1),
    ModelCheckpoint("vgg19_stage1.keras", monitor='val_accuracy',
                    save_best_only=True, verbose=1)
]
print("\nVGG-19 Stage 1...")
h_vgg1 = model_vgg.fit(train_gen, validation_data=val_gen,
                        epochs=20, callbacks=cb_s1,
                        class_weight=class_weights)

# Stage 2 — unfreeze block4 + block5
vgg_base.trainable = True
for layer in vgg_base.layers:
    layer.trainable = 'block5' in layer.name or 'block4' in layer.name

model_vgg.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=5e-6),
    loss='categorical_crossentropy', metrics=['accuracy'])

cb_s2 = [
    EarlyStopping(monitor='val_loss', patience=8,
                  restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.3,
                      patience=4, min_lr=1e-9, verbose=1),
    ModelCheckpoint("vgg19_best.keras", monitor='val_accuracy',
                    save_best_only=True, verbose=1)
]
print("\nVGG-19 Stage 2...")
h_vgg2 = model_vgg.fit(train_gen, validation_data=val_gen,
                        epochs=40, callbacks=cb_s2,
                        class_weight=class_weights)

print(f"\nVGG-19 Best Val Accuracy: {max(h_vgg2.history['val_accuracy']):.4f}")
# Out:
# ==================================================
# TRAINING MODEL 1: VGG-19
# ==================================================
# Found 2172 images belonging to 3 classes.
# Found 432 images belonging to 3 classes.
# Found 294 images belonging to 3 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step
#
# VGG-19 Stage 1...
# Epoch 1/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 583ms/step - accuracy: 0.5482 - loss: 1.3006
# Epoch 1: val_accuracy improved from None to 0.70602, saving model to vgg19_stage1.keras
#
# Epoch 1: finished saving model to vgg19_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 105s 676ms/step - accuracy: 0.6027 - loss: 1.1968 - val_accuracy: 0.7060 - val_loss: 0.8227 - learning_rate: 0.0010
# Epoch 2/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - accuracy: 0.6445 - loss: 0.9310
# Epoch 2: val_accuracy improved from 0.70602 to 0.70833, saving model to vgg19_stage1.keras
#
# Epoch 2: finished saving model to vgg19_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 595ms/step - accuracy: 0.6372 - loss: 0.9468 - val_accuracy: 0.7083 - val_loss: 0.7448 - learning_rate: 0.0010
# Epoch 3/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - accuracy: 0.6832 - loss: 0.8283
# Epoch 3: val_accuracy improved from 0.70833 to 0.75000, saving model to vgg19_stage1.keras
#
# Epoch 3: finished saving model to vgg19_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 586ms/step - accuracy: 0.6883 - loss: 0.8264 - val_accuracy: 0.7500 - val_loss: 0.6967 - learning_rate: 0.0010
# Epoch 4/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - accuracy: 0.6874 - loss: 0.8182
# Epoch 4: val_accuracy did not improve from 0.75000
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 591ms/step - accuracy: 0.6934 - loss: 0.8220 - val_accuracy: 0.7407 - val_loss: 0.6796 - learning_rate: 0.0010
# Epoch 5/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.7092 - loss: 0.7798
# Epoch 5: val_accuracy improved from 0.75000 to 0.76389, saving model to vgg19_stage1.keras
#
# Epoch 5: finished saving model to vgg19_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 82s 592ms/step - accuracy: 0.7095 - loss: 0.7743 - val_accuracy: 0.7639 - val_loss: 0.6527 - learning_rate: 0.0010
# Epoch 6/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - accuracy: 0.6855 - loss: 0.8189
# Epoch 6: val_accuracy did not improve from 0.76389
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 595ms/step - accuracy: 0.7035 - loss: 0.7789 - val_accuracy: 0.7546 - val_loss: 0.6740 - learning_rate: 0.0010
# Epoch 7/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.7162 - loss: 0.7194
# Epoch 7: val_accuracy did not improve from 0.76389
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 590ms/step - accuracy: 0.7261 - loss: 0.7301 - val_accuracy: 0.7407 - val_loss: 0.6619 - learning_rate: 0.0010
# Epoch 8/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - accuracy: 0.7313 - loss: 0.6927
# Epoch 8: val_accuracy did not improve from 0.76389
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 587ms/step - accuracy: 0.7122 - loss: 0.7381 - val_accuracy: 0.7639 - val_loss: 0.6262 - learning_rate: 0.0010
# Epoch 9/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 522ms/step - accuracy: 0.7168 - loss: 0.7155
# Epoch 9: val_accuracy did not improve from 0.76389
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 598ms/step - accuracy: 0.7219 - loss: 0.7093 - val_accuracy: 0.7500 - val_loss: 0.6278 - learning_rate: 0.0010
# Epoch 10/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - accuracy: 0.7361 - loss: 0.7199
# Epoch 10: val_accuracy improved from 0.76389 to 0.78704, saving model to vgg19_stage1.keras
#
# Epoch 10: finished saving model to vgg19_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 591ms/step - accuracy: 0.7210 - loss: 0.7304 - val_accuracy: 0.7870 - val_loss: 0.6282 - learning_rate: 0.0010
# Epoch 11/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - accuracy: 0.7336 - loss: 0.7019
# Epoch 11: val_accuracy did not improve from 0.78704
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 589ms/step - accuracy: 0.7320 - loss: 0.7039 - val_accuracy: 0.7778 - val_loss: 0.6244 - learning_rate: 0.0010
# Epoch 12/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 519ms/step - accuracy: 0.7624 - loss: 0.6555
# Epoch 12: val_accuracy did not improve from 0.78704
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 594ms/step - accuracy: 0.7509 - loss: 0.6759 - val_accuracy: 0.7616 - val_loss: 0.6323 - learning_rate: 0.0010
# Epoch 13/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 519ms/step - accuracy: 0.7279 - loss: 0.7216
# Epoch 13: val_accuracy improved from 0.78704 to 0.79630, saving model to vgg19_stage1.keras
#
# Epoch 13: finished saving model to vgg19_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 596ms/step - accuracy: 0.7394 - loss: 0.6991 - val_accuracy: 0.7963 - val_loss: 0.6001 - learning_rate: 0.0010
# Epoch 14/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - accuracy: 0.7487 - loss: 0.6648
# Epoch 14: val_accuracy did not improve from 0.79630
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 83s 612ms/step - accuracy: 0.7417 - loss: 0.6822 - val_accuracy: 0.7963 - val_loss: 0.6056 - learning_rate: 0.0010
# Epoch 15/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 523ms/step - accuracy: 0.7653 - loss: 0.6491
# Epoch 15: val_accuracy improved from 0.79630 to 0.79861, saving model to vgg19_stage1.keras
#
# Epoch 15: finished saving model to vgg19_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 599ms/step - accuracy: 0.7509 - loss: 0.6779 - val_accuracy: 0.7986 - val_loss: 0.6146 - learning_rate: 0.0010
# Epoch 16/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - accuracy: 0.7787 - loss: 0.6347
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
#
# Epoch 16: val_accuracy improved from 0.79861 to 0.80324, saving model to vgg19_stage1.keras
#
# Epoch 16: finished saving model to vgg19_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 83s 610ms/step - accuracy: 0.7551 - loss: 0.6820 - val_accuracy: 0.8032 - val_loss: 0.6056 - learning_rate: 0.0010
# Epoch 17/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 522ms/step - accuracy: 0.7412 - loss: 0.6926
# Epoch 17: val_accuracy did not improve from 0.80324
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 594ms/step - accuracy: 0.7495 - loss: 0.6610 - val_accuracy: 0.7917 - val_loss: 0.6091 - learning_rate: 3.0000e-04
# Epoch 18/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - accuracy: 0.7646 - loss: 0.6553
# Epoch 18: val_accuracy did not improve from 0.80324
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 83s 610ms/step - accuracy: 0.7592 - loss: 0.6567 - val_accuracy: 0.7870 - val_loss: 0.5890 - learning_rate: 3.0000e-04
# Epoch 19/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 525ms/step - accuracy: 0.7815 - loss: 0.6261
# Epoch 19: val_accuracy did not improve from 0.80324
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 598ms/step - accuracy: 0.7735 - loss: 0.6548 - val_accuracy: 0.8009 - val_loss: 0.5925 - learning_rate: 3.0000e-04
# Epoch 20/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 528ms/step - accuracy: 0.7563 - loss: 0.6485
# Epoch 20: val_accuracy improved from 0.80324 to 0.80787, saving model to vgg19_stage1.keras
#
# Epoch 20: finished saving model to vgg19_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 82s 606ms/step - accuracy: 0.7578 - loss: 0.6649 - val_accuracy: 0.8079 - val_loss: 0.5853 - learning_rate: 3.0000e-04
# Restoring model weights from the end of the best epoch: 20.
#
# VGG-19 Stage 2...
# Epoch 1/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 615ms/step - accuracy: 0.7616 - loss: 0.6452
# Epoch 1: val_accuracy improved from None to 0.76620, saving model to vgg19_best.keras
#
# Epoch 1: finished saving model to vgg19_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 111s 710ms/step - accuracy: 0.7624 - loss: 0.6387 - val_accuracy: 0.7662 - val_loss: 0.6205 - learning_rate: 5.0000e-06
# Epoch 2/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 562ms/step - accuracy: 0.7465 - loss: 0.6549
# Epoch 2: val_accuracy improved from 0.76620 to 0.82407, saving model to vgg19_best.keras
#
# Epoch 2: finished saving model to vgg19_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 88s 647ms/step - accuracy: 0.7661 - loss: 0.6252 - val_accuracy: 0.8241 - val_loss: 0.5711 - learning_rate: 5.0000e-06
# Epoch 3/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 562ms/step - accuracy: 0.7939 - loss: 0.5959
# Epoch 3: val_accuracy did not improve from 0.82407
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 86s 636ms/step - accuracy: 0.7845 - loss: 0.5994 - val_accuracy: 0.8102 - val_loss: 0.5459 - learning_rate: 5.0000e-06
# Epoch 4/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - accuracy: 0.7952 - loss: 0.5812
# Epoch 4: val_accuracy improved from 0.82407 to 0.84259, saving model to vgg19_best.keras
#
# Epoch 4: finished saving model to vgg19_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 87s 638ms/step - accuracy: 0.7970 - loss: 0.5736 - val_accuracy: 0.8426 - val_loss: 0.5139 - learning_rate: 5.0000e-06
# Epoch 5/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 556ms/step - accuracy: 0.8097 - loss: 0.5847
# Epoch 5: val_accuracy did not improve from 0.84259
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 86s 631ms/step - accuracy: 0.8025 - loss: 0.5709 - val_accuracy: 0.8287 - val_loss: 0.5217 - learning_rate: 5.0000e-06
# Epoch 6/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - accuracy: 0.8092 - loss: 0.5643
# Epoch 6: val_accuracy did not improve from 0.84259
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 86s 634ms/step - accuracy: 0.8163 - loss: 0.5537 - val_accuracy: 0.7894 - val_loss: 0.5908 - learning_rate: 5.0000e-06
# Epoch 7/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 566ms/step - accuracy: 0.8311 - loss: 0.5398
# Epoch 7: val_accuracy did not improve from 0.84259
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 87s 642ms/step - accuracy: 0.8209 - loss: 0.5453 - val_accuracy: 0.8079 - val_loss: 0.5656 - learning_rate: 5.0000e-06
# Epoch 8/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - accuracy: 0.8316 - loss: 0.5056
# Epoch 8: val_accuracy improved from 0.84259 to 0.85185, saving model to vgg19_best.keras
#
# Epoch 8: finished saving model to vgg19_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 87s 639ms/step - accuracy: 0.8264 - loss: 0.5170 - val_accuracy: 0.8519 - val_loss: 0.5055 - learning_rate: 5.0000e-06
# Epoch 9/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 554ms/step - accuracy: 0.8254 - loss: 0.5243
# Epoch 9: val_accuracy did not improve from 0.85185
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 85s 625ms/step - accuracy: 0.8204 - loss: 0.5178 - val_accuracy: 0.8426 - val_loss: 0.5291 - learning_rate: 5.0000e-06
# Epoch 10/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 548ms/step - accuracy: 0.8376 - loss: 0.4866
# Epoch 10: val_accuracy did not improve from 0.85185
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 85s 625ms/step - accuracy: 0.8250 - loss: 0.5060 - val_accuracy: 0.8032 - val_loss: 0.5944 - learning_rate: 5.0000e-06
# Epoch 11/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 556ms/step - accuracy: 0.8419 - loss: 0.5050
# Epoch 11: val_accuracy did not improve from 0.85185
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 86s 631ms/step - accuracy: 0.8384 - loss: 0.5024 - val_accuracy: 0.8403 - val_loss: 0.4932 - learning_rate: 5.0000e-06
# Epoch 12/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 571ms/step - accuracy: 0.8409 - loss: 0.4757
# Epoch 12: val_accuracy did not improve from 0.85185
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 88s 648ms/step - accuracy: 0.8320 - loss: 0.4862 - val_accuracy: 0.8495 - val_loss: 0.5331 - learning_rate: 5.0000e-06
# Epoch 13/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 562ms/step - accuracy: 0.8311 - loss: 0.5013
# Epoch 13: val_accuracy did not improve from 0.85185
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 87s 637ms/step - accuracy: 0.8499 - loss: 0.4747 - val_accuracy: 0.8333 - val_loss: 0.4909 - learning_rate: 5.0000e-06
# Epoch 14/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 575ms/step - accuracy: 0.8455 - loss: 0.4739
# Epoch 14: val_accuracy improved from 0.85185 to 0.86111, saving model to vgg19_best.keras
#
# Epoch 14: finished saving model to vgg19_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 90s 659ms/step - accuracy: 0.8550 - loss: 0.4593 - val_accuracy: 0.8611 - val_loss: 0.4892 - learning_rate: 5.0000e-06
# Epoch 15/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 561ms/step - accuracy: 0.8620 - loss: 0.4372
# Epoch 15: val_accuracy did not improve from 0.86111
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 87s 639ms/step - accuracy: 0.8527 - loss: 0.4515 - val_accuracy: 0.8218 - val_loss: 0.5832 - learning_rate: 5.0000e-06
# Epoch 16/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 564ms/step - accuracy: 0.8468 - loss: 0.4652
# Epoch 16: val_accuracy did not improve from 0.86111
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 87s 642ms/step - accuracy: 0.8513 - loss: 0.4569 - val_accuracy: 0.8333 - val_loss: 0.5147 - learning_rate: 5.0000e-06
# Epoch 17/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 572ms/step - accuracy: 0.8477 - loss: 0.4607
# Epoch 17: val_accuracy did not improve from 0.86111
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 88s 645ms/step - accuracy: 0.8499 - loss: 0.4626 - val_accuracy: 0.8403 - val_loss: 0.5042 - learning_rate: 5.0000e-06
# Epoch 18/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 568ms/step - accuracy: 0.8449 - loss: 0.4792
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.4999999621068127e-06.
#
# Epoch 18: val_accuracy did not improve from 0.86111
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 88s 642ms/step - accuracy: 0.8508 - loss: 0.4666 - val_accuracy: 0.8241 - val_loss: 0.5395 - learning_rate: 5.0000e-06
# Epoch 19/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 557ms/step - accuracy: 0.8499 - loss: 0.4549
# Epoch 19: val_accuracy did not improve from 0.86111
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 87s 636ms/step - accuracy: 0.8646 - loss: 0.4355 - val_accuracy: 0.8611 - val_loss: 0.4760 - learning_rate: 1.5000e-06
# Epoch 20/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 569ms/step - accuracy: 0.8767 - loss: 0.4282
# Epoch 20: val_accuracy did not improve from 0.86111
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 87s 644ms/step - accuracy: 0.8628 - loss: 0.4492 - val_accuracy: 0.8542 - val_loss: 0.5032 - learning_rate: 1.5000e-06
# Epoch 21/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 569ms/step - accuracy: 0.8807 - loss: 0.4141
# Epoch 21: val_accuracy did not improve from 0.86111
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 87s 643ms/step - accuracy: 0.8688 - loss: 0.4277 - val_accuracy: 0.8588 - val_loss: 0.4984 - learning_rate: 1.5000e-06
# Epoch 22/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 565ms/step - accuracy: 0.8749 - loss: 0.4270
# Epoch 22: val_accuracy did not improve from 0.86111
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 88s 643ms/step - accuracy: 0.8651 - loss: 0.4315 - val_accuracy: 0.8495 - val_loss: 0.5003 - learning_rate: 1.5000e-06
# Epoch 23/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 567ms/step - accuracy: 0.8801 - loss: 0.4102
# Epoch 23: ReduceLROnPlateau reducing learning rate to 4.4999998181083353e-07.
#
# Epoch 23: val_accuracy did not improve from 0.86111
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 88s 644ms/step - accuracy: 0.8720 - loss: 0.4192 - val_accuracy: 0.8611 - val_loss: 0.4812 - learning_rate: 1.5000e-06
# Epoch 24/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 568ms/step - accuracy: 0.8648 - loss: 0.4375
# Epoch 24: val_accuracy did not improve from 0.86111
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 88s 645ms/step - accuracy: 0.8715 - loss: 0.4252 - val_accuracy: 0.8542 - val_loss: 0.4980 - learning_rate: 4.5000e-07
# Epoch 25/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 565ms/step - accuracy: 0.8833 - loss: 0.4020
# Epoch 25: val_accuracy did not improve from 0.86111
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 87s 639ms/step - accuracy: 0.8771 - loss: 0.4111 - val_accuracy: 0.8519 - val_loss: 0.5005 - learning_rate: 4.5000e-07
# Epoch 26/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 568ms/step - accuracy: 0.8709 - loss: 0.4083
# Epoch 26: val_accuracy did not improve from 0.86111
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 87s 642ms/step - accuracy: 0.8688 - loss: 0.4195 - val_accuracy: 0.8542 - val_loss: 0.4893 - learning_rate: 4.5000e-07
# Epoch 27/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 562ms/step - accuracy: 0.8481 - loss: 0.4420
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.3499999624855262e-07.
#
# Epoch 27: val_accuracy did not improve from 0.86111
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 87s 636ms/step - accuracy: 0.8660 - loss: 0.4279 - val_accuracy: 0.8542 - val_loss: 0.4880 - learning_rate: 4.5000e-07
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 19.
#
# VGG-19 Best Val Accuracy: 0.8611

# %%
print("=" * 50)
print("TRAINING MODEL 2: ResNet50")
print("=" * 50)

preprocess_res = tf.keras.applications.resnet50.preprocess_input
train_gen_r, val_gen_r, test_gen_r = make_generators(preprocess_res)

res_base = tf.keras.applications.ResNet50(
    include_top=False, weights='imagenet', input_shape=(224, 224, 3))
model_res = build_model(res_base, 'resnet50')

# Stage 1
model_res.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss='categorical_crossentropy', metrics=['accuracy'])

cb_r1 = [
    EarlyStopping(monitor='val_loss', patience=8,
                  restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.3,
                      patience=3, min_lr=1e-7, verbose=1),
    ModelCheckpoint("resnet50_stage1.keras", monitor='val_accuracy',
                    save_best_only=True, verbose=1)
]
print("\nResNet50 Stage 1...")
h_res1 = model_res.fit(train_gen_r, validation_data=val_gen_r,
                        epochs=20, callbacks=cb_r1,
                        class_weight=class_weights)

# Stage 2 — unfreeze last 40 layers
res_base.trainable = True
for layer in res_base.layers[:-40]:
    layer.trainable = False

model_res.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=5e-6),
    loss='categorical_crossentropy', metrics=['accuracy'])

cb_r2 = [
    EarlyStopping(monitor='val_loss', patience=8,
                  restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.3,
                      patience=4, min_lr=1e-9, verbose=1),
    ModelCheckpoint("resnet50_best.keras", monitor='val_accuracy',
                    save_best_only=True, verbose=1)
]
print("\nResNet50 Stage 2...")
h_res2 = model_res.fit(train_gen_r, validation_data=val_gen_r,
                        epochs=40, callbacks=cb_r2,
                        class_weight=class_weights)

print(f"\nResNet50 Best Val Accuracy: {max(h_res2.history['val_accuracy']):.4f}")
# Out:
# ==================================================
# TRAINING MODEL 2: ResNet50
# ==================================================
# Found 2172 images belonging to 3 classes.
# Found 432 images belonging to 3 classes.
# Found 294 images belonging to 3 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step
#
# ResNet50 Stage 1...
# Epoch 1/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - accuracy: 0.6148 - loss: 1.2091
# Epoch 1: val_accuracy improved from None to 0.72454, saving model to resnet50_stage1.keras
#
# Epoch 1: finished saving model to resnet50_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 107s 677ms/step - accuracy: 0.6542 - loss: 1.0726 - val_accuracy: 0.7245 - val_loss: 0.8338 - learning_rate: 0.0010
# Epoch 2/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 510ms/step - accuracy: 0.7168 - loss: 0.8556
# Epoch 2: val_accuracy did not improve from 0.72454
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 79s 583ms/step - accuracy: 0.7159 - loss: 0.8596 - val_accuracy: 0.7106 - val_loss: 0.7623 - learning_rate: 0.0010
# Epoch 3/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 504ms/step - accuracy: 0.7021 - loss: 0.8223
# Epoch 3: val_accuracy improved from 0.72454 to 0.79861, saving model to resnet50_stage1.keras
#
# Epoch 3: finished saving model to resnet50_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 79s 582ms/step - accuracy: 0.7155 - loss: 0.7976 - val_accuracy: 0.7986 - val_loss: 0.6184 - learning_rate: 0.0010
# Epoch 4/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - accuracy: 0.7520 - loss: 0.7604
# Epoch 4: val_accuracy improved from 0.79861 to 0.80787, saving model to resnet50_stage1.keras
#
# Epoch 4: finished saving model to resnet50_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 590ms/step - accuracy: 0.7477 - loss: 0.7607 - val_accuracy: 0.8079 - val_loss: 0.5895 - learning_rate: 0.0010
# Epoch 5/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - accuracy: 0.7525 - loss: 0.7243
# Epoch 5: val_accuracy improved from 0.80787 to 0.81250, saving model to resnet50_stage1.keras
#
# Epoch 5: finished saving model to resnet50_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 589ms/step - accuracy: 0.7555 - loss: 0.7148 - val_accuracy: 0.8125 - val_loss: 0.5956 - learning_rate: 0.0010
# Epoch 6/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 519ms/step - accuracy: 0.7425 - loss: 0.7330
# Epoch 6: val_accuracy did not improve from 0.81250
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 590ms/step - accuracy: 0.7436 - loss: 0.7146 - val_accuracy: 0.7731 - val_loss: 0.6264 - learning_rate: 0.0010
# Epoch 7/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.7615 - loss: 0.7065
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
#
# Epoch 7: val_accuracy improved from 0.81250 to 0.82176, saving model to resnet50_stage1.keras
#
# Epoch 7: finished saving model to resnet50_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 591ms/step - accuracy: 0.7716 - loss: 0.6880 - val_accuracy: 0.8218 - val_loss: 0.6025 - learning_rate: 0.0010
# Epoch 8/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 503ms/step - accuracy: 0.7742 - loss: 0.6703
# Epoch 8: val_accuracy did not improve from 0.82176
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 78s 575ms/step - accuracy: 0.7868 - loss: 0.6567 - val_accuracy: 0.8056 - val_loss: 0.5971 - learning_rate: 3.0000e-04
# Epoch 9/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - accuracy: 0.7797 - loss: 0.6413
# Epoch 9: val_accuracy did not improve from 0.82176
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 79s 579ms/step - accuracy: 0.7758 - loss: 0.6594 - val_accuracy: 0.8125 - val_loss: 0.5875 - learning_rate: 3.0000e-04
# Epoch 10/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - accuracy: 0.7981 - loss: 0.6373
# Epoch 10: val_accuracy did not improve from 0.82176
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 79s 581ms/step - accuracy: 0.7947 - loss: 0.6341 - val_accuracy: 0.8194 - val_loss: 0.5818 - learning_rate: 3.0000e-04
# Epoch 11/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 502ms/step - accuracy: 0.7938 - loss: 0.6423
# Epoch 11: val_accuracy improved from 0.82176 to 0.83565, saving model to resnet50_stage1.keras
#
# Epoch 11: finished saving model to resnet50_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 79s 578ms/step - accuracy: 0.7933 - loss: 0.6399 - val_accuracy: 0.8356 - val_loss: 0.5777 - learning_rate: 3.0000e-04
# Epoch 12/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 504ms/step - accuracy: 0.7879 - loss: 0.6394
# Epoch 12: val_accuracy did not improve from 0.83565
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 78s 575ms/step - accuracy: 0.7859 - loss: 0.6480 - val_accuracy: 0.8171 - val_loss: 0.5893 - learning_rate: 3.0000e-04
# Epoch 13/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.7961 - loss: 0.6070
# Epoch 13: val_accuracy did not improve from 0.83565
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 78s 578ms/step - accuracy: 0.8011 - loss: 0.6046 - val_accuracy: 0.8310 - val_loss: 0.5757 - learning_rate: 3.0000e-04
# Epoch 14/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - accuracy: 0.7907 - loss: 0.6189
# Epoch 14: val_accuracy did not improve from 0.83565
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 79s 582ms/step - accuracy: 0.7887 - loss: 0.6104 - val_accuracy: 0.8218 - val_loss: 0.5892 - learning_rate: 3.0000e-04
# Epoch 15/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - accuracy: 0.7997 - loss: 0.6160
# Epoch 15: val_accuracy did not improve from 0.83565
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 586ms/step - accuracy: 0.7924 - loss: 0.6195 - val_accuracy: 0.8194 - val_loss: 0.5722 - learning_rate: 3.0000e-04
# Epoch 16/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - accuracy: 0.8073 - loss: 0.6011
# Epoch 16: val_accuracy did not improve from 0.83565
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 587ms/step - accuracy: 0.8094 - loss: 0.5967 - val_accuracy: 0.8032 - val_loss: 0.5982 - learning_rate: 3.0000e-04
# Epoch 17/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 546ms/step - accuracy: 0.7962 - loss: 0.5898
# Epoch 17: val_accuracy did not improve from 0.83565
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 84s 617ms/step - accuracy: 0.7910 - loss: 0.6084 - val_accuracy: 0.8241 - val_loss: 0.5697 - learning_rate: 3.0000e-04
# Epoch 18/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 519ms/step - accuracy: 0.8141 - loss: 0.5932
# Epoch 18: val_accuracy did not improve from 0.83565
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 591ms/step - accuracy: 0.8080 - loss: 0.5910 - val_accuracy: 0.8310 - val_loss: 0.5764 - learning_rate: 3.0000e-04
# Epoch 19/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - accuracy: 0.7888 - loss: 0.6003
# Epoch 19: val_accuracy did not improve from 0.83565
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 587ms/step - accuracy: 0.7970 - loss: 0.5966 - val_accuracy: 0.8218 - val_loss: 0.5891 - learning_rate: 3.0000e-04
# Epoch 20/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 523ms/step - accuracy: 0.8078 - loss: 0.5993
# Epoch 20: val_accuracy did not improve from 0.83565
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 596ms/step - accuracy: 0.8085 - loss: 0.6025 - val_accuracy: 0.8333 - val_loss: 0.5421 - learning_rate: 3.0000e-04
# Restoring model weights from the end of the best epoch: 20.
#
# ResNet50 Stage 2...
# Epoch 1/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 591ms/step - accuracy: 0.7734 - loss: 0.6699
# Epoch 1: val_accuracy improved from None to 0.80556, saving model to resnet50_best.keras
#
# Epoch 1: finished saving model to resnet50_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 121s 709ms/step - accuracy: 0.7684 - loss: 0.6672 - val_accuracy: 0.8056 - val_loss: 0.5709 - learning_rate: 5.0000e-06
# Epoch 2/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 526ms/step - accuracy: 0.7871 - loss: 0.6626
# Epoch 2: val_accuracy did not improve from 0.80556
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 598ms/step - accuracy: 0.7762 - loss: 0.6461 - val_accuracy: 0.8056 - val_loss: 0.5715 - learning_rate: 5.0000e-06
# Epoch 3/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 524ms/step - accuracy: 0.8008 - loss: 0.6115
# Epoch 3: val_accuracy improved from 0.80556 to 0.81713, saving model to resnet50_best.keras
#
# Epoch 3: finished saving model to resnet50_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 82s 606ms/step - accuracy: 0.7896 - loss: 0.6214 - val_accuracy: 0.8171 - val_loss: 0.5710 - learning_rate: 5.0000e-06
# Epoch 4/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - accuracy: 0.7888 - loss: 0.6056
# Epoch 4: val_accuracy improved from 0.81713 to 0.82870, saving model to resnet50_best.keras
#
# Epoch 4: finished saving model to resnet50_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 84s 618ms/step - accuracy: 0.7970 - loss: 0.6068 - val_accuracy: 0.8287 - val_loss: 0.5523 - learning_rate: 5.0000e-06
# Epoch 5/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 530ms/step - accuracy: 0.8159 - loss: 0.5820
# Epoch 5: val_accuracy did not improve from 0.82870
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 599ms/step - accuracy: 0.8076 - loss: 0.5857 - val_accuracy: 0.8264 - val_loss: 0.5515 - learning_rate: 5.0000e-06
# Epoch 6/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 526ms/step - accuracy: 0.8032 - loss: 0.5876
# Epoch 6: val_accuracy improved from 0.82870 to 0.84259, saving model to resnet50_best.keras
#
# Epoch 6: finished saving model to resnet50_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 83s 613ms/step - accuracy: 0.8016 - loss: 0.5885 - val_accuracy: 0.8426 - val_loss: 0.5459 - learning_rate: 5.0000e-06
# Epoch 7/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 524ms/step - accuracy: 0.8310 - loss: 0.5576
# Epoch 7: val_accuracy improved from 0.84259 to 0.84722, saving model to resnet50_best.keras
#
# Epoch 7: finished saving model to resnet50_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 82s 603ms/step - accuracy: 0.8186 - loss: 0.5803 - val_accuracy: 0.8472 - val_loss: 0.5481 - learning_rate: 5.0000e-06
# Epoch 8/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 522ms/step - accuracy: 0.8098 - loss: 0.5620
# Epoch 8: val_accuracy did not improve from 0.84722
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 141s 594ms/step - accuracy: 0.8172 - loss: 0.5536 - val_accuracy: 0.8356 - val_loss: 0.5364 - learning_rate: 5.0000e-06
# Epoch 9/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 528ms/step - accuracy: 0.8124 - loss: 0.5751
# Epoch 9: val_accuracy did not improve from 0.84722
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 597ms/step - accuracy: 0.8076 - loss: 0.5894 - val_accuracy: 0.8310 - val_loss: 0.5406 - learning_rate: 5.0000e-06
# Epoch 10/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 524ms/step - accuracy: 0.8174 - loss: 0.5567
# Epoch 10: val_accuracy did not improve from 0.84722
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 82s 600ms/step - accuracy: 0.8223 - loss: 0.5475 - val_accuracy: 0.8356 - val_loss: 0.5360 - learning_rate: 5.0000e-06
# Epoch 11/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 523ms/step - accuracy: 0.8413 - loss: 0.5144
# Epoch 11: val_accuracy did not improve from 0.84722
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 588ms/step - accuracy: 0.8320 - loss: 0.5198 - val_accuracy: 0.8380 - val_loss: 0.5401 - learning_rate: 5.0000e-06
# Epoch 12/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 524ms/step - accuracy: 0.8118 - loss: 0.5643
# Epoch 12: val_accuracy did not improve from 0.84722
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 598ms/step - accuracy: 0.8089 - loss: 0.5599 - val_accuracy: 0.8356 - val_loss: 0.5311 - learning_rate: 5.0000e-06
# Epoch 13/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 523ms/step - accuracy: 0.8402 - loss: 0.5147
# Epoch 13: val_accuracy did not improve from 0.84722
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 600ms/step - accuracy: 0.8287 - loss: 0.5272 - val_accuracy: 0.8356 - val_loss: 0.5273 - learning_rate: 5.0000e-06
# Epoch 14/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - accuracy: 0.8207 - loss: 0.5473
# Epoch 14: val_accuracy did not improve from 0.84722
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 589ms/step - accuracy: 0.8310 - loss: 0.5261 - val_accuracy: 0.8380 - val_loss: 0.5345 - learning_rate: 5.0000e-06
# Epoch 15/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - accuracy: 0.8307 - loss: 0.5228
# Epoch 15: val_accuracy did not improve from 0.84722
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 584ms/step - accuracy: 0.8214 - loss: 0.5451 - val_accuracy: 0.8472 - val_loss: 0.5218 - learning_rate: 5.0000e-06
# Epoch 16/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - accuracy: 0.8465 - loss: 0.5166
# Epoch 16: val_accuracy improved from 0.84722 to 0.85648, saving model to resnet50_best.keras
#
# Epoch 16: finished saving model to resnet50_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 594ms/step - accuracy: 0.8343 - loss: 0.5189 - val_accuracy: 0.8565 - val_loss: 0.5139 - learning_rate: 5.0000e-06
# Epoch 17/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - accuracy: 0.8401 - loss: 0.4821
# Epoch 17: val_accuracy did not improve from 0.85648
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 593ms/step - accuracy: 0.8458 - loss: 0.4887 - val_accuracy: 0.8495 - val_loss: 0.5190 - learning_rate: 5.0000e-06
# Epoch 18/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - accuracy: 0.8384 - loss: 0.5232
# Epoch 18: val_accuracy did not improve from 0.85648
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 79s 584ms/step - accuracy: 0.8352 - loss: 0.5214 - val_accuracy: 0.8449 - val_loss: 0.5110 - learning_rate: 5.0000e-06
# Epoch 19/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - accuracy: 0.8458 - loss: 0.5222
# Epoch 19: val_accuracy did not improve from 0.85648
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 79s 582ms/step - accuracy: 0.8499 - loss: 0.5143 - val_accuracy: 0.8449 - val_loss: 0.5177 - learning_rate: 5.0000e-06
# Epoch 20/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - accuracy: 0.8309 - loss: 0.5158
# Epoch 20: val_accuracy did not improve from 0.85648
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 587ms/step - accuracy: 0.8389 - loss: 0.5009 - val_accuracy: 0.8472 - val_loss: 0.5228 - learning_rate: 5.0000e-06
# Epoch 21/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - accuracy: 0.8414 - loss: 0.5130
# Epoch 21: val_accuracy did not improve from 0.85648
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 79s 582ms/step - accuracy: 0.8527 - loss: 0.4928 - val_accuracy: 0.8565 - val_loss: 0.5031 - learning_rate: 5.0000e-06
# Epoch 22/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.8411 - loss: 0.5177
# Epoch 22: val_accuracy did not improve from 0.85648
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 585ms/step - accuracy: 0.8550 - loss: 0.4885 - val_accuracy: 0.8519 - val_loss: 0.5031 - learning_rate: 5.0000e-06
# Epoch 23/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 519ms/step - accuracy: 0.8545 - loss: 0.4767
# Epoch 23: val_accuracy improved from 0.85648 to 0.85880, saving model to resnet50_best.keras
#
# Epoch 23: finished saving model to resnet50_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 82s 603ms/step - accuracy: 0.8467 - loss: 0.4880 - val_accuracy: 0.8588 - val_loss: 0.4992 - learning_rate: 5.0000e-06
# Epoch 24/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - accuracy: 0.8555 - loss: 0.5035
# Epoch 24: val_accuracy did not improve from 0.85880
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 586ms/step - accuracy: 0.8577 - loss: 0.4896 - val_accuracy: 0.8588 - val_loss: 0.5001 - learning_rate: 5.0000e-06
# Epoch 25/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - accuracy: 0.8692 - loss: 0.4396
# Epoch 25: val_accuracy did not improve from 0.85880
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 588ms/step - accuracy: 0.8596 - loss: 0.4596 - val_accuracy: 0.8565 - val_loss: 0.5034 - learning_rate: 5.0000e-06
# Epoch 26/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - accuracy: 0.8509 - loss: 0.4802
# Epoch 26: val_accuracy did not improve from 0.85880
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 590ms/step - accuracy: 0.8564 - loss: 0.4743 - val_accuracy: 0.8565 - val_loss: 0.5043 - learning_rate: 5.0000e-06
# Epoch 27/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - accuracy: 0.8516 - loss: 0.4842
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.4999999621068127e-06.
#
# Epoch 27: val_accuracy did not improve from 0.85880
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 78s 575ms/step - accuracy: 0.8448 - loss: 0.4944 - val_accuracy: 0.8588 - val_loss: 0.4997 - learning_rate: 5.0000e-06
# Epoch 28/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 519ms/step - accuracy: 0.8648 - loss: 0.4665
# Epoch 28: val_accuracy improved from 0.85880 to 0.86111, saving model to resnet50_best.keras
#
# Epoch 28: finished saving model to resnet50_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 598ms/step - accuracy: 0.8637 - loss: 0.4653 - val_accuracy: 0.8611 - val_loss: 0.4880 - learning_rate: 1.5000e-06
# Epoch 29/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - accuracy: 0.8748 - loss: 0.4386
# Epoch 29: val_accuracy did not improve from 0.86111
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 589ms/step - accuracy: 0.8665 - loss: 0.4553 - val_accuracy: 0.8588 - val_loss: 0.4889 - learning_rate: 1.5000e-06
# Epoch 30/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - accuracy: 0.8689 - loss: 0.4567
# Epoch 30: val_accuracy did not improve from 0.86111
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 79s 583ms/step - accuracy: 0.8702 - loss: 0.4556 - val_accuracy: 0.8588 - val_loss: 0.4876 - learning_rate: 1.5000e-06
# Epoch 31/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - accuracy: 0.8593 - loss: 0.4773
# Epoch 31: val_accuracy did not improve from 0.86111
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 587ms/step - accuracy: 0.8494 - loss: 0.4838 - val_accuracy: 0.8542 - val_loss: 0.4850 - learning_rate: 1.5000e-06
# Epoch 32/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 528ms/step - accuracy: 0.8570 - loss: 0.4684
# Epoch 32: val_accuracy did not improve from 0.86111
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 82s 605ms/step - accuracy: 0.8605 - loss: 0.4579 - val_accuracy: 0.8565 - val_loss: 0.4852 - learning_rate: 1.5000e-06
# Epoch 33/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - accuracy: 0.8640 - loss: 0.4479
# Epoch 33: val_accuracy improved from 0.86111 to 0.86343, saving model to resnet50_best.keras
#
# Epoch 33: finished saving model to resnet50_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 86s 628ms/step - accuracy: 0.8564 - loss: 0.4574 - val_accuracy: 0.8634 - val_loss: 0.4852 - learning_rate: 1.5000e-06
# Epoch 34/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - accuracy: 0.8427 - loss: 0.4875
# Epoch 34: val_accuracy improved from 0.86343 to 0.86574, saving model to resnet50_best.keras
#
# Epoch 34: finished saving model to resnet50_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 83s 613ms/step - accuracy: 0.8554 - loss: 0.4688 - val_accuracy: 0.8657 - val_loss: 0.4853 - learning_rate: 1.5000e-06
# Epoch 35/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 525ms/step - accuracy: 0.8489 - loss: 0.4611
# Epoch 35: ReduceLROnPlateau reducing learning rate to 4.4999998181083353e-07.
#
# Epoch 35: val_accuracy did not improve from 0.86574
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 596ms/step - accuracy: 0.8541 - loss: 0.4589 - val_accuracy: 0.8657 - val_loss: 0.4891 - learning_rate: 1.5000e-06
# Epoch 36/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - accuracy: 0.8611 - loss: 0.4609
# Epoch 36: val_accuracy did not improve from 0.86574
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 590ms/step - accuracy: 0.8642 - loss: 0.4545 - val_accuracy: 0.8657 - val_loss: 0.4878 - learning_rate: 4.5000e-07
# Epoch 37/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 524ms/step - accuracy: 0.8654 - loss: 0.4425
# Epoch 37: val_accuracy improved from 0.86574 to 0.86806, saving model to resnet50_best.keras
#
# Epoch 37: finished saving model to resnet50_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 82s 603ms/step - accuracy: 0.8610 - loss: 0.4488 - val_accuracy: 0.8681 - val_loss: 0.4882 - learning_rate: 4.5000e-07
# Epoch 38/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 522ms/step - accuracy: 0.8558 - loss: 0.4571
# Epoch 38: val_accuracy did not improve from 0.86806
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 593ms/step - accuracy: 0.8725 - loss: 0.4405 - val_accuracy: 0.8681 - val_loss: 0.4882 - learning_rate: 4.5000e-07
# Epoch 39/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - accuracy: 0.8679 - loss: 0.4707
# Epoch 39: ReduceLROnPlateau reducing learning rate to 1.3499999624855262e-07.
#
# Epoch 39: val_accuracy did not improve from 0.86806
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 584ms/step - accuracy: 0.8679 - loss: 0.4620 - val_accuracy: 0.8657 - val_loss: 0.4918 - learning_rate: 4.5000e-07
# Epoch 39: early stopping
# Restoring model weights from the end of the best epoch: 31.
#
# ResNet50 Best Val Accuracy: 0.8681

# %%
print("=" * 50)
print("TRAINING MODEL 3: EfficientNetB0")
print("=" * 50)

preprocess_eff = tf.keras.applications.efficientnet.preprocess_input
train_gen_e, val_gen_e, test_gen_e = make_generators(preprocess_eff)

eff_base = tf.keras.applications.EfficientNetB0(
    include_top=False, weights='imagenet', input_shape=(224, 224, 3))
model_eff = build_model(eff_base, 'efficientnet')

# Stage 1
model_eff.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss='categorical_crossentropy', metrics=['accuracy'])

cb_e1 = [
    EarlyStopping(monitor='val_loss', patience=8,
                  restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.3,
                      patience=3, min_lr=1e-7, verbose=1),
    ModelCheckpoint("effnet_stage1.keras", monitor='val_accuracy',
                    save_best_only=True, verbose=1)
]
print("\nEfficientNetB0 Stage 1...")
h_eff1 = model_eff.fit(train_gen_e, validation_data=val_gen_e,
                        epochs=20, callbacks=cb_e1,
                        class_weight=class_weights)

# Stage 2 — unfreeze top 30%
eff_base.trainable = True
freeze_until = int(len(eff_base.layers) * 0.7)
for layer in eff_base.layers[:freeze_until]:
    layer.trainable = False

model_eff.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=5e-6),
    loss='categorical_crossentropy', metrics=['accuracy'])

cb_e2 = [
    EarlyStopping(monitor='val_loss', patience=8,
                  restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.3,
                      patience=4, min_lr=1e-9, verbose=1),
    ModelCheckpoint("effnet_best.keras", monitor='val_accuracy',
                    save_best_only=True, verbose=1)
]
print("\nEfficientNetB0 Stage 2...")
h_eff2 = model_eff.fit(train_gen_e, validation_data=val_gen_e,
                        epochs=40, callbacks=cb_e2,
                        class_weight=class_weights)

print(f"\nEfficientNetB0 Best Val Accuracy: {max(h_eff2.history['val_accuracy']):.4f}")
# Out:
# ==================================================
# TRAINING MODEL 3: EfficientNetB0
# ==================================================
# Found 2172 images belonging to 3 classes.
# Found 432 images belonging to 3 classes.
# Found 294 images belonging to 3 classes.
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
#
# EfficientNetB0 Stage 1...
# Epoch 1/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 638ms/step - accuracy: 0.5669 - loss: 1.3404
# Epoch 1: val_accuracy improved from None to 0.70139, saving model to effnet_stage1.keras
#
# Epoch 1: finished saving model to effnet_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 136s 773ms/step - accuracy: 0.6248 - loss: 1.1624 - val_accuracy: 0.7014 - val_loss: 0.7393 - learning_rate: 0.0010
# Epoch 2/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step - accuracy: 0.6868 - loss: 0.8938
# Epoch 2: val_accuracy improved from 0.70139 to 0.73380, saving model to effnet_stage1.keras
#
# Epoch 2: finished saving model to effnet_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 77s 564ms/step - accuracy: 0.6915 - loss: 0.8758 - val_accuracy: 0.7338 - val_loss: 0.7142 - learning_rate: 0.0010
# Epoch 3/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step - accuracy: 0.7067 - loss: 0.8397
# Epoch 3: val_accuracy improved from 0.73380 to 0.75000, saving model to effnet_stage1.keras
#
# Epoch 3: finished saving model to effnet_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 76s 556ms/step - accuracy: 0.7040 - loss: 0.8189 - val_accuracy: 0.7500 - val_loss: 0.7082 - learning_rate: 0.0010
# Epoch 4/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step - accuracy: 0.7307 - loss: 0.7534
# Epoch 4: val_accuracy improved from 0.75000 to 0.77546, saving model to effnet_stage1.keras
#
# Epoch 4: finished saving model to effnet_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 77s 563ms/step - accuracy: 0.7325 - loss: 0.7593 - val_accuracy: 0.7755 - val_loss: 0.6206 - learning_rate: 0.0010
# Epoch 5/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step - accuracy: 0.7166 - loss: 0.7534
# Epoch 5: val_accuracy did not improve from 0.77546
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 76s 560ms/step - accuracy: 0.7325 - loss: 0.7329 - val_accuracy: 0.7731 - val_loss: 0.6528 - learning_rate: 0.0010
# Epoch 6/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step - accuracy: 0.7528 - loss: 0.7182
# Epoch 6: val_accuracy did not improve from 0.77546
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 76s 556ms/step - accuracy: 0.7449 - loss: 0.7259 - val_accuracy: 0.7755 - val_loss: 0.6418 - learning_rate: 0.0010
# Epoch 7/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step - accuracy: 0.7371 - loss: 0.7182
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
#
# Epoch 7: val_accuracy improved from 0.77546 to 0.78704, saving model to effnet_stage1.keras
#
# Epoch 7: finished saving model to effnet_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 76s 559ms/step - accuracy: 0.7403 - loss: 0.7222 - val_accuracy: 0.7870 - val_loss: 0.6445 - learning_rate: 0.0010
# Epoch 8/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step - accuracy: 0.7540 - loss: 0.7072
# Epoch 8: val_accuracy improved from 0.78704 to 0.79398, saving model to effnet_stage1.keras
#
# Epoch 8: finished saving model to effnet_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 78s 574ms/step - accuracy: 0.7546 - loss: 0.6856 - val_accuracy: 0.7940 - val_loss: 0.6006 - learning_rate: 3.0000e-04
# Epoch 9/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step - accuracy: 0.7702 - loss: 0.6405
# Epoch 9: val_accuracy did not improve from 0.79398
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 76s 556ms/step - accuracy: 0.7657 - loss: 0.6632 - val_accuracy: 0.7824 - val_loss: 0.6211 - learning_rate: 3.0000e-04
# Epoch 10/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step - accuracy: 0.7791 - loss: 0.6391
# Epoch 10: val_accuracy did not improve from 0.79398
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 76s 559ms/step - accuracy: 0.7730 - loss: 0.6524 - val_accuracy: 0.7940 - val_loss: 0.6290 - learning_rate: 3.0000e-04
# Epoch 11/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step - accuracy: 0.7522 - loss: 0.6715
# Epoch 11: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
#
# Epoch 11: val_accuracy did not improve from 0.79398
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 75s 554ms/step - accuracy: 0.7643 - loss: 0.6493 - val_accuracy: 0.7870 - val_loss: 0.6091 - learning_rate: 3.0000e-04
# Epoch 12/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step - accuracy: 0.7675 - loss: 0.6425
# Epoch 12: val_accuracy did not improve from 0.79398
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 75s 552ms/step - accuracy: 0.7772 - loss: 0.6257 - val_accuracy: 0.7940 - val_loss: 0.6066 - learning_rate: 9.0000e-05
# Epoch 13/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step - accuracy: 0.7583 - loss: 0.6635
# Epoch 13: val_accuracy did not improve from 0.79398
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 75s 552ms/step - accuracy: 0.7675 - loss: 0.6521 - val_accuracy: 0.7847 - val_loss: 0.5894 - learning_rate: 9.0000e-05
# Epoch 14/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step - accuracy: 0.7670 - loss: 0.6711
# Epoch 14: val_accuracy did not improve from 0.79398
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 77s 566ms/step - accuracy: 0.7703 - loss: 0.6553 - val_accuracy: 0.7894 - val_loss: 0.5871 - learning_rate: 9.0000e-05
# Epoch 15/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step - accuracy: 0.7663 - loss: 0.6564
# Epoch 15: val_accuracy improved from 0.79398 to 0.80324, saving model to effnet_stage1.keras
#
# Epoch 15: finished saving model to effnet_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 76s 561ms/step - accuracy: 0.7749 - loss: 0.6382 - val_accuracy: 0.8032 - val_loss: 0.5922 - learning_rate: 9.0000e-05
# Epoch 16/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step - accuracy: 0.7855 - loss: 0.6266
# Epoch 16: val_accuracy did not improve from 0.80324
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 76s 558ms/step - accuracy: 0.7942 - loss: 0.6167 - val_accuracy: 0.8032 - val_loss: 0.5869 - learning_rate: 9.0000e-05
# Epoch 17/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step - accuracy: 0.7763 - loss: 0.6452
# Epoch 17: val_accuracy did not improve from 0.80324
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 76s 563ms/step - accuracy: 0.7762 - loss: 0.6404 - val_accuracy: 0.7940 - val_loss: 0.5848 - learning_rate: 9.0000e-05
# Epoch 18/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step - accuracy: 0.7866 - loss: 0.6188
# Epoch 18: val_accuracy did not improve from 0.80324
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 75s 552ms/step - accuracy: 0.7744 - loss: 0.6399 - val_accuracy: 0.8009 - val_loss: 0.5847 - learning_rate: 9.0000e-05
# Epoch 19/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step - accuracy: 0.7956 - loss: 0.5950
# Epoch 19: val_accuracy did not improve from 0.80324
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 75s 549ms/step - accuracy: 0.7910 - loss: 0.6014 - val_accuracy: 0.7940 - val_loss: 0.5879 - learning_rate: 9.0000e-05
# Epoch 20/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step - accuracy: 0.7778 - loss: 0.6316
# Epoch 20: val_accuracy did not improve from 0.80324
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 75s 554ms/step - accuracy: 0.7855 - loss: 0.6184 - val_accuracy: 0.7894 - val_loss: 0.5812 - learning_rate: 9.0000e-05
# Restoring model weights from the end of the best epoch: 20.
#
# EfficientNetB0 Stage 2...
# Epoch 1/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 632ms/step - accuracy: 0.6698 - loss: 0.8588
# Epoch 1: val_accuracy improved from None to 0.78472, saving model to effnet_best.keras
#
# Epoch 1: finished saving model to effnet_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 143s 763ms/step - accuracy: 0.6865 - loss: 0.8421 - val_accuracy: 0.7847 - val_loss: 0.6322 - learning_rate: 5.0000e-06
# Epoch 2/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step - accuracy: 0.7146 - loss: 0.7729
# Epoch 2: val_accuracy improved from 0.78472 to 0.78935, saving model to effnet_best.keras
#
# Epoch 2: finished saving model to effnet_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 77s 565ms/step - accuracy: 0.7076 - loss: 0.7935 - val_accuracy: 0.7894 - val_loss: 0.6569 - learning_rate: 5.0000e-06
# Epoch 3/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step - accuracy: 0.6984 - loss: 0.8279
# Epoch 3: val_accuracy did not improve from 0.78935
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 76s 563ms/step - accuracy: 0.7017 - loss: 0.8182 - val_accuracy: 0.7870 - val_loss: 0.6550 - learning_rate: 5.0000e-06
# Epoch 4/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step - accuracy: 0.6877 - loss: 0.8035
# Epoch 4: val_accuracy improved from 0.78935 to 0.79398, saving model to effnet_best.keras
#
# Epoch 4: finished saving model to effnet_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 76s 562ms/step - accuracy: 0.7113 - loss: 0.7745 - val_accuracy: 0.7940 - val_loss: 0.6426 - learning_rate: 5.0000e-06
# Epoch 5/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step - accuracy: 0.7148 - loss: 0.8110
# Epoch 5: val_accuracy improved from 0.79398 to 0.79861, saving model to effnet_best.keras
#
# Epoch 5: finished saving model to effnet_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 76s 563ms/step - accuracy: 0.7196 - loss: 0.7906 - val_accuracy: 0.7986 - val_loss: 0.6291 - learning_rate: 5.0000e-06
# Epoch 6/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 502ms/step - accuracy: 0.7241 - loss: 0.7619
# Epoch 6: val_accuracy improved from 0.79861 to 0.80324, saving model to effnet_best.keras
#
# Epoch 6: finished saving model to effnet_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 78s 572ms/step - accuracy: 0.7274 - loss: 0.7661 - val_accuracy: 0.8032 - val_loss: 0.6231 - learning_rate: 5.0000e-06
# Epoch 7/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - accuracy: 0.7387 - loss: 0.7385
# Epoch 7: val_accuracy did not improve from 0.80324
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 78s 571ms/step - accuracy: 0.7238 - loss: 0.7580 - val_accuracy: 0.7940 - val_loss: 0.6201 - learning_rate: 5.0000e-06
# Epoch 8/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step - accuracy: 0.7532 - loss: 0.7166
# Epoch 8: val_accuracy did not improve from 0.80324
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 74s 541ms/step - accuracy: 0.7431 - loss: 0.7231 - val_accuracy: 0.8009 - val_loss: 0.6136 - learning_rate: 5.0000e-06
# Epoch 9/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step - accuracy: 0.7210 - loss: 0.7448
# Epoch 9: val_accuracy did not improve from 0.80324
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 76s 561ms/step - accuracy: 0.7371 - loss: 0.7234 - val_accuracy: 0.8009 - val_loss: 0.6047 - learning_rate: 5.0000e-06
# Epoch 10/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step - accuracy: 0.7222 - loss: 0.7656
# Epoch 10: val_accuracy improved from 0.80324 to 0.80556, saving model to effnet_best.keras
#
# Epoch 10: finished saving model to effnet_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 77s 567ms/step - accuracy: 0.7431 - loss: 0.7152 - val_accuracy: 0.8056 - val_loss: 0.5986 - learning_rate: 5.0000e-06
# Epoch 11/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step - accuracy: 0.7301 - loss: 0.7482
# Epoch 11: val_accuracy did not improve from 0.80556
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 77s 566ms/step - accuracy: 0.7422 - loss: 0.7326 - val_accuracy: 0.8032 - val_loss: 0.5981 - learning_rate: 5.0000e-06
# Epoch 12/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step - accuracy: 0.7451 - loss: 0.6955
# Epoch 12: val_accuracy did not improve from 0.80556
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 75s 555ms/step - accuracy: 0.7463 - loss: 0.7052 - val_accuracy: 0.8056 - val_loss: 0.5945 - learning_rate: 5.0000e-06
# Epoch 13/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step - accuracy: 0.7823 - loss: 0.6839
# Epoch 13: val_accuracy did not improve from 0.80556
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 75s 549ms/step - accuracy: 0.7647 - loss: 0.6834 - val_accuracy: 0.8009 - val_loss: 0.5874 - learning_rate: 5.0000e-06
# Epoch 14/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step - accuracy: 0.7641 - loss: 0.6747
# Epoch 14: val_accuracy did not improve from 0.80556
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 75s 549ms/step - accuracy: 0.7583 - loss: 0.6772 - val_accuracy: 0.8009 - val_loss: 0.5884 - learning_rate: 5.0000e-06
# Epoch 15/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step - accuracy: 0.7443 - loss: 0.6877
# Epoch 15: val_accuracy did not improve from 0.80556
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 77s 563ms/step - accuracy: 0.7413 - loss: 0.7110 - val_accuracy: 0.8032 - val_loss: 0.5873 - learning_rate: 5.0000e-06
# Epoch 16/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step - accuracy: 0.7718 - loss: 0.6658
# Epoch 16: val_accuracy improved from 0.80556 to 0.80787, saving model to effnet_best.keras
#
# Epoch 16: finished saving model to effnet_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 77s 562ms/step - accuracy: 0.7606 - loss: 0.6797 - val_accuracy: 0.8079 - val_loss: 0.5824 - learning_rate: 5.0000e-06
# Epoch 17/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step - accuracy: 0.7769 - loss: 0.6595
# Epoch 17: val_accuracy did not improve from 0.80787
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 76s 559ms/step - accuracy: 0.7795 - loss: 0.6437 - val_accuracy: 0.8032 - val_loss: 0.5834 - learning_rate: 5.0000e-06
# Epoch 18/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step - accuracy: 0.7437 - loss: 0.6948
# Epoch 18: val_accuracy did not improve from 0.80787
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 75s 551ms/step - accuracy: 0.7491 - loss: 0.6965 - val_accuracy: 0.8079 - val_loss: 0.5768 - learning_rate: 5.0000e-06
# Epoch 19/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step - accuracy: 0.7763 - loss: 0.6607
# Epoch 19: val_accuracy did not improve from 0.80787
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 74s 547ms/step - accuracy: 0.7624 - loss: 0.6756 - val_accuracy: 0.8079 - val_loss: 0.5764 - learning_rate: 5.0000e-06
# Epoch 20/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step - accuracy: 0.7661 - loss: 0.6771
# Epoch 20: val_accuracy improved from 0.80787 to 0.81019, saving model to effnet_best.keras
#
# Epoch 20: finished saving model to effnet_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 77s 563ms/step - accuracy: 0.7661 - loss: 0.6712 - val_accuracy: 0.8102 - val_loss: 0.5767 - learning_rate: 5.0000e-06
# Epoch 21/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step - accuracy: 0.7490 - loss: 0.6929
# Epoch 21: val_accuracy did not improve from 0.81019
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 77s 567ms/step - accuracy: 0.7615 - loss: 0.6728 - val_accuracy: 0.8102 - val_loss: 0.5767 - learning_rate: 5.0000e-06
# Epoch 22/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step - accuracy: 0.7732 - loss: 0.6570
# Epoch 22: val_accuracy did not improve from 0.81019
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 74s 547ms/step - accuracy: 0.7726 - loss: 0.6396 - val_accuracy: 0.8102 - val_loss: 0.5751 - learning_rate: 5.0000e-06
# Epoch 23/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step - accuracy: 0.7527 - loss: 0.6798
# Epoch 23: val_accuracy did not improve from 0.81019
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 77s 564ms/step - accuracy: 0.7592 - loss: 0.6727 - val_accuracy: 0.8079 - val_loss: 0.5679 - learning_rate: 5.0000e-06
# Epoch 24/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step - accuracy: 0.7871 - loss: 0.6227
# Epoch 24: val_accuracy improved from 0.81019 to 0.81481, saving model to effnet_best.keras
#
# Epoch 24: finished saving model to effnet_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 76s 562ms/step - accuracy: 0.7781 - loss: 0.6486 - val_accuracy: 0.8148 - val_loss: 0.5698 - learning_rate: 5.0000e-06
# Epoch 25/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step - accuracy: 0.7594 - loss: 0.6666
# Epoch 25: val_accuracy did not improve from 0.81481
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 78s 572ms/step - accuracy: 0.7684 - loss: 0.6487 - val_accuracy: 0.8125 - val_loss: 0.5689 - learning_rate: 5.0000e-06
# Epoch 26/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step - accuracy: 0.7682 - loss: 0.6423
# Epoch 26: val_accuracy did not improve from 0.81481
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 77s 563ms/step - accuracy: 0.7804 - loss: 0.6348 - val_accuracy: 0.8102 - val_loss: 0.5684 - learning_rate: 5.0000e-06
# Epoch 27/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step - accuracy: 0.7804 - loss: 0.6337
# Epoch 27: val_accuracy did not improve from 0.81481
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 77s 564ms/step - accuracy: 0.7859 - loss: 0.6286 - val_accuracy: 0.8102 - val_loss: 0.5655 - learning_rate: 5.0000e-06
# Epoch 28/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step - accuracy: 0.7524 - loss: 0.6813
# Epoch 28: val_accuracy did not improve from 0.81481
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 77s 565ms/step - accuracy: 0.7624 - loss: 0.6647 - val_accuracy: 0.8079 - val_loss: 0.5638 - learning_rate: 5.0000e-06
# Epoch 29/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step - accuracy: 0.7584 - loss: 0.6650
# Epoch 29: val_accuracy did not improve from 0.81481
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 77s 565ms/step - accuracy: 0.7735 - loss: 0.6475 - val_accuracy: 0.8032 - val_loss: 0.5660 - learning_rate: 5.0000e-06
# Epoch 30/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step - accuracy: 0.7792 - loss: 0.6407
# Epoch 30: val_accuracy did not improve from 0.81481
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 76s 559ms/step - accuracy: 0.7795 - loss: 0.6317 - val_accuracy: 0.8102 - val_loss: 0.5586 - learning_rate: 5.0000e-06
# Epoch 31/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step - accuracy: 0.7957 - loss: 0.6218
# Epoch 31: val_accuracy did not improve from 0.81481
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 77s 561ms/step - accuracy: 0.7841 - loss: 0.6415 - val_accuracy: 0.8125 - val_loss: 0.5581 - learning_rate: 5.0000e-06
# Epoch 32/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step - accuracy: 0.7695 - loss: 0.6349
# Epoch 32: val_accuracy did not improve from 0.81481
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 74s 546ms/step - accuracy: 0.7772 - loss: 0.6274 - val_accuracy: 0.8148 - val_loss: 0.5545 - learning_rate: 5.0000e-06
# Epoch 33/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step - accuracy: 0.7641 - loss: 0.6647
# Epoch 33: val_accuracy did not improve from 0.81481
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 76s 559ms/step - accuracy: 0.7753 - loss: 0.6396 - val_accuracy: 0.8125 - val_loss: 0.5554 - learning_rate: 5.0000e-06
# Epoch 34/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step - accuracy: 0.7897 - loss: 0.6135
# Epoch 34: val_accuracy did not improve from 0.81481
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 76s 557ms/step - accuracy: 0.7942 - loss: 0.6086 - val_accuracy: 0.8125 - val_loss: 0.5504 - learning_rate: 5.0000e-06
# Epoch 35/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step - accuracy: 0.7781 - loss: 0.6466
# Epoch 35: val_accuracy did not improve from 0.81481
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 75s 547ms/step - accuracy: 0.7845 - loss: 0.6341 - val_accuracy: 0.8148 - val_loss: 0.5509 - learning_rate: 5.0000e-06
# Epoch 36/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step - accuracy: 0.7818 - loss: 0.6014
# Epoch 36: val_accuracy did not improve from 0.81481
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 74s 545ms/step - accuracy: 0.7758 - loss: 0.6104 - val_accuracy: 0.8125 - val_loss: 0.5474 - learning_rate: 5.0000e-06
# Epoch 37/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step - accuracy: 0.7806 - loss: 0.6539
# Epoch 37: val_accuracy did not improve from 0.81481
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 76s 558ms/step - accuracy: 0.7859 - loss: 0.6220 - val_accuracy: 0.8148 - val_loss: 0.5521 - learning_rate: 5.0000e-06
# Epoch 38/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step - accuracy: 0.7866 - loss: 0.6279
# Epoch 38: val_accuracy did not improve from 0.81481
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 75s 554ms/step - accuracy: 0.7744 - loss: 0.6407 - val_accuracy: 0.8125 - val_loss: 0.5476 - learning_rate: 5.0000e-06
# Epoch 39/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step - accuracy: 0.7787 - loss: 0.6191
# Epoch 39: val_accuracy did not improve from 0.81481
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 75s 551ms/step - accuracy: 0.7799 - loss: 0.6139 - val_accuracy: 0.8148 - val_loss: 0.5483 - learning_rate: 5.0000e-06
# Epoch 40/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step - accuracy: 0.7753 - loss: 0.6023
# Epoch 40: val_accuracy did not improve from 0.81481
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 75s 554ms/step - accuracy: 0.7818 - loss: 0.5957 - val_accuracy: 0.8148 - val_loss: 0.5426 - learning_rate: 5.0000e-06
# Restoring model weights from the end of the best epoch: 40.
#
# EfficientNetB0 Best Val Accuracy: 0.8148

# %%
print("=" * 50)
print("TRAINING MODEL 4: ResNet50V2")
print("=" * 50)

preprocess_res2 = tf.keras.applications.resnet_v2.preprocess_input
train_gen_r2, val_gen_r2, test_gen_r2 = make_generators(preprocess_res2)

res_base_v2 = tf.keras.applications.ResNet50V2(
    include_top=False, weights='imagenet', input_shape=(224, 224, 3))
model_res2 = build_model(res_base_v2, 'resnet50v2')

# Stage 1
model_res2.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss='categorical_crossentropy', metrics=['accuracy'])

cb_r2s1 = [
    EarlyStopping(monitor='val_loss', patience=8,
                  restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.3,
                      patience=3, min_lr=1e-7, verbose=1),
    ModelCheckpoint("resnet50v2_stage1.keras", monitor='val_accuracy',
                    save_best_only=True, verbose=1)
]
print("\nResNet50V2 Stage 1...")
h_res2s1 = model_res2.fit(train_gen_r2, validation_data=val_gen_r2,
                           epochs=20, callbacks=cb_r2s1,
                           class_weight=class_weights)

# Stage 2 — unfreeze last 40 layers
res_base_v2.trainable = True
for layer in res_base_v2.layers[:-40]:
    layer.trainable = False

print(f"Trainable layers: {sum(1 for l in res_base_v2.layers if l.trainable)}")

model_res2.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=5e-6),
    loss='categorical_crossentropy', metrics=['accuracy'])

cb_r2s2 = [
    EarlyStopping(monitor='val_loss', patience=8,
                  restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.3,
                      patience=4, min_lr=1e-9, verbose=1),
    ModelCheckpoint("resnet50v2_best.keras", monitor='val_accuracy',
                    save_best_only=True, verbose=1)
]
print("\nResNet50V2 Stage 2...")
h_res2s2 = model_res2.fit(train_gen_r2, validation_data=val_gen_r2,
                           epochs=40, callbacks=cb_r2s2,
                           class_weight=class_weights)

print(f"\nResNet50V2 Best Val Accuracy: {max(h_res2s2.history['val_accuracy']):.4f}")
# Out:
# ==================================================
# TRAINING MODEL 4: ResNet50V2
# ==================================================
# Found 2172 images belonging to 3 classes.
# Found 432 images belonging to 3 classes.
# Found 294 images belonging to 3 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step
#
# ResNet50V2 Stage 1...
# Epoch 1/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 524ms/step - accuracy: 0.5844 - loss: 1.3009
# Epoch 1: val_accuracy improved from None to 0.66435, saving model to resnet50v2_stage1.keras
#
# Epoch 1: finished saving model to resnet50v2_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 101s 637ms/step - accuracy: 0.6257 - loss: 1.1644 - val_accuracy: 0.6644 - val_loss: 0.8403 - learning_rate: 0.0010
# Epoch 2/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step - accuracy: 0.6672 - loss: 0.9495
# Epoch 2: val_accuracy improved from 0.66435 to 0.72222, saving model to resnet50v2_stage1.keras
#
# Epoch 2: finished saving model to resnet50v2_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 77s 569ms/step - accuracy: 0.6745 - loss: 0.9274 - val_accuracy: 0.7222 - val_loss: 0.7264 - learning_rate: 0.0010
# Epoch 3/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step - accuracy: 0.6783 - loss: 0.8790
# Epoch 3: val_accuracy improved from 0.72222 to 0.74306, saving model to resnet50v2_stage1.keras
#
# Epoch 3: finished saving model to resnet50v2_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 77s 568ms/step - accuracy: 0.7007 - loss: 0.8454 - val_accuracy: 0.7431 - val_loss: 0.7289 - learning_rate: 0.0010
# Epoch 4/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step - accuracy: 0.7035 - loss: 0.8097
# Epoch 4: val_accuracy improved from 0.74306 to 0.75000, saving model to resnet50v2_stage1.keras
#
# Epoch 4: finished saving model to resnet50v2_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 77s 564ms/step - accuracy: 0.7187 - loss: 0.8036 - val_accuracy: 0.7500 - val_loss: 0.7120 - learning_rate: 0.0010
# Epoch 5/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step - accuracy: 0.7322 - loss: 0.7508
# Epoch 5: val_accuracy did not improve from 0.75000
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 75s 556ms/step - accuracy: 0.7261 - loss: 0.7736 - val_accuracy: 0.7500 - val_loss: 0.6942 - learning_rate: 0.0010
# Epoch 6/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 504ms/step - accuracy: 0.7354 - loss: 0.7538
# Epoch 6: val_accuracy improved from 0.75000 to 0.76157, saving model to resnet50v2_stage1.keras
#
# Epoch 6: finished saving model to resnet50v2_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 79s 581ms/step - accuracy: 0.7339 - loss: 0.7604 - val_accuracy: 0.7616 - val_loss: 0.6812 - learning_rate: 0.0010
# Epoch 7/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 503ms/step - accuracy: 0.7224 - loss: 0.7568
# Epoch 7: val_accuracy improved from 0.76157 to 0.76620, saving model to resnet50v2_stage1.keras
#
# Epoch 7: finished saving model to resnet50v2_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 78s 574ms/step - accuracy: 0.7362 - loss: 0.7471 - val_accuracy: 0.7662 - val_loss: 0.7006 - learning_rate: 0.0010
# Epoch 8/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 504ms/step - accuracy: 0.7468 - loss: 0.7141
# Epoch 8: val_accuracy improved from 0.76620 to 0.78704, saving model to resnet50v2_stage1.keras
#
# Epoch 8: finished saving model to resnet50v2_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 79s 577ms/step - accuracy: 0.7362 - loss: 0.7351 - val_accuracy: 0.7870 - val_loss: 0.6531 - learning_rate: 0.0010
# Epoch 9/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step - accuracy: 0.7522 - loss: 0.7044
# Epoch 9: val_accuracy did not improve from 0.78704
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 79s 556ms/step - accuracy: 0.7408 - loss: 0.7247 - val_accuracy: 0.7269 - val_loss: 0.7049 - learning_rate: 0.0010
# Epoch 10/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step - accuracy: 0.7374 - loss: 0.7427
# Epoch 10: val_accuracy did not improve from 0.78704
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 77s 567ms/step - accuracy: 0.7463 - loss: 0.7183 - val_accuracy: 0.7870 - val_loss: 0.6653 - learning_rate: 0.0010
# Epoch 11/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step - accuracy: 0.7414 - loss: 0.7136
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
#
# Epoch 11: val_accuracy did not improve from 0.78704
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 76s 560ms/step - accuracy: 0.7440 - loss: 0.7142 - val_accuracy: 0.7431 - val_loss: 0.6976 - learning_rate: 0.0010
# Epoch 12/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step - accuracy: 0.7684 - loss: 0.6851
# Epoch 12: val_accuracy did not improve from 0.78704
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 76s 560ms/step - accuracy: 0.7643 - loss: 0.6975 - val_accuracy: 0.7870 - val_loss: 0.6346 - learning_rate: 3.0000e-04
# Epoch 13/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step - accuracy: 0.7740 - loss: 0.6602
# Epoch 13: val_accuracy improved from 0.78704 to 0.78935, saving model to resnet50v2_stage1.keras
#
# Epoch 13: finished saving model to resnet50v2_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 78s 574ms/step - accuracy: 0.7716 - loss: 0.6723 - val_accuracy: 0.7894 - val_loss: 0.6210 - learning_rate: 3.0000e-04
# Epoch 14/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step - accuracy: 0.7514 - loss: 0.7065
# Epoch 14: val_accuracy did not improve from 0.78935
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 77s 564ms/step - accuracy: 0.7781 - loss: 0.6746 - val_accuracy: 0.7801 - val_loss: 0.6315 - learning_rate: 3.0000e-04
# Epoch 15/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step - accuracy: 0.7681 - loss: 0.6632
# Epoch 15: val_accuracy improved from 0.78935 to 0.79398, saving model to resnet50v2_stage1.keras
#
# Epoch 15: finished saving model to resnet50v2_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 78s 572ms/step - accuracy: 0.7666 - loss: 0.6724 - val_accuracy: 0.7940 - val_loss: 0.6185 - learning_rate: 3.0000e-04
# Epoch 16/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step - accuracy: 0.7860 - loss: 0.6495
# Epoch 16: val_accuracy improved from 0.79398 to 0.80324, saving model to resnet50v2_stage1.keras
#
# Epoch 16: finished saving model to resnet50v2_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 82s 571ms/step - accuracy: 0.7813 - loss: 0.6495 - val_accuracy: 0.8032 - val_loss: 0.6098 - learning_rate: 3.0000e-04
# Epoch 17/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step - accuracy: 0.7640 - loss: 0.6648
# Epoch 17: val_accuracy did not improve from 0.80324
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 75s 553ms/step - accuracy: 0.7629 - loss: 0.6711 - val_accuracy: 0.7986 - val_loss: 0.6139 - learning_rate: 3.0000e-04
# Epoch 18/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step - accuracy: 0.7738 - loss: 0.6749
# Epoch 18: val_accuracy did not improve from 0.80324
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 77s 568ms/step - accuracy: 0.7795 - loss: 0.6561 - val_accuracy: 0.8032 - val_loss: 0.6066 - learning_rate: 3.0000e-04
# Epoch 19/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step - accuracy: 0.7760 - loss: 0.6324
# Epoch 19: val_accuracy did not improve from 0.80324
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 77s 564ms/step - accuracy: 0.7693 - loss: 0.6613 - val_accuracy: 0.7894 - val_loss: 0.6071 - learning_rate: 3.0000e-04
# Epoch 20/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step - accuracy: 0.7728 - loss: 0.6516
# Epoch 20: val_accuracy did not improve from 0.80324
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 77s 569ms/step - accuracy: 0.7762 - loss: 0.6427 - val_accuracy: 0.8009 - val_loss: 0.5979 - learning_rate: 3.0000e-04
# Restoring model weights from the end of the best epoch: 20.
# Trainable layers: 40
#
# ResNet50V2 Stage 2...
# Epoch 1/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 571ms/step - accuracy: 0.6900 - loss: 0.8384
# Epoch 1: val_accuracy improved from None to 0.77083, saving model to resnet50v2_best.keras
#
# Epoch 1: finished saving model to resnet50v2_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 126s 772ms/step - accuracy: 0.7141 - loss: 0.7995 - val_accuracy: 0.7708 - val_loss: 0.6411 - learning_rate: 5.0000e-06
# Epoch 2/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.7385 - loss: 0.7421
# Epoch 2: val_accuracy did not improve from 0.77083
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 78s 575ms/step - accuracy: 0.7348 - loss: 0.7523 - val_accuracy: 0.7708 - val_loss: 0.6446 - learning_rate: 5.0000e-06
# Epoch 3/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - accuracy: 0.7142 - loss: 0.8018
# Epoch 3: val_accuracy improved from 0.77083 to 0.78472, saving model to resnet50v2_best.keras
#
# Epoch 3: finished saving model to resnet50v2_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 90s 633ms/step - accuracy: 0.7261 - loss: 0.7773 - val_accuracy: 0.7847 - val_loss: 0.6394 - learning_rate: 5.0000e-06
# Epoch 4/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step - accuracy: 0.7600 - loss: 0.7084
# Epoch 4: val_accuracy did not improve from 0.78472
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 77s 563ms/step - accuracy: 0.7468 - loss: 0.7256 - val_accuracy: 0.7824 - val_loss: 0.6324 - learning_rate: 5.0000e-06
# Epoch 5/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.7696 - loss: 0.6870
# Epoch 5: val_accuracy improved from 0.78472 to 0.78935, saving model to resnet50v2_best.keras
#
# Epoch 5: finished saving model to resnet50v2_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 85s 627ms/step - accuracy: 0.7680 - loss: 0.6899 - val_accuracy: 0.7894 - val_loss: 0.6171 - learning_rate: 5.0000e-06
# Epoch 6/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step - accuracy: 0.7650 - loss: 0.7144
# Epoch 6: val_accuracy improved from 0.78935 to 0.79167, saving model to resnet50v2_best.keras
#
# Epoch 6: finished saving model to resnet50v2_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 83s 606ms/step - accuracy: 0.7638 - loss: 0.7091 - val_accuracy: 0.7917 - val_loss: 0.6112 - learning_rate: 5.0000e-06
# Epoch 7/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - accuracy: 0.7775 - loss: 0.6727
# Epoch 7: val_accuracy did not improve from 0.79167
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 597ms/step - accuracy: 0.7744 - loss: 0.6702 - val_accuracy: 0.7917 - val_loss: 0.6086 - learning_rate: 5.0000e-06
# Epoch 8/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - accuracy: 0.7742 - loss: 0.6715
# Epoch 8: val_accuracy improved from 0.79167 to 0.80787, saving model to resnet50v2_best.keras
#
# Epoch 8: finished saving model to resnet50v2_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 85s 626ms/step - accuracy: 0.7735 - loss: 0.6643 - val_accuracy: 0.8079 - val_loss: 0.6016 - learning_rate: 5.0000e-06
# Epoch 9/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - accuracy: 0.7838 - loss: 0.6236
# Epoch 9: val_accuracy did not improve from 0.80787
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 79s 584ms/step - accuracy: 0.7855 - loss: 0.6327 - val_accuracy: 0.7917 - val_loss: 0.6048 - learning_rate: 5.0000e-06
# Epoch 10/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 508ms/step - accuracy: 0.7678 - loss: 0.6669
# Epoch 10: val_accuracy did not improve from 0.80787
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 79s 578ms/step - accuracy: 0.7707 - loss: 0.6565 - val_accuracy: 0.7963 - val_loss: 0.5948 - learning_rate: 5.0000e-06
# Epoch 11/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 523ms/step - accuracy: 0.7906 - loss: 0.6410
# Epoch 11: val_accuracy did not improve from 0.80787
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 593ms/step - accuracy: 0.7850 - loss: 0.6556 - val_accuracy: 0.7986 - val_loss: 0.5877 - learning_rate: 5.0000e-06
# Epoch 12/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - accuracy: 0.7995 - loss: 0.6079
# Epoch 12: val_accuracy did not improve from 0.80787
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 584ms/step - accuracy: 0.7942 - loss: 0.6224 - val_accuracy: 0.7986 - val_loss: 0.5834 - learning_rate: 5.0000e-06
# Epoch 13/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - accuracy: 0.7962 - loss: 0.6318
# Epoch 13: val_accuracy improved from 0.80787 to 0.82407, saving model to resnet50v2_best.keras
#
# Epoch 13: finished saving model to resnet50v2_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 86s 627ms/step - accuracy: 0.7974 - loss: 0.6229 - val_accuracy: 0.8241 - val_loss: 0.5747 - learning_rate: 5.0000e-06
# Epoch 14/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - accuracy: 0.7843 - loss: 0.6377
# Epoch 14: val_accuracy did not improve from 0.82407
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 589ms/step - accuracy: 0.7859 - loss: 0.6354 - val_accuracy: 0.8032 - val_loss: 0.5791 - learning_rate: 5.0000e-06
# Epoch 15/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - accuracy: 0.7942 - loss: 0.6122
# Epoch 15: val_accuracy did not improve from 0.82407
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 79s 581ms/step - accuracy: 0.7951 - loss: 0.6130 - val_accuracy: 0.8009 - val_loss: 0.5786 - learning_rate: 5.0000e-06
# Epoch 16/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 522ms/step - accuracy: 0.7993 - loss: 0.6261
# Epoch 16: val_accuracy did not improve from 0.82407
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 591ms/step - accuracy: 0.8057 - loss: 0.6061 - val_accuracy: 0.8171 - val_loss: 0.5623 - learning_rate: 5.0000e-06
# Epoch 17/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 519ms/step - accuracy: 0.8215 - loss: 0.5637
# Epoch 17: val_accuracy did not improve from 0.82407
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 591ms/step - accuracy: 0.8158 - loss: 0.5832 - val_accuracy: 0.8079 - val_loss: 0.5682 - learning_rate: 5.0000e-06
# Epoch 18/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - accuracy: 0.7844 - loss: 0.6423
# Epoch 18: val_accuracy did not improve from 0.82407
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 79s 576ms/step - accuracy: 0.7965 - loss: 0.6205 - val_accuracy: 0.8079 - val_loss: 0.5725 - learning_rate: 5.0000e-06
# Epoch 19/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step - accuracy: 0.8132 - loss: 0.5848
# Epoch 19: val_accuracy did not improve from 0.82407
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 78s 571ms/step - accuracy: 0.8057 - loss: 0.6002 - val_accuracy: 0.8241 - val_loss: 0.5588 - learning_rate: 5.0000e-06
# Epoch 20/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 502ms/step - accuracy: 0.8070 - loss: 0.5791
# Epoch 20: val_accuracy improved from 0.82407 to 0.83333, saving model to resnet50v2_best.keras
#
# Epoch 20: finished saving model to resnet50v2_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 85s 626ms/step - accuracy: 0.8085 - loss: 0.5788 - val_accuracy: 0.8333 - val_loss: 0.5502 - learning_rate: 5.0000e-06
# Epoch 21/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 510ms/step - accuracy: 0.8256 - loss: 0.5528
# Epoch 21: val_accuracy did not improve from 0.83333
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 79s 580ms/step - accuracy: 0.8145 - loss: 0.5733 - val_accuracy: 0.8333 - val_loss: 0.5484 - learning_rate: 5.0000e-06
# Epoch 22/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.8083 - loss: 0.5906
# Epoch 22: val_accuracy did not improve from 0.83333
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 79s 580ms/step - accuracy: 0.8204 - loss: 0.5668 - val_accuracy: 0.8333 - val_loss: 0.5401 - learning_rate: 5.0000e-06
# Epoch 23/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - accuracy: 0.8077 - loss: 0.5868
# Epoch 23: val_accuracy improved from 0.83333 to 0.83796, saving model to resnet50v2_best.keras
#
# Epoch 23: finished saving model to resnet50v2_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 84s 619ms/step - accuracy: 0.8122 - loss: 0.5883 - val_accuracy: 0.8380 - val_loss: 0.5356 - learning_rate: 5.0000e-06
# Epoch 24/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 537ms/step - accuracy: 0.8245 - loss: 0.5677
# Epoch 24: val_accuracy did not improve from 0.83796
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 82s 601ms/step - accuracy: 0.8195 - loss: 0.5671 - val_accuracy: 0.8356 - val_loss: 0.5356 - learning_rate: 5.0000e-06
# Epoch 25/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 522ms/step - accuracy: 0.8365 - loss: 0.5522
# Epoch 25: val_accuracy did not improve from 0.83796
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 591ms/step - accuracy: 0.8246 - loss: 0.5647 - val_accuracy: 0.8356 - val_loss: 0.5386 - learning_rate: 5.0000e-06
# Epoch 26/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 510ms/step - accuracy: 0.8370 - loss: 0.5186
# Epoch 26: val_accuracy did not improve from 0.83796
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 79s 581ms/step - accuracy: 0.8232 - loss: 0.5502 - val_accuracy: 0.8380 - val_loss: 0.5326 - learning_rate: 5.0000e-06
# Epoch 27/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - accuracy: 0.8223 - loss: 0.5570
# Epoch 27: val_accuracy did not improve from 0.83796
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 79s 583ms/step - accuracy: 0.8297 - loss: 0.5497 - val_accuracy: 0.8333 - val_loss: 0.5270 - learning_rate: 5.0000e-06
# Epoch 28/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - accuracy: 0.8302 - loss: 0.5279
# Epoch 28: val_accuracy did not improve from 0.83796
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 586ms/step - accuracy: 0.8370 - loss: 0.5257 - val_accuracy: 0.8333 - val_loss: 0.5291 - learning_rate: 5.0000e-06
# Epoch 29/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 510ms/step - accuracy: 0.8254 - loss: 0.5278
# Epoch 29: val_accuracy did not improve from 0.83796
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 79s 578ms/step - accuracy: 0.8232 - loss: 0.5429 - val_accuracy: 0.8287 - val_loss: 0.5271 - learning_rate: 5.0000e-06
# Epoch 30/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - accuracy: 0.8266 - loss: 0.5455
# Epoch 30: val_accuracy did not improve from 0.83796
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 79s 581ms/step - accuracy: 0.8232 - loss: 0.5522 - val_accuracy: 0.8310 - val_loss: 0.5305 - learning_rate: 5.0000e-06
# Epoch 31/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - accuracy: 0.8363 - loss: 0.5252
# Epoch 31: val_accuracy did not improve from 0.83796
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 78s 575ms/step - accuracy: 0.8343 - loss: 0.5319 - val_accuracy: 0.8310 - val_loss: 0.5245 - learning_rate: 5.0000e-06
# Epoch 32/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 508ms/step - accuracy: 0.8385 - loss: 0.5294
# Epoch 32: val_accuracy improved from 0.83796 to 0.84028, saving model to resnet50v2_best.keras
#
# Epoch 32: finished saving model to resnet50v2_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 85s 623ms/step - accuracy: 0.8379 - loss: 0.5354 - val_accuracy: 0.8403 - val_loss: 0.5302 - learning_rate: 5.0000e-06
# Epoch 33/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 508ms/step - accuracy: 0.8290 - loss: 0.5156
# Epoch 33: val_accuracy did not improve from 0.84028
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 78s 576ms/step - accuracy: 0.8338 - loss: 0.5177 - val_accuracy: 0.8310 - val_loss: 0.5211 - learning_rate: 5.0000e-06
# Epoch 34/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 519ms/step - accuracy: 0.8456 - loss: 0.5215
# Epoch 34: val_accuracy did not improve from 0.84028
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 587ms/step - accuracy: 0.8462 - loss: 0.5204 - val_accuracy: 0.8287 - val_loss: 0.5201 - learning_rate: 5.0000e-06
# Epoch 35/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.8291 - loss: 0.5204
# Epoch 35: val_accuracy did not improve from 0.84028
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 587ms/step - accuracy: 0.8379 - loss: 0.5222 - val_accuracy: 0.8241 - val_loss: 0.5155 - learning_rate: 5.0000e-06
# Epoch 36/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 525ms/step - accuracy: 0.8393 - loss: 0.5478
# Epoch 36: val_accuracy did not improve from 0.84028
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 596ms/step - accuracy: 0.8352 - loss: 0.5381 - val_accuracy: 0.8380 - val_loss: 0.5088 - learning_rate: 5.0000e-06
# Epoch 37/40
# 108/136 ━━━━━━━━━━━━━━━━━━━━ 14s 513ms/step - accuracy: 0.8454 - loss: 0.4936

# %%
print("Loading all 4 best models...")
m_vgg  = tf.keras.models.load_model("vgg19_best.keras")
m_res  = tf.keras.models.load_model("resnet50_best.keras")
m_eff  = tf.keras.models.load_model("effnet_best.keras")
m_res2 = tf.keras.models.load_model("resnet50v2_best.keras")

class_names = ['Normal', 'Osteopenia', 'Osteoporosis']

def get_preds(model, preprocess_fn, n_tta=20):
    """Get TTA predictions from a model."""
    tta_datagen = ImageDataGenerator(
        rotation_range=5,
        horizontal_flip=True,
        zoom_range=0.03,
        preprocessing_function=preprocess_fn
    )
    # Get total test samples
    total = sum(
        len(os.listdir(os.path.join(test_dir, cls)))
        for cls in ['Normal', 'Osteopenia', 'Osteoporosis']
    )
    preds = np.zeros((total, 3))

    for i in range(n_tta):
        gen = tta_datagen.flow_from_directory(
            test_dir, target_size=(224, 224), batch_size=1,
            classes=['Normal', 'Osteopenia', 'Osteoporosis'],
            class_mode='categorical', shuffle=False)
        gen.reset()
        preds += model.predict(gen, steps=len(gen), verbose=0)
        print(f"  TTA round {i+1}/{n_tta} done")
    return preds / n_tta

# VGG-19 and ResNet50 are strongest — give them 30 TTA rounds
print("\nVGG-19 predictions (30 TTA rounds)...")
preds_vgg = get_preds(m_vgg,
                      tf.keras.applications.vgg19.preprocess_input,
                      n_tta=30)

print("\nResNet50 predictions (30 TTA rounds)...")
preds_res = get_preds(m_res,
                      tf.keras.applications.resnet50.preprocess_input,
                      n_tta=30)

# EfficientNetB0 and ResNet50V2 get 20 TTA rounds
print("\nEfficientNetB0 predictions (20 TTA rounds)...")
preds_eff = get_preds(m_eff,
                      tf.keras.applications.efficientnet.preprocess_input,
                      n_tta=20)

print("\nResNet50V2 predictions (20 TTA rounds)...")
preds_res2 = get_preds(m_res2,
                       tf.keras.applications.resnet_v2.preprocess_input,
                       n_tta=20)

# Get true labels
label_gen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.vgg19.preprocess_input
).flow_from_directory(
    test_dir, target_size=(224, 224), batch_size=1,
    classes=['Normal', 'Osteopenia', 'Osteoporosis'],
    class_mode='categorical', shuffle=False)
y_true = label_gen.classes

print("\nAll predictions done!")

# %%
print("\nSearching for optimal ensemble weights...")
print("(This may take ~1 minute)")

best_acc   = 0
best_w     = (1, 1, 1, 1)
best_preds = None

# Search weight combinations for all 4 models
for w1 in np.arange(0.2, 1.3, 0.2):      # VGG-19
    for w2 in np.arange(0.2, 1.3, 0.2):   # ResNet50
        for w3 in np.arange(0.2, 1.1, 0.2): # EfficientNetB0
            for w4 in np.arange(0.2, 1.3, 0.2): # ResNet50V2
                ensemble = (w1*preds_vgg + w2*preds_res +
                            w3*preds_eff + w4*preds_res2)
                y_pred   = np.argmax(ensemble, axis=1)
                acc      = np.sum(y_pred == y_true) / len(y_true)
                if acc > best_acc:
                    best_acc   = acc
                    best_w     = (w1, w2, w3, w4)
                    best_preds = ensemble.copy()

print(f"\nBest weights:")
print(f"  VGG-19:        {best_w[0]:.1f}")
print(f"  ResNet50:      {best_w[1]:.1f}")
print(f"  EfficientNetB0:{best_w[2]:.1f}")
print(f"  ResNet50V2:    {best_w[3]:.1f}")
print(f"\nBest Ensemble Accuracy: {best_acc * 100:.2f}%")

y_pred_final = np.argmax(best_preds, axis=1)

print("\n--- Final Ensemble Classification Report ---")
print(classification_report(y_true, y_pred_final, target_names=class_names))

cm = confusion_matrix(y_true, y_pred_final)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d',
            xticklabels=class_names,
            yticklabels=class_names,
            cmap='Greens')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title(f'4-Model Ensemble — {best_acc*100:.2f}%')
plt.show()

# %%
print("\nFull model comparison:")
print("-" * 45)

results = {
    "VGG-19 (30 TTA)":        preds_vgg,
    "ResNet50 (30 TTA)":      preds_res,
    "EfficientNetB0 (20 TTA)":preds_eff,
    "ResNet50V2 (20 TTA)":    preds_res2,
    "Equal Ensemble (4 models)":(preds_vgg + preds_res +
                                  preds_eff + preds_res2) / 4,
    "Weighted Ensemble":       best_preds
}

for name, preds in results.items():
    y_p = np.argmax(preds, axis=1)
    acc = np.sum(y_p == y_true) / len(y_true)
    print(f"{name:30s}: {acc*100:.2f}%")

print(f"\nPrevious best (3-model ensemble): 89.46%")
print(f"New best (4-model ensemble):      {best_acc*100:.2f}%")
improvement = best_acc * 100 - 89.46
print(f"Improvement:                      +{improvement:.2f}%")

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator

test_dir = "/tmp/osteoporosis_merged/test"

label_gen = ImageDataGenerator(
 preprocessing_function=tf.keras.applications.vgg19.preprocess_input
).flow_from_directory(
 test_dir, target_size=(224, 224), batch_size=1,
 classes=['Normal', 'Osteopenia', 'Osteoporosis'],
 class_mode='categorical', shuffle=False)
y_true_current = label_gen.classes

def quick_predict(model, preprocess_fn):
 gen = ImageDataGenerator(
  preprocessing_function=preprocess_fn
 ).flow_from_directory(
  test_dir, target_size=(224, 224), batch_size=1,
  classes=['Normal', 'Osteopenia', 'Osteoporosis'],
  class_mode='categorical', shuffle=False)
 gen.reset()
 preds = model.predict(gen, steps=len(gen), verbose=0)
 return preds

print("Getting predictions...")
p_vgg = quick_predict(m_vgg, tf.keras.applications.vgg19.preprocess_input)
p_res = quick_predict(m_res, tf.keras.applications.resnet50.preprocess_input)
p_eff = quick_predict(m_eff, tf.keras.applications.efficientnet.preprocess_input)
p_res2 = quick_predict(m_res2, tf.keras.applications.resnet_v2.preprocess_input)

old_3 = (p_vgg + p_res + p_eff) / 3
acc_old3 = np.sum(np.argmax(old_3, axis=1) == y_true_current) / len(y_true_current)

new_4 = (0.6*p_vgg + 1.0*p_res + 0.2*p_eff + 0.2*p_res2)
acc_new4 = np.sum(np.argmax(new_4, axis=1) == y_true_current) / len(y_true_current)

print(f"\nOld 3-model ensemble: {acc_old3*100:.2f}%")
print(f"New 4-model weighted: {acc_new4*100:.2f}%")

if acc_new4 > acc_old3:
 print(f"4-model is BETTER by {(acc_new4-acc_old3)*100:.2f}%")
else:
 print(f"3-model is BETTER by {(acc_old3-acc_new4)*100:.2f}%")

# %%
import kagglehub
import os

# Option 1 — Orvile (newer 2025 dataset, never used in training)
print("Downloading Orvile dataset...")
path_orvile = kagglehub.dataset_download("orvile/knee-x-ray-osteoporosis-database")
print("Orvile path:", path_orvile)

# Option 2 — Sachinkumar preprocessed dataset
print("\nDownloading Sachinkumar dataset...")
path_sach = kagglehub.dataset_download("sachinkumar413/osteoporosis-knee-dataset-preprocessed128x256")
print("Sachinkumar path:", path_sach)

# Option 3 — mohamedgobara secondary dataset
print("\nDownloading mohamedgobara secondary dataset...")
path_bmd = kagglehub.dataset_download("mohamedgobara/osteoporosis-database")
print("BMD path:", path_bmd)

def explore_folder(path, max_depth=3, current_depth=0):
 if current_depth >= max_depth:
  return
 try:
  for item in sorted(os.listdir(path)):
   print(" " * current_depth + item)
   full = os.path.join(path, item)
   if os.path.isdir(full):
    explore_folder(full, max_depth, current_depth + 1)
 except:
  pass

print("\n=== Orvile Structure ===")
explore_folder(path_orvile)

print("\n=== Sachinkumar Structure ===")
explore_folder(path_sach)

print("\n=== BMD Structure ===")
explore_folder(path_bmd)

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import shutil

class_names = ['Normal', 'Osteopenia', 'Osteoporosis']

def ensemble_predict_from_folder(folder, preprocess_vgg, preprocess_res, preprocess_eff, n_tta=10):
 total = sum(
  len(os.listdir(os.path.join(folder, c)))
  for c in os.listdir(folder)
  if os.path.isdir(os.path.join(folder, c))
 )
 preds_vgg = np.zeros((total, 3))
 preds_res = np.zeros((total, 3))
 preds_eff = np.zeros((total, 3))
 tta_datagen_vgg = ImageDataGenerator(rotation_range=5, horizontal_flip=True, zoom_range=0.03, preprocessing_function=preprocess_vgg)
 tta_datagen_res = ImageDataGenerator(rotation_range=5, horizontal_flip=True, zoom_range=0.03, preprocessing_function=preprocess_res)
 tta_datagen_eff = ImageDataGenerator(rotation_range=5, horizontal_flip=True, zoom_range=0.03, preprocessing_function=preprocess_eff)
 classes = sorted(os.listdir(folder))
 classes = [c for c in classes if os.path.isdir(os.path.join(folder, c))]
 for i in range(n_tta):
  for datagen, preds, model in [
   (tta_datagen_vgg, preds_vgg, m_vgg),
   (tta_datagen_res, preds_res, m_res),
   (tta_datagen_eff, preds_eff, m_eff)
  ]:
   gen = datagen.flow_from_directory(
    folder, target_size=(224, 224), batch_size=1,
    classes=classes, class_mode='categorical', shuffle=False)
   gen.reset()
   preds += model.predict(gen, steps=len(gen), verbose=0)
  print(f" TTA round {i+1}/{n_tta} done")
 preds_vgg /= n_tta
 preds_res /= n_tta
 preds_eff /= n_tta
 ensemble = (preds_vgg + preds_res + preds_eff) / 3
 label_gen = ImageDataGenerator(preprocessing_function=preprocess_vgg).flow_from_directory(
  folder, target_size=(224, 224), batch_size=1,
  classes=classes, class_mode='categorical', shuffle=False)
 y_true = label_gen.classes
 return ensemble, y_true, classes

def show_results(ensemble, y_true, dataset_name, label_names):
 y_pred = np.argmax(ensemble, axis=1)
 acc = np.sum(y_pred == y_true) / len(y_true)
 print(f"\n{'='*50}")
 print(f"Dataset: {dataset_name}")
 print(f"Total images: {len(y_true)}")
 print(f"Accuracy: {acc*100:.2f}%")
 print(f"{'='*50}")
 print(classification_report(y_true, y_pred, target_names=label_names))
 cm = confusion_matrix(y_true, y_pred)
 plt.figure(figsize=(8, 6))
 sns.heatmap(cm, annot=True, fmt='d', xticklabels=label_names, yticklabels=label_names, cmap='Blues')
 plt.xlabel('Predicted')
 plt.ylabel('True')
 plt.title(f'{dataset_name} — {acc*100:.2f}%')
 plt.show()

# ── Test on Orvile dataset (3 classes) ──
print("\nTesting on Orvile dataset...")
orvile_dir = os.path.join(path_orvile, "Osteoporosis Knee X-ray")

# Rename folders to match training classes
rename_map = {
 'normal': 'Normal',
 'osteopenia': 'Osteopenia',
 'osteoporosis': 'Osteoporosis'
}
for old, new in rename_map.items():
 old_path = os.path.join(orvile_dir, old)
 new_path = os.path.join(orvile_dir, new)
 if os.path.exists(old_path) and not os.path.exists(new_path):
  os.rename(old_path, new_path)
  print(f" Renamed {old} -> {new}")

ensemble_orvile, y_true_orvile, _ = ensemble_predict_from_folder(
 orvile_dir,
 tf.keras.applications.vgg19.preprocess_input,
 tf.keras.applications.resnet50.preprocess_input,
 tf.keras.applications.efficientnet.preprocess_input,
 n_tta=10
)
show_results(ensemble_orvile, y_true_orvile, "Orvile Dataset", class_names)

# ── Test on Sachinkumar dataset (2 classes only) ──
print("\nTesting on Sachinkumar dataset (Normal vs Osteoporosis only)...")
sach_dir = os.path.join(path_sach, "Osteoporosis Knee Dataset")
sach_classes = ['Normal', 'Osteoporosis']

ensemble_sach, y_true_sach, _ = ensemble_predict_from_folder(
 sach_dir,
 tf.keras.applications.vgg19.preprocess_input,
 tf.keras.applications.resnet50.preprocess_input,
 tf.keras.applications.efficientnet.preprocess_input,
 n_tta=10
)

# For Sachinkumar remap predictions to only Normal/Osteoporosis
# Class indices from flow_from_directory will be Normal=0, Osteoporosis=1
# But our model outputs 3 classes: Normal=0, Osteopenia=1, Osteoporosis=2
# So we combine Osteopenia predictions into Osteoporosis
sach_ensemble_2class = np.zeros((len(y_true_sach), 2))
sach_ensemble_2class[:, 0] = ensemble_sach[:, 0]  # Normal
sach_ensemble_2class[:, 1] = ensemble_sach[:, 1] + ensemble_sach[:, 2]  # Osteopenia+Osteoporosis -> Osteoporosis

y_pred_sach = np.argmax(sach_ensemble_2class, axis=1)
acc_sach = np.sum(y_pred_sach == y_true_sach) / len(y_true_sach)

print(f"\n{'='*50}")
print(f"Dataset: Sachinkumar (2-class)")
print(f"Total images: {len(y_true_sach)}")
print(f"Accuracy: {acc_sach*100:.2f}%")
print(f"{'='*50}")
print(classification_report(y_true_sach, y_pred_sach, target_names=sach_classes))

cm_sach = confusion_matrix(y_true_sach, y_pred_sach)
plt.figure(figsize=(6, 5))
sns.heatmap(cm_sach, annot=True, fmt='d', xticklabels=sach_classes, yticklabels=sach_classes, cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title(f'Sachinkumar Dataset — {acc_sach*100:.2f}%')
plt.show()
