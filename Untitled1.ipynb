# %% [markdown]
# <a href="https://colab.research.google.com/github/Shahidrrs/nutribone3/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
import matplotlib.pyplot as plt
import numpy as np
import os
import shutil
import random
import seaborn as sns

# %%
import kagglehub

print("Downloading dataset 1 (mohamedgobara)...")
path1 = kagglehub.dataset_download("mohamedgobara/multi-class-knee-osteoporosis-x-ray-dataset")
print("Dataset 1 path:", path1)

print("\nDownloading dataset 2 (stevepython)...")
path2 = kagglehub.dataset_download("stevepython/osteoporosis-knee-xray-dataset")
print("Dataset 2 path:", path2)
# Out:
# Downloading dataset 1 (mohamedgobara)...
# Using Colab cache for faster access to the 'multi-class-knee-osteoporosis-x-ray-dataset' dataset.
# Dataset 1 path: /kaggle/input/multi-class-knee-osteoporosis-x-ray-dataset
#
# Downloading dataset 2 (stevepython)...
# Using Colab cache for faster access to the 'osteoporosis-knee-xray-dataset' dataset.
# Dataset 2 path: /kaggle/input/osteoporosis-knee-xray-dataset

# %%
random.seed(42)
import cv2
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img

merged_dir = "/tmp/osteoporosis_merged"
splits     = ['train', 'val', 'test']
classes    = ['Normal', 'Osteopenia', 'Osteoporosis']

# Create folder structure
for split in splits:
    for cls in classes:
        os.makedirs(os.path.join(merged_dir, split, cls), exist_ok=True)

def collect_images(src_dir):
    if not os.path.exists(src_dir):
        print(f"  WARNING: Not found: {src_dir}")
        return []
    return [
        os.path.join(src_dir, f)
        for f in os.listdir(src_dir)
        if f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp'))
    ]

def split_and_copy(image_paths, dst_class_dirs, label_prefix, train=0.75, val=0.15):
    random.shuffle(image_paths)
    n       = len(image_paths)
    n_train = int(n * train)
    n_val   = int(n * val)
    splits_map = {
        'train': image_paths[:n_train],
        'val':   image_paths[n_train:n_train + n_val],
        'test':  image_paths[n_train + n_val:]
    }
    counts = {}
    for split_name, paths in splits_map.items():
        dst = dst_class_dirs[split_name]
        for i, src in enumerate(paths):
            ext = os.path.splitext(src)[1]
            shutil.copy2(src, os.path.join(dst, f"{label_prefix}_{i}{ext}"))
        counts[split_name] = len(paths)
    return counts

def augment_to_target(src_dir, target_count, label_prefix='aug'):
    """
    Augment images in src_dir until target_count is reached.
    Returns list of augmented image arrays saved as files.
    """
    existing = [
        os.path.join(src_dir, f)
        for f in os.listdir(src_dir)
        if f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp'))
    ]
    current = len(existing)
    if current >= target_count:
        return

    aug = ImageDataGenerator(
        rotation_range=15,
        width_shift_range=0.1,
        height_shift_range=0.1,
        zoom_range=0.1,
        horizontal_flip=True,
        brightness_range=[0.85, 1.15],
        fill_mode='nearest'
    )

    needed = target_count - current
    idx    = 0
    print(f"  Augmenting {current} → {target_count} images ({needed} new)...")

    while idx < needed:
        # Pick a random existing image to augment
        src_img_path = random.choice(existing)
        img = load_img(src_img_path, target_size=(224, 224))
        x   = img_to_array(img)
        x   = x.reshape((1,) + x.shape)

        for batch in aug.flow(x, batch_size=1):
            aug_img = batch[0].astype(np.uint8)
            save_path = os.path.join(src_dir, f"{label_prefix}_{idx}.jpg")
            # Save using PIL
            from PIL import Image
            Image.fromarray(aug_img).save(save_path)
            idx += 1
            break  # one augmented image per loop

        if idx >= needed:
            break

    print(f"  Done. Total now: {len(os.listdir(src_dir))} images")

# ── Dataset 1 source paths ──
d1_base    = os.path.join(path1, "OS Collected Data")
d1_sources = {
    'Normal':       os.path.join(d1_base, "Normal"),
    'Osteopenia':   os.path.join(d1_base, "Osteopenia"),
    'Osteoporosis': os.path.join(d1_base, "Osteoporosis"),
}

# ── Dataset 2 source paths ──
d2_sources = {
    'Normal':       os.path.join(path2, "normal", "normal"),
    'Osteoporosis': os.path.join(path2, "osteoporosis", "osteoporosis"),
}

print("=" * 50)
print("Merging and splitting datasets...")
print("=" * 50)

for cls in classes:
    dst_dirs = {s: os.path.join(merged_dir, s, cls) for s in splits}

    imgs_d1 = collect_images(d1_sources.get(cls, ""))
    counts1 = split_and_copy(imgs_d1, dst_dirs, label_prefix="d1")

    imgs_d2 = collect_images(d2_sources.get(cls, ""))
    counts2 = split_and_copy(imgs_d2, dst_dirs, label_prefix="d2")

    total = len(imgs_d1) + len(imgs_d2)
    print(f"\n{cls}: {len(imgs_d1)} from D1 + {len(imgs_d2)} from D2 = {total} total")
    for s in splits:
        n = counts1.get(s, 0) + counts2.get(s, 0)
        print(f"  {s}: {n} images")

# ── Balance Osteopenia by augmenting to match Normal/Osteoporosis ──
print("\n" + "=" * 50)
print("Balancing Osteopenia class via augmentation...")
print("=" * 50)

# Target: match roughly the average of Normal and Osteoporosis in each split
targets = {
    'train': 724,   # match Normal train count
    'val':   144,   # match Normal val count
    'test':  98     # match Normal test count
}

for split_name, target in targets.items():
    osteopenia_dir = os.path.join(merged_dir, split_name, 'Osteopenia')
    print(f"\n{split_name}/Osteopenia:")
    augment_to_target(osteopenia_dir, target, label_prefix='aug')

# ── Final summary ──
print("\n" + "=" * 50)
print("Final balanced dataset summary:")
for split in splits:
    print(f"\n{split}/")
    for cls in classes:
        n = len(os.listdir(os.path.join(merged_dir, split, cls)))
        print(f"  {cls}: {n} images")
# Out:
# ==================================================
# Merging and splitting datasets...
# ==================================================
#
# Normal: 780 from D1 + 186 from D2 = 966 total
#   train: 724 images
#   val: 144 images
#   test: 98 images
#   WARNING: Not found:
#
# Osteopenia: 374 from D1 + 0 from D2 = 374 total
#   train: 280 images
#   val: 56 images
#   test: 38 images
#
# Osteoporosis: 793 from D1 + 186 from D2 = 979 total
#   train: 733 images
#   val: 145 images
#   test: 101 images
#
# ==================================================
# Balancing Osteopenia class via augmentation...
# ==================================================
#
# train/Osteopenia:
#   Augmenting 280 → 724 images (444 new)...
#   Done. Total now: 724 images
#
# val/Osteopenia:
#   Augmenting 56 → 144 images (88 new)...
#   Done. Total now: 144 images
#
# test/Osteopenia:
#   Augmenting 38 → 98 images (60 new)...
#   Done. Total now: 98 images
#
# ==================================================
# Final balanced dataset summary:
#
# train/
#   Normal: 724 images
#   Osteopenia: 724 images
#   Osteoporosis: 733 images
#
# val/
#   Normal: 144 images
#   Osteopenia: 144 images
#   Osteoporosis: 145 images
#
# test/
#   Normal: 98 images
#   Osteopenia: 98 images
#   Osteoporosis: 101 images

# %%
train_dir = os.path.join(merged_dir, 'train')
val_dir   = os.path.join(merged_dir, 'val')
test_dir  = os.path.join(merged_dir, 'test')

train_datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    brightness_range=[0.85, 1.15],
    fill_mode='nearest',
    preprocessing_function=tf.keras.applications.vgg19.preprocess_input
)

val_datagen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.vgg19.preprocess_input
)

test_datagen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.vgg19.preprocess_input
)

train_gen = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=16,
    classes=['Normal', 'Osteopenia', 'Osteoporosis'],
    class_mode='categorical',
    shuffle=True
)

val_gen = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=16,
    classes=['Normal', 'Osteopenia', 'Osteoporosis'],
    class_mode='categorical',
    shuffle=False
)

test_gen = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=1,
    classes=['Normal', 'Osteopenia', 'Osteoporosis'],
    class_mode='categorical',
    shuffle=False
)

print(f"Train : {train_gen.samples} images")
print(f"Val   : {val_gen.samples} images")
print(f"Test  : {test_gen.samples} images")
print(f"Classes: {train_gen.class_indices}")
# Out:
# Found 2520 images belonging to 2 classes.
# Found 720 images belonging to 2 classes.
# Found 360 images belonging to 2 classes.
#
# Training samples: 2520
# Validation samples: 720
# Test samples: 360
# Class indices: {'Normal': 0, 'Osteoporosis': 1}

# %%
print("\nBuilding VGG-19 model...")

inputs = layers.Input(shape=(224, 224, 3))

base_model = tf.keras.applications.VGG19(
    include_top=False,
    weights='imagenet',
    input_shape=(224, 224, 3)
)

# Stage 1: freeze entire backbone
base_model.trainable = False

x = base_model(inputs, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.5)(x)

x = layers.Dense(512, activation='relu',
                  kernel_regularizer=tf.keras.regularizers.l2(1e-4))(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.4)(x)

x = layers.Dense(256, activation='relu',
                  kernel_regularizer=tf.keras.regularizers.l2(1e-4))(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.3)(x)

outputs = layers.Dense(3, activation='softmax')(x)

model = models.Model(inputs, outputs)
model.summary()
print("\nStage 1 ready — VGG-19 backbone frozen.")
# Out:
# Building EfficientNetB3 model...
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941136/43941136 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb3 (Functional)     │ (None, 7, 7, 1536)     │    10,783,535 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1536)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 1536)           │         6,144 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1536)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       786,944 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,711,280 (44.67 MB)
#  Trainable params: 923,137 (3.52 MB)
#  Non-trainable params: 10,788,143 (41.15 MB)
# Stage 1 model ready — backbone fully frozen.

# %%
# Compute class weights
class_weights_array = compute_class_weight(
    class_weight='balanced',
    classes=np.array([0, 1, 2]),
    y=train_gen.classes
)
class_weights = dict(enumerate(class_weights_array))
print("Class weights:", class_weights)

callbacks_s1 = [
    EarlyStopping(monitor='val_loss', patience=6,
                  restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.3,
                      patience=3, min_lr=1e-7, verbose=1),
    ModelCheckpoint("best_stage1.keras", monitor='val_accuracy',
                    save_best_only=True, verbose=1)
]

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

print("\nStage 1: Training head with frozen backbone...")
history1 = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=20,
    callbacks=callbacks_s1,
    class_weight=class_weights
)

print(f"\nBest Stage 1 Val Accuracy: {max(history1.history['val_accuracy']):.4f}")
# Out:
# Class weights: {0: np.float64(1.0), 1: np.float64(1.0)}
#
# Stage 1: Training head with frozen backbone...
# Epoch 1/15
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 902ms/step - accuracy: 0.6350 - loss: 0.9165
# Epoch 1: val_accuracy improved from None to 0.67222, saving model to best_stage1.keras
#
# Epoch 1: finished saving model to best_stage1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 152s 1s/step - accuracy: 0.6528 - loss: 0.8584 - val_accuracy: 0.6722 - val_loss: 0.7192 - learning_rate: 0.0010
# Epoch 2/15
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.6858 - loss: 0.7746
# Epoch 2: val_accuracy improved from 0.67222 to 0.67917, saving model to best_stage1.keras
#
# Epoch 2: finished saving model to best_stage1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 40s 501ms/step - accuracy: 0.6873 - loss: 0.7709 - val_accuracy: 0.6792 - val_loss: 0.7047 - learning_rate: 0.0010
# Epoch 3/15
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step - accuracy: 0.7058 - loss: 0.7249
# Epoch 3: val_accuracy improved from 0.67917 to 0.69861, saving model to best_stage1.keras
#
# Epoch 3: finished saving model to best_stage1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 508ms/step - accuracy: 0.7060 - loss: 0.7123 - val_accuracy: 0.6986 - val_loss: 0.6852 - learning_rate: 0.0010
# Epoch 4/15
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - accuracy: 0.7393 - loss: 0.6468
# Epoch 4: val_accuracy did not improve from 0.69861
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 38s 484ms/step - accuracy: 0.7345 - loss: 0.6648 - val_accuracy: 0.6917 - val_loss: 0.7285 - learning_rate: 0.0010
# Epoch 5/15
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step - accuracy: 0.7405 - loss: 0.6677
# Epoch 5: val_accuracy improved from 0.69861 to 0.70694, saving model to best_stage1.keras
#
# Epoch 5: finished saving model to best_stage1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 39s 497ms/step - accuracy: 0.7476 - loss: 0.6400 - val_accuracy: 0.7069 - val_loss: 0.7164 - learning_rate: 0.0010
# Epoch 6/15
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - accuracy: 0.7459 - loss: 0.6457
# Epoch 6: val_accuracy improved from 0.70694 to 0.73056, saving model to best_stage1.keras
#
# Epoch 6: finished saving model to best_stage1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 40s 501ms/step - accuracy: 0.7496 - loss: 0.6443 - val_accuracy: 0.7306 - val_loss: 0.6644 - learning_rate: 0.0010
# Epoch 7/15
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step - accuracy: 0.7528 - loss: 0.6387
# Epoch 7: val_accuracy improved from 0.73056 to 0.73472, saving model to best_stage1.keras
#
# Epoch 7: finished saving model to best_stage1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 40s 505ms/step - accuracy: 0.7433 - loss: 0.6450 - val_accuracy: 0.7347 - val_loss: 0.6533 - learning_rate: 0.0010
# Epoch 8/15
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step - accuracy: 0.7691 - loss: 0.6281
# Epoch 8: val_accuracy improved from 0.73472 to 0.74583, saving model to best_stage1.keras
#
# Epoch 8: finished saving model to best_stage1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 518ms/step - accuracy: 0.7694 - loss: 0.6210 - val_accuracy: 0.7458 - val_loss: 0.6338 - learning_rate: 0.0010
# Epoch 9/15
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - accuracy: 0.7565 - loss: 0.6277
# Epoch 9: val_accuracy did not improve from 0.74583
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 39s 491ms/step - accuracy: 0.7583 - loss: 0.6197 - val_accuracy: 0.7389 - val_loss: 0.6260 - learning_rate: 0.0010
# Epoch 10/15
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - accuracy: 0.7699 - loss: 0.6035
# Epoch 10: val_accuracy did not improve from 0.74583
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 38s 486ms/step - accuracy: 0.7726 - loss: 0.6102 - val_accuracy: 0.7333 - val_loss: 0.6536 - learning_rate: 0.0010
# Epoch 11/15
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - accuracy: 0.7783 - loss: 0.5993
# Epoch 11: val_accuracy improved from 0.74583 to 0.74722, saving model to best_stage1.keras
#
# Epoch 11: finished saving model to best_stage1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 39s 498ms/step - accuracy: 0.7607 - loss: 0.6195 - val_accuracy: 0.7472 - val_loss: 0.6401 - learning_rate: 0.0010
# Epoch 12/15
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step - accuracy: 0.7811 - loss: 0.5917
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
#
# Epoch 12: val_accuracy improved from 0.74722 to 0.75139, saving model to best_stage1.keras
#
# Epoch 12: finished saving model to best_stage1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 41s 497ms/step - accuracy: 0.7849 - loss: 0.5882 - val_accuracy: 0.7514 - val_loss: 0.6332 - learning_rate: 0.0010
# Epoch 13/15
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - accuracy: 0.7764 - loss: 0.5887
# Epoch 13: val_accuracy improved from 0.75139 to 0.76389, saving model to best_stage1.keras
#
# Epoch 13: finished saving model to best_stage1.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 39s 493ms/step - accuracy: 0.7754 - loss: 0.5946 - val_accuracy: 0.7639 - val_loss: 0.6206 - learning_rate: 3.0000e-04
# Epoch 14/15
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - accuracy: 0.7867 - loss: 0.5810
# Epoch 14: val_accuracy did not improve from 0.76389
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 39s 488ms/step - accuracy: 0.7813 - loss: 0.5843 - val_accuracy: 0.7569 - val_loss: 0.6190 - learning_rate: 3.0000e-04
# Epoch 15/15
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - accuracy: 0.8015 - loss: 0.5721
# Epoch 15: val_accuracy did not improve from 0.76389
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 39s 487ms/step - accuracy: 0.7925 - loss: 0.5780 - val_accuracy: 0.7514 - val_loss: 0.6217 - learning_rate: 3.0000e-04
# Restoring model weights from the end of the best epoch: 14.
#
# Best Stage 1 Val Accuracy: 0.7639

# %%
print("\nStage 2: Unfreezing VGG-19 block5 only...")

base_model.trainable = True
for layer in base_model.layers:
    layer.trainable = 'block5' in layer.name

print("Trainable layers:", [l.name for l in base_model.layers if l.trainable])

callbacks_s2 = [
    EarlyStopping(monitor='val_loss', patience=8,
                  restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.3,
                      patience=4, min_lr=1e-9, verbose=1),
    ModelCheckpoint("best_stage2.keras", monitor='val_accuracy',
                    save_best_only=True, verbose=1)
]

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

print("\nStage 2: Fine-tuning...")
history2 = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=40,
    callbacks=callbacks_s2,
    class_weight=class_weights
)

model.save("nutribone_vgg19_3class_final.keras")
print(f"\nBest Stage 2 Val Accuracy: {max(history2.history['val_accuracy']):.4f}")
# Out:
# Stage 2: Unfreezing top 40% of backbone layers...
# Total backbone layers: 385
# Frozen layers: 231
# Trainable backbone layers: 154
#
# Stage 2: Fine-tuning with partial backbone unfreeze...
# Epoch 1/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 982ms/step - accuracy: 0.6881 - loss: 0.7563
# Epoch 1: val_accuracy improved from None to 0.70833, saving model to best_stage2.keras
#
# Epoch 1: finished saving model to best_stage2.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 171s 1s/step - accuracy: 0.6841 - loss: 0.7562 - val_accuracy: 0.7083 - val_loss: 0.6938 - learning_rate: 1.0000e-05
# Epoch 2/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step - accuracy: 0.6974 - loss: 0.7169
# Epoch 2: val_accuracy did not improve from 0.70833
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 39s 493ms/step - accuracy: 0.7052 - loss: 0.7000 - val_accuracy: 0.6917 - val_loss: 0.7225 - learning_rate: 1.0000e-05
# Epoch 3/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step - accuracy: 0.7137 - loss: 0.6951
# Epoch 3: val_accuracy did not improve from 0.70833
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 39s 491ms/step - accuracy: 0.7163 - loss: 0.6965 - val_accuracy: 0.6847 - val_loss: 0.7423 - learning_rate: 1.0000e-05
# Epoch 4/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step - accuracy: 0.7515 - loss: 0.6449
# Epoch 4: ReduceLROnPlateau reducing learning rate to 2.9999999242136253e-06.
#
# Epoch 4: val_accuracy did not improve from 0.70833
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 39s 495ms/step - accuracy: 0.7357 - loss: 0.6620 - val_accuracy: 0.6819 - val_loss: 0.7442 - learning_rate: 1.0000e-05
# Epoch 5/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step - accuracy: 0.7399 - loss: 0.6696
# Epoch 5: val_accuracy did not improve from 0.70833
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 40s 499ms/step - accuracy: 0.7456 - loss: 0.6540 - val_accuracy: 0.6792 - val_loss: 0.7523 - learning_rate: 3.0000e-06
# Epoch 6/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step - accuracy: 0.7413 - loss: 0.6501
# Epoch 6: val_accuracy did not improve from 0.70833
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 40s 502ms/step - accuracy: 0.7385 - loss: 0.6562 - val_accuracy: 0.6792 - val_loss: 0.7546 - learning_rate: 3.0000e-06
# Epoch 7/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step - accuracy: 0.7659 - loss: 0.6258
# Epoch 7: ReduceLROnPlateau reducing learning rate to 8.999999636216671e-07.
#
# Epoch 7: val_accuracy did not improve from 0.70833
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 40s 505ms/step - accuracy: 0.7560 - loss: 0.6339 - val_accuracy: 0.6806 - val_loss: 0.7521 - learning_rate: 3.0000e-06
# Epoch 8/30
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step - accuracy: 0.7570 - loss: 0.6389
# Epoch 8: val_accuracy did not improve from 0.70833
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 40s 502ms/step - accuracy: 0.7464 - loss: 0.6502 - val_accuracy: 0.6806 - val_loss: 0.7520 - learning_rate: 9.0000e-07
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 1.
#
# Best Stage 2 Val Accuracy: 0.7083
# Final model saved!

# %%
total_train_loss = history1.history['loss'] + history2.history['loss']
total_val_loss   = history1.history['val_loss'] + history2.history['val_loss']
total_train_acc  = history1.history['accuracy'] + history2.history['accuracy']
total_val_acc    = history1.history['val_accuracy'] + history2.history['val_accuracy']
split_point      = len(history1.history['loss']) - 1

plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(total_train_loss, label='Train Loss', color='royalblue')
plt.plot(total_val_loss, label='Val Loss', color='orange', linestyle='--')
plt.axvline(x=split_point, color='gray', linestyle=':', label='Fine-Tune Split')
plt.legend()
plt.title('Loss (Stage 1 + Stage 2)')
plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.subplot(1, 2, 2)
plt.plot(total_train_acc, label='Train Accuracy', color='royalblue')
plt.plot(total_val_acc, label='Val Accuracy', color='orange', linestyle='--')
plt.axvline(x=split_point, color='gray', linestyle=':', label='Fine-Tune Split')
plt.legend()
plt.title('Accuracy (Stage 1 + Stage 2)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

plt.tight_layout()
plt.show()

# %%
print("\nLoading best model...")
eval_model = tf.keras.models.load_model("best_stage2.keras")

test_gen.reset()
preds  = eval_model.predict(test_gen, steps=len(test_gen), verbose=1)
y_pred = np.argmax(preds, axis=1)
y_true = test_gen.classes
class_names = ['Normal', 'Osteopenia', 'Osteoporosis']

print("\n--- Classification Report ---")
print(classification_report(y_true, y_pred, target_names=class_names))

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d',
            xticklabels=class_names,
            yticklabels=class_names,
            cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix — Test Set')
plt.show()

print(f"\nFinal Test Accuracy: {np.sum(y_pred == y_true) / len(y_true) * 100:.2f}%")
# Out:
# Loading best saved model for evaluation...
# Running predictions on test set...
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 22s 11ms/step
#
# --- Classification Report (Test Set) ---
#               precision    recall  f1-score   support
#
#       Normal       0.72      0.61      0.66       180
# Osteoporosis       0.66      0.76      0.71       180
#
#     accuracy                           0.68       360
#    macro avg       0.69      0.68      0.68       360
# weighted avg       0.69      0.68      0.68       360
# Final Test Accuracy: 68.33%

# %%
print("\nApplying TTA...")

tta_datagen = ImageDataGenerator(
    rotation_range=8,
    horizontal_flip=True,
    zoom_range=0.08,
    preprocessing_function=tf.keras.applications.vgg19.preprocess_input
)

tta_rounds = 10
tta_preds  = np.zeros((test_gen.samples, 3))

for i in range(tta_rounds):
    tta_gen = tta_datagen.flow_from_directory(
        test_dir,
        target_size=(224, 224),
        batch_size=1,
        classes=['Normal', 'Osteopenia', 'Osteoporosis'],
        class_mode='categorical',
        shuffle=False
    )
    tta_gen.reset()
    tta_preds += eval_model.predict(tta_gen, steps=len(tta_gen), verbose=0)
    print(f"TTA round {i+1}/{tta_rounds} done")

tta_preds /= tta_rounds
y_pred_tta = np.argmax(tta_preds, axis=1)

print("\n--- TTA Classification Report ---")
print(classification_report(y_true, y_pred_tta, target_names=class_names))

cm_tta = confusion_matrix(y_true, y_pred_tta)
plt.figure(figsize=(8, 6))
sns.heatmap(cm_tta, annot=True, fmt='d',
            xticklabels=class_names,
            yticklabels=class_names,
            cmap='Greens')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix — With TTA')
plt.show()

print(f"\nFinal TTA Accuracy: {np.sum(y_pred_tta == y_true) / len(y_true) * 100:.2f}%")
# Out:
# Applying Test Time Augmentation (TTA) for final accuracy boost...
# Found 360 images belonging to 2 classes.
# TTA round 1/10 complete
# Found 360 images belonging to 2 classes.
# TTA round 2/10 complete
# Found 360 images belonging to 2 classes.
# TTA round 3/10 complete
# Found 360 images belonging to 2 classes.
# TTA round 4/10 complete
# Found 360 images belonging to 2 classes.
# TTA round 5/10 complete
# Found 360 images belonging to 2 classes.
# TTA round 6/10 complete
# Found 360 images belonging to 2 classes.
# TTA round 7/10 complete
# Found 360 images belonging to 2 classes.
# TTA round 8/10 complete
# Found 360 images belonging to 2 classes.
# TTA round 9/10 complete
# Found 360 images belonging to 2 classes.
# TTA round 10/10 complete
#
# --- TTA Classification Report ---
#               precision    recall  f1-score   support
#
#       Normal       0.74      0.63      0.68       180
# Osteoporosis       0.68      0.78      0.73       180
#
#     accuracy                           0.71       360
#    macro avg       0.71      0.71      0.70       360
# weighted avg       0.71      0.71      0.70       360
# Final TTA Test Accuracy: 70.56%
