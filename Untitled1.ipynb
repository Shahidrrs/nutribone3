# %% [markdown]
# <a href="https://colab.research.google.com/github/Shahidrrs/nutribone3/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
import matplotlib.pyplot as plt
import numpy as np
import os
import shutil
import random
import seaborn as sns

# %%
import kagglehub

print("Downloading dataset 1 (mohamedgobara)...")
path1 = kagglehub.dataset_download("mohamedgobara/multi-class-knee-osteoporosis-x-ray-dataset")
print("Dataset 1 path:", path1)

print("\nDownloading dataset 2 (stevepython)...")
path2 = kagglehub.dataset_download("stevepython/osteoporosis-knee-xray-dataset")
print("Dataset 2 path:", path2)
# Out:
# Downloading dataset 1 (mohamedgobara)...
# Using Colab cache for faster access to the 'multi-class-knee-osteoporosis-x-ray-dataset' dataset.
# Dataset 1 path: /kaggle/input/multi-class-knee-osteoporosis-x-ray-dataset
#
# Downloading dataset 2 (stevepython)...
# Using Colab cache for faster access to the 'osteoporosis-knee-xray-dataset' dataset.
# Dataset 2 path: /kaggle/input/osteoporosis-knee-xray-dataset

# %%
import random
import shutil
import os
import numpy as np
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img

random.seed(42)
np.random.seed(42)

if os.path.exists("/tmp/osteoporosis_merged"):
    shutil.rmtree("/tmp/osteoporosis_merged")
    print("Old merged folder deleted.")

merged_dir = "/tmp/osteoporosis_merged"
splits     = ['train', 'val', 'test']
classes    = ['Normal', 'Osteopenia', 'Osteoporosis']

targets = {
    'train': 724,
    'val':   144,
    'test':  98
}

for split in splits:
    for cls in classes:
        os.makedirs(os.path.join(merged_dir, split, cls), exist_ok=True)

def collect_images(src_dir):
    if not os.path.exists(src_dir):
        print(f"  WARNING: Not found: {src_dir}")
        return []
    return [
        os.path.join(src_dir, f)
        for f in os.listdir(src_dir)
        if f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp'))
    ]

def split_and_copy(image_paths, dst_class_dirs, label_prefix, train=0.75, val=0.15):
    random.shuffle(image_paths)
    n       = len(image_paths)
    n_train = int(n * train)
    n_val   = int(n * val)
    splits_map = {
        'train': image_paths[:n_train],
        'val':   image_paths[n_train:n_train + n_val],
        'test':  image_paths[n_train + n_val:]
    }
    counts = {}
    for split_name, paths in splits_map.items():
        dst = dst_class_dirs[split_name]
        for i, src in enumerate(paths):
            ext = os.path.splitext(src)[1].lower()
            shutil.copy2(src, os.path.join(dst, f"{label_prefix}_{i}{ext}"))
        counts[split_name] = len(paths)
    return counts

def augment_to_exact(src_dir, target_count, label_prefix='aug'):
    existing = [
        os.path.join(src_dir, f)
        for f in os.listdir(src_dir)
        if f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp'))
    ]
    current = len(existing)
    if current > target_count:
        to_remove = random.sample(existing, current - target_count)
        for f in to_remove:
            os.remove(f)
        print(f"  Trimmed {current} → {target_count}")
        return
    if current < target_count:
        aug = ImageDataGenerator(
            rotation_range=20,
            width_shift_range=0.1,
            height_shift_range=0.1,
            zoom_range=0.15,
            horizontal_flip=True,
            brightness_range=[0.8, 1.2],
            shear_range=0.1,
            fill_mode='nearest'
        )
        needed = target_count - current
        idx = 0
        print(f"  Augmenting {current} → {target_count} (need {needed})...")
        while idx < needed:
            src_img_path = random.choice(existing)
            try:
                img = load_img(src_img_path, target_size=(224, 224))
                x   = img_to_array(img).reshape((1, 224, 224, 3))
                for batch in aug.flow(x, batch_size=1):
                    Image.fromarray(batch[0].astype(np.uint8)).save(
                        os.path.join(src_dir, f"{label_prefix}_{idx}.jpg"))
                    idx += 1
                    break
            except Exception as e:
                continue
        print(f"  Done: {len(os.listdir(src_dir))} images")

d1_base    = os.path.join(path1, "OS Collected Data")
d1_sources = {
    'Normal':       os.path.join(d1_base, "Normal"),
    'Osteopenia':   os.path.join(d1_base, "Osteopenia"),
    'Osteoporosis': os.path.join(d1_base, "Osteoporosis"),
}
d2_sources = {
    'Normal':       os.path.join(path2, "normal", "normal"),
    'Osteoporosis': os.path.join(path2, "osteoporosis", "osteoporosis"),
}

for cls in classes:
    dst_dirs = {s: os.path.join(merged_dir, s, cls) for s in splits}
    imgs_d1  = collect_images(d1_sources.get(cls, ""))
    imgs_d2  = collect_images(d2_sources.get(cls, ""))
    counts1  = split_and_copy(imgs_d1, dst_dirs, label_prefix="d1")
    counts2  = split_and_copy(imgs_d2, dst_dirs, label_prefix="d2")
    print(f"\n{cls}: {len(imgs_d1)} D1 + {len(imgs_d2)} D2 = {len(imgs_d1)+len(imgs_d2)}")

print("\nBalancing classes...")
for cls in classes:
    for split_name in splits:
        target    = targets[split_name]
        split_dir = os.path.join(merged_dir, split_name, cls)
        augment_to_exact(split_dir, target, label_prefix=f'aug_{cls[:3].lower()}')

print("\nFinal summary:")
for split in splits:
    print(f"\n{split}/")
    for cls in classes:
        n = len(os.listdir(os.path.join(merged_dir, split, cls)))
        print(f"  {cls}: {n}")
# Out:
# Old merged folder deleted.
#
# Normal: 780 D1 + 186 D2 = 966
#   WARNING: Not found:
#
# Osteopenia: 374 D1 + 0 D2 = 374
#
# Osteoporosis: 793 D1 + 186 D2 = 979
#
# Balancing classes...
#   Augmenting 280 → 724 (need 444)...
#   Done: 724 images
#   Augmenting 56 → 144 (need 88)...
#   Done: 144 images
#   Augmenting 38 → 98 (need 60)...
#   Done: 98 images
#   Trimmed 733 → 724
#   Trimmed 145 → 144
#   Trimmed 101 → 98
#
# Final summary:
#
# train/
#   Normal: 724
#   Osteopenia: 724
#   Osteoporosis: 724
#
# val/
#   Normal: 144
#   Osteopenia: 144
#   Osteoporosis: 144
#
# test/
#   Normal: 98
#   Osteopenia: 98
#   Osteoporosis: 98

# %%
train_dir = os.path.join(merged_dir, 'train')
val_dir   = os.path.join(merged_dir, 'val')
test_dir  = os.path.join(merged_dir, 'test')

def make_generators(preprocess_fn, batch_size=16):
    train_datagen = ImageDataGenerator(
        rotation_range=15,
        width_shift_range=0.1,
        height_shift_range=0.1,
        zoom_range=0.1,
        horizontal_flip=True,
        brightness_range=[0.85, 1.15],
        fill_mode='nearest',
        preprocessing_function=preprocess_fn
    )
    val_datagen  = ImageDataGenerator(preprocessing_function=preprocess_fn)
    test_datagen = ImageDataGenerator(preprocessing_function=preprocess_fn)

    train_gen = train_datagen.flow_from_directory(
        train_dir, target_size=(224, 224), batch_size=batch_size,
        classes=['Normal', 'Osteopenia', 'Osteoporosis'],
        class_mode='categorical', shuffle=True
    )
    val_gen = val_datagen.flow_from_directory(
        val_dir, target_size=(224, 224), batch_size=batch_size,
        classes=['Normal', 'Osteopenia', 'Osteoporosis'],
        class_mode='categorical', shuffle=False
    )
    test_gen = test_datagen.flow_from_directory(
        test_dir, target_size=(224, 224), batch_size=1,
        classes=['Normal', 'Osteopenia', 'Osteoporosis'],
        class_mode='categorical', shuffle=False
    )
    return train_gen, val_gen, test_gen

def build_model(backbone, preprocess_fn_name):
    inputs     = layers.Input(shape=(224, 224, 3))
    backbone.trainable = False
    x = backbone(inputs, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.5)(x)
    x = layers.Dense(512, activation='relu',
                     kernel_regularizer=tf.keras.regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.4)(x)
    x = layers.Dense(256, activation='relu',
                     kernel_regularizer=tf.keras.regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(3, activation='softmax')(x)
    return models.Model(inputs, outputs)

print("Helper functions ready.")
# Out:
# Helper functions ready.

# %%
print("=" * 50)
print("TRAINING MODEL 1: VGG-19")
print("=" * 50)

preprocess_vgg = tf.keras.applications.vgg19.preprocess_input
train_gen, val_gen, test_gen = make_generators(preprocess_vgg)

class_weights_array = compute_class_weight(
    class_weight='balanced',
    classes=np.array([0, 1, 2]),
    y=train_gen.classes
)
class_weights = dict(enumerate(class_weights_array))

# Build VGG-19
vgg_base = tf.keras.applications.VGG19(
    include_top=False, weights='imagenet', input_shape=(224, 224, 3))
model_vgg = build_model(vgg_base, 'vgg19')

# Stage 1
model_vgg.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss='categorical_crossentropy', metrics=['accuracy'])

cb_s1 = [
    EarlyStopping(monitor='val_loss', patience=8,
                  restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.3,
                      patience=3, min_lr=1e-7, verbose=1),
    ModelCheckpoint("vgg19_stage1.keras", monitor='val_accuracy',
                    save_best_only=True, verbose=1)
]
print("\nVGG-19 Stage 1...")
h_vgg1 = model_vgg.fit(train_gen, validation_data=val_gen,
                        epochs=20, callbacks=cb_s1,
                        class_weight=class_weights)

# Stage 2 — unfreeze block4 + block5
vgg_base.trainable = True
for layer in vgg_base.layers:
    layer.trainable = 'block5' in layer.name or 'block4' in layer.name

model_vgg.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=5e-6),
    loss='categorical_crossentropy', metrics=['accuracy'])

cb_s2 = [
    EarlyStopping(monitor='val_loss', patience=8,
                  restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.3,
                      patience=4, min_lr=1e-9, verbose=1),
    ModelCheckpoint("vgg19_best.keras", monitor='val_accuracy',
                    save_best_only=True, verbose=1)
]
print("\nVGG-19 Stage 2...")
h_vgg2 = model_vgg.fit(train_gen, validation_data=val_gen,
                        epochs=40, callbacks=cb_s2,
                        class_weight=class_weights)

print(f"\nVGG-19 Best Val Accuracy: {max(h_vgg2.history['val_accuracy']):.4f}")
# Out:
# ==================================================
# TRAINING MODEL 1: VGG-19
# ==================================================
# Found 2172 images belonging to 3 classes.
# Found 432 images belonging to 3 classes.
# Found 294 images belonging to 3 classes.
#
# VGG-19 Stage 1...
# Epoch 1/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 610ms/step - accuracy: 0.5511 - loss: 1.3359
# Epoch 1: val_accuracy improved from None to 0.73380, saving model to vgg19_stage1.keras
#
# Epoch 1: finished saving model to vgg19_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 102s 707ms/step - accuracy: 0.5898 - loss: 1.2194 - val_accuracy: 0.7338 - val_loss: 0.7485 - learning_rate: 0.0010
# Epoch 2/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 550ms/step - accuracy: 0.6809 - loss: 0.9090
# Epoch 2: val_accuracy did not improve from 0.73380
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 86s 633ms/step - accuracy: 0.6745 - loss: 0.9163 - val_accuracy: 0.7315 - val_loss: 0.7024 - learning_rate: 0.0010
# Epoch 3/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 551ms/step - accuracy: 0.6951 - loss: 0.8268
# Epoch 3: val_accuracy did not improve from 0.73380
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 86s 631ms/step - accuracy: 0.6957 - loss: 0.8231 - val_accuracy: 0.7130 - val_loss: 0.7453 - learning_rate: 0.0010
# Epoch 4/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 549ms/step - accuracy: 0.7088 - loss: 0.7502
# Epoch 4: val_accuracy improved from 0.73380 to 0.76157, saving model to vgg19_stage1.keras
#
# Epoch 4: finished saving model to vgg19_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 86s 637ms/step - accuracy: 0.6888 - loss: 0.7900 - val_accuracy: 0.7616 - val_loss: 0.6414 - learning_rate: 0.0010
# Epoch 5/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 548ms/step - accuracy: 0.7005 - loss: 0.7796
# Epoch 5: val_accuracy did not improve from 0.76157
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 86s 631ms/step - accuracy: 0.7081 - loss: 0.7763 - val_accuracy: 0.7546 - val_loss: 0.6377 - learning_rate: 0.0010
# Epoch 6/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 545ms/step - accuracy: 0.7241 - loss: 0.7250
# Epoch 6: val_accuracy improved from 0.76157 to 0.76620, saving model to vgg19_stage1.keras
#
# Epoch 6: finished saving model to vgg19_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 85s 627ms/step - accuracy: 0.7058 - loss: 0.7615 - val_accuracy: 0.7662 - val_loss: 0.6608 - learning_rate: 0.0010
# Epoch 7/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 543ms/step - accuracy: 0.7251 - loss: 0.7404
# Epoch 7: val_accuracy improved from 0.76620 to 0.78472, saving model to vgg19_stage1.keras
#
# Epoch 7: finished saving model to vgg19_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 85s 627ms/step - accuracy: 0.7261 - loss: 0.7492 - val_accuracy: 0.7847 - val_loss: 0.6339 - learning_rate: 0.0010
# Epoch 8/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - accuracy: 0.7802 - loss: 0.6410
# Epoch 8: val_accuracy did not improve from 0.78472
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 84s 621ms/step - accuracy: 0.7551 - loss: 0.6940 - val_accuracy: 0.7778 - val_loss: 0.6089 - learning_rate: 0.0010
# Epoch 9/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 543ms/step - accuracy: 0.7246 - loss: 0.7344
# Epoch 9: val_accuracy did not improve from 0.78472
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 84s 621ms/step - accuracy: 0.7224 - loss: 0.7284 - val_accuracy: 0.7708 - val_loss: 0.6199 - learning_rate: 0.0010
# Epoch 10/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - accuracy: 0.7461 - loss: 0.7028
# Epoch 10: val_accuracy did not improve from 0.78472
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 84s 617ms/step - accuracy: 0.7334 - loss: 0.7108 - val_accuracy: 0.7616 - val_loss: 0.6080 - learning_rate: 0.0010
# Epoch 11/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - accuracy: 0.7283 - loss: 0.7069
# Epoch 11: val_accuracy did not improve from 0.78472
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 83s 611ms/step - accuracy: 0.7325 - loss: 0.7058 - val_accuracy: 0.7778 - val_loss: 0.6115 - learning_rate: 0.0010
# Epoch 12/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 549ms/step - accuracy: 0.7530 - loss: 0.6588
# Epoch 12: val_accuracy did not improve from 0.78472
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 85s 626ms/step - accuracy: 0.7472 - loss: 0.6847 - val_accuracy: 0.7755 - val_loss: 0.5980 - learning_rate: 0.0010
# Epoch 13/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 538ms/step - accuracy: 0.7502 - loss: 0.6717
# Epoch 13: val_accuracy did not improve from 0.78472
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 84s 620ms/step - accuracy: 0.7449 - loss: 0.6855 - val_accuracy: 0.7755 - val_loss: 0.5973 - learning_rate: 0.0010
# Epoch 14/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - accuracy: 0.7563 - loss: 0.6660
# Epoch 14: val_accuracy did not improve from 0.78472
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 94s 694ms/step - accuracy: 0.7482 - loss: 0.6760 - val_accuracy: 0.7731 - val_loss: 0.6159 - learning_rate: 0.0010
# Epoch 15/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - accuracy: 0.7524 - loss: 0.6731
# Epoch 15: val_accuracy did not improve from 0.78472
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 85s 623ms/step - accuracy: 0.7532 - loss: 0.6769 - val_accuracy: 0.7616 - val_loss: 0.6625 - learning_rate: 0.0010
# Epoch 16/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 551ms/step - accuracy: 0.7617 - loss: 0.6647
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
#
# Epoch 16: val_accuracy did not improve from 0.78472
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 86s 633ms/step - accuracy: 0.7537 - loss: 0.6862 - val_accuracy: 0.7755 - val_loss: 0.6044 - learning_rate: 0.0010
# Epoch 17/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 545ms/step - accuracy: 0.7334 - loss: 0.6875
# Epoch 17: val_accuracy improved from 0.78472 to 0.79630, saving model to vgg19_stage1.keras
#
# Epoch 17: finished saving model to vgg19_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 85s 630ms/step - accuracy: 0.7440 - loss: 0.6666 - val_accuracy: 0.7963 - val_loss: 0.5834 - learning_rate: 3.0000e-04
# Epoch 18/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - accuracy: 0.7605 - loss: 0.6615
# Epoch 18: val_accuracy improved from 0.79630 to 0.80093, saving model to vgg19_stage1.keras
#
# Epoch 18: finished saving model to vgg19_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 85s 622ms/step - accuracy: 0.7615 - loss: 0.6558 - val_accuracy: 0.8009 - val_loss: 0.5785 - learning_rate: 3.0000e-04
# Epoch 19/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - accuracy: 0.7881 - loss: 0.6203
# Epoch 19: val_accuracy did not improve from 0.80093
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 84s 617ms/step - accuracy: 0.7707 - loss: 0.6511 - val_accuracy: 0.7894 - val_loss: 0.6016 - learning_rate: 3.0000e-04
# Epoch 20/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 546ms/step - accuracy: 0.7772 - loss: 0.6193
# Epoch 20: val_accuracy did not improve from 0.80093
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 84s 621ms/step - accuracy: 0.7698 - loss: 0.6518 - val_accuracy: 0.7963 - val_loss: 0.6049 - learning_rate: 3.0000e-04
# Restoring model weights from the end of the best epoch: 18.
#
# VGG-19 Stage 2...
# Epoch 1/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 654ms/step - accuracy: 0.7857 - loss: 0.6505
# Epoch 1: val_accuracy improved from None to 0.79630, saving model to vgg19_best.keras
#
# Epoch 1: finished saving model to vgg19_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 112s 754ms/step - accuracy: 0.7744 - loss: 0.6480 - val_accuracy: 0.7963 - val_loss: 0.5469 - learning_rate: 5.0000e-06
# Epoch 2/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 579ms/step - accuracy: 0.7555 - loss: 0.6610
# Epoch 2: val_accuracy did not improve from 0.79630
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 90s 661ms/step - accuracy: 0.7693 - loss: 0.6228 - val_accuracy: 0.7731 - val_loss: 0.6019 - learning_rate: 5.0000e-06
# Epoch 3/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 588ms/step - accuracy: 0.7716 - loss: 0.6124
# Epoch 3: val_accuracy improved from 0.79630 to 0.83102, saving model to vgg19_best.keras
#
# Epoch 3: finished saving model to vgg19_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 95s 699ms/step - accuracy: 0.7942 - loss: 0.5894 - val_accuracy: 0.8310 - val_loss: 0.5121 - learning_rate: 5.0000e-06
# Epoch 4/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 578ms/step - accuracy: 0.8120 - loss: 0.5544
# Epoch 4: val_accuracy improved from 0.83102 to 0.84028, saving model to vgg19_best.keras
#
# Epoch 4: finished saving model to vgg19_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 91s 665ms/step - accuracy: 0.7970 - loss: 0.5784 - val_accuracy: 0.8403 - val_loss: 0.5397 - learning_rate: 5.0000e-06
# Epoch 5/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 585ms/step - accuracy: 0.8014 - loss: 0.5697
# Epoch 5: val_accuracy did not improve from 0.84028
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 91s 667ms/step - accuracy: 0.8052 - loss: 0.5590 - val_accuracy: 0.8218 - val_loss: 0.5288 - learning_rate: 5.0000e-06
# Epoch 6/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 586ms/step - accuracy: 0.8058 - loss: 0.5705
# Epoch 6: val_accuracy did not improve from 0.84028
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 91s 665ms/step - accuracy: 0.8149 - loss: 0.5565 - val_accuracy: 0.7662 - val_loss: 0.6922 - learning_rate: 5.0000e-06
# Epoch 7/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 573ms/step - accuracy: 0.8157 - loss: 0.5328
# Epoch 7: ReduceLROnPlateau reducing learning rate to 1.4999999621068127e-06.
#
# Epoch 7: val_accuracy did not improve from 0.84028
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 99s 724ms/step - accuracy: 0.8241 - loss: 0.5318 - val_accuracy: 0.8148 - val_loss: 0.5730 - learning_rate: 5.0000e-06
# Epoch 8/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 582ms/step - accuracy: 0.8429 - loss: 0.5017
# Epoch 8: val_accuracy did not improve from 0.84028
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 91s 663ms/step - accuracy: 0.8260 - loss: 0.5200 - val_accuracy: 0.8333 - val_loss: 0.5358 - learning_rate: 1.5000e-06
# Epoch 9/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 588ms/step - accuracy: 0.8255 - loss: 0.5162
# Epoch 9: val_accuracy did not improve from 0.84028
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 91s 669ms/step - accuracy: 0.8306 - loss: 0.5163 - val_accuracy: 0.8310 - val_loss: 0.5457 - learning_rate: 1.5000e-06
# Epoch 10/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 578ms/step - accuracy: 0.8268 - loss: 0.5113
# Epoch 10: val_accuracy did not improve from 0.84028
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 90s 660ms/step - accuracy: 0.8200 - loss: 0.5150 - val_accuracy: 0.8380 - val_loss: 0.5594 - learning_rate: 1.5000e-06
# Epoch 11/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 570ms/step - accuracy: 0.8343 - loss: 0.5070
# Epoch 11: ReduceLROnPlateau reducing learning rate to 4.4999998181083353e-07.
#
# Epoch 11: val_accuracy did not improve from 0.84028
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 88s 649ms/step - accuracy: 0.8306 - loss: 0.5111 - val_accuracy: 0.8264 - val_loss: 0.5838 - learning_rate: 1.5000e-06
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 3.
#
# VGG-19 Best Val Accuracy: 0.8403

# %%
print("=" * 50)
print("TRAINING MODEL 2: ResNet50")
print("=" * 50)

preprocess_res = tf.keras.applications.resnet50.preprocess_input
train_gen_r, val_gen_r, test_gen_r = make_generators(preprocess_res)

res_base = tf.keras.applications.ResNet50(
    include_top=False, weights='imagenet', input_shape=(224, 224, 3))
model_res = build_model(res_base, 'resnet50')

# Stage 1
model_res.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss='categorical_crossentropy', metrics=['accuracy'])

cb_r1 = [
    EarlyStopping(monitor='val_loss', patience=8,
                  restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.3,
                      patience=3, min_lr=1e-7, verbose=1),
    ModelCheckpoint("resnet50_stage1.keras", monitor='val_accuracy',
                    save_best_only=True, verbose=1)
]
print("\nResNet50 Stage 1...")
h_res1 = model_res.fit(train_gen_r, validation_data=val_gen_r,
                        epochs=20, callbacks=cb_r1,
                        class_weight=class_weights)

# Stage 2 — unfreeze last 40 layers
res_base.trainable = True
for layer in res_base.layers[:-40]:
    layer.trainable = False

model_res.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=5e-6),
    loss='categorical_crossentropy', metrics=['accuracy'])

cb_r2 = [
    EarlyStopping(monitor='val_loss', patience=8,
                  restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.3,
                      patience=4, min_lr=1e-9, verbose=1),
    ModelCheckpoint("resnet50_best.keras", monitor='val_accuracy',
                    save_best_only=True, verbose=1)
]
print("\nResNet50 Stage 2...")
h_res2 = model_res.fit(train_gen_r, validation_data=val_gen_r,
                        epochs=40, callbacks=cb_r2,
                        class_weight=class_weights)

print(f"\nResNet50 Best Val Accuracy: {max(h_res2.history['val_accuracy']):.4f}")
# Out:
# ==================================================
# TRAINING MODEL 2: ResNet50
# ==================================================
# Found 2172 images belonging to 3 classes.
# Found 432 images belonging to 3 classes.
# Found 294 images belonging to 3 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
#
# ResNet50 Stage 1...
# Epoch 1/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 577ms/step - accuracy: 0.6255 - loss: 1.1785
# Epoch 1: val_accuracy improved from None to 0.71759, saving model to resnet50_stage1.keras
#
# Epoch 1: finished saving model to resnet50_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 111s 698ms/step - accuracy: 0.6634 - loss: 1.0797 - val_accuracy: 0.7176 - val_loss: 0.7719 - learning_rate: 0.0010
# Epoch 2/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 528ms/step - accuracy: 0.6887 - loss: 0.8967
# Epoch 2: val_accuracy improved from 0.71759 to 0.78009, saving model to resnet50_stage1.keras
#
# Epoch 2: finished saving model to resnet50_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 83s 611ms/step - accuracy: 0.7058 - loss: 0.8606 - val_accuracy: 0.7801 - val_loss: 0.6201 - learning_rate: 0.0010
# Epoch 3/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - accuracy: 0.7180 - loss: 0.8253
# Epoch 3: val_accuracy did not improve from 0.78009
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 590ms/step - accuracy: 0.7201 - loss: 0.8212 - val_accuracy: 0.7801 - val_loss: 0.6596 - learning_rate: 0.0010
# Epoch 4/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - accuracy: 0.7442 - loss: 0.7517
# Epoch 4: val_accuracy improved from 0.78009 to 0.79167, saving model to resnet50_stage1.keras
#
# Epoch 4: finished saving model to resnet50_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 83s 605ms/step - accuracy: 0.7449 - loss: 0.7548 - val_accuracy: 0.7917 - val_loss: 0.6654 - learning_rate: 0.0010
# Epoch 5/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - accuracy: 0.7671 - loss: 0.7191
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
#
# Epoch 5: val_accuracy improved from 0.79167 to 0.80556, saving model to resnet50_stage1.keras
#
# Epoch 5: finished saving model to resnet50_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 84s 618ms/step - accuracy: 0.7587 - loss: 0.7297 - val_accuracy: 0.8056 - val_loss: 0.6323 - learning_rate: 0.0010
# Epoch 6/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 530ms/step - accuracy: 0.7780 - loss: 0.6802
# Epoch 6: val_accuracy improved from 0.80556 to 0.81944, saving model to resnet50_stage1.keras
#
# Epoch 6: finished saving model to resnet50_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 83s 610ms/step - accuracy: 0.7643 - loss: 0.7040 - val_accuracy: 0.8194 - val_loss: 0.5819 - learning_rate: 3.0000e-04
# Epoch 7/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - accuracy: 0.7933 - loss: 0.6660
# Epoch 7: val_accuracy improved from 0.81944 to 0.82176, saving model to resnet50_stage1.keras
#
# Epoch 7: finished saving model to resnet50_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 82s 603ms/step - accuracy: 0.7850 - loss: 0.6670 - val_accuracy: 0.8218 - val_loss: 0.5735 - learning_rate: 3.0000e-04
# Epoch 8/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - accuracy: 0.7966 - loss: 0.6373
# Epoch 8: val_accuracy improved from 0.82176 to 0.82639, saving model to resnet50_stage1.keras
#
# Epoch 8: finished saving model to resnet50_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 593ms/step - accuracy: 0.7744 - loss: 0.6703 - val_accuracy: 0.8264 - val_loss: 0.5742 - learning_rate: 3.0000e-04
# Epoch 9/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - accuracy: 0.7750 - loss: 0.6704
# Epoch 9: val_accuracy did not improve from 0.82639
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 595ms/step - accuracy: 0.7818 - loss: 0.6557 - val_accuracy: 0.8056 - val_loss: 0.5883 - learning_rate: 3.0000e-04
# Epoch 10/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 528ms/step - accuracy: 0.7913 - loss: 0.6391
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
#
# Epoch 10: val_accuracy did not improve from 0.82639
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 598ms/step - accuracy: 0.7781 - loss: 0.6524 - val_accuracy: 0.8102 - val_loss: 0.5860 - learning_rate: 3.0000e-04
# Epoch 11/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 522ms/step - accuracy: 0.7965 - loss: 0.6353
# Epoch 11: val_accuracy did not improve from 0.82639
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 596ms/step - accuracy: 0.7914 - loss: 0.6354 - val_accuracy: 0.8241 - val_loss: 0.5766 - learning_rate: 9.0000e-05
# Epoch 12/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.7882 - loss: 0.6256
# Epoch 12: val_accuracy did not improve from 0.82639
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 586ms/step - accuracy: 0.7813 - loss: 0.6337 - val_accuracy: 0.8241 - val_loss: 0.5750 - learning_rate: 9.0000e-05
# Epoch 13/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 525ms/step - accuracy: 0.7983 - loss: 0.6147
# Epoch 13: val_accuracy did not improve from 0.82639
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 82s 602ms/step - accuracy: 0.7947 - loss: 0.6228 - val_accuracy: 0.8264 - val_loss: 0.5734 - learning_rate: 9.0000e-05
# Epoch 14/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - accuracy: 0.7968 - loss: 0.6202
# Epoch 14: val_accuracy did not improve from 0.82639
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 590ms/step - accuracy: 0.7947 - loss: 0.6230 - val_accuracy: 0.8194 - val_loss: 0.5768 - learning_rate: 9.0000e-05
# Epoch 15/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - accuracy: 0.7961 - loss: 0.6117
# Epoch 15: val_accuracy improved from 0.82639 to 0.83333, saving model to resnet50_stage1.keras
#
# Epoch 15: finished saving model to resnet50_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 82s 603ms/step - accuracy: 0.7910 - loss: 0.6244 - val_accuracy: 0.8333 - val_loss: 0.5571 - learning_rate: 9.0000e-05
# Epoch 16/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - accuracy: 0.8055 - loss: 0.6230
# Epoch 16: val_accuracy did not improve from 0.83333
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 584ms/step - accuracy: 0.7974 - loss: 0.6302 - val_accuracy: 0.8310 - val_loss: 0.5635 - learning_rate: 9.0000e-05
# Epoch 17/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - accuracy: 0.7959 - loss: 0.6121
# Epoch 17: val_accuracy did not improve from 0.83333
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 590ms/step - accuracy: 0.7841 - loss: 0.6295 - val_accuracy: 0.8241 - val_loss: 0.5602 - learning_rate: 9.0000e-05
# Epoch 18/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 526ms/step - accuracy: 0.7906 - loss: 0.6341
# Epoch 18: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
#
# Epoch 18: val_accuracy did not improve from 0.83333
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 599ms/step - accuracy: 0.7882 - loss: 0.6226 - val_accuracy: 0.8241 - val_loss: 0.5653 - learning_rate: 9.0000e-05
# Epoch 19/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 525ms/step - accuracy: 0.7899 - loss: 0.6202
# Epoch 19: val_accuracy did not improve from 0.83333
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 599ms/step - accuracy: 0.7924 - loss: 0.6110 - val_accuracy: 0.8241 - val_loss: 0.5584 - learning_rate: 2.7000e-05
# Epoch 20/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - accuracy: 0.7974 - loss: 0.6059
# Epoch 20: val_accuracy did not improve from 0.83333
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 593ms/step - accuracy: 0.7942 - loss: 0.6188 - val_accuracy: 0.8264 - val_loss: 0.5649 - learning_rate: 2.7000e-05
# Restoring model weights from the end of the best epoch: 15.
#
# ResNet50 Stage 2...
# Epoch 1/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 607ms/step - accuracy: 0.7506 - loss: 0.7166
# Epoch 1: val_accuracy improved from None to 0.81019, saving model to resnet50_best.keras
#
# Epoch 1: finished saving model to resnet50_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 126s 734ms/step - accuracy: 0.7555 - loss: 0.7169 - val_accuracy: 0.8102 - val_loss: 0.5982 - learning_rate: 5.0000e-06
# Epoch 2/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - accuracy: 0.7565 - loss: 0.7171
# Epoch 2: val_accuracy improved from 0.81019 to 0.81250, saving model to resnet50_best.keras
#
# Epoch 2: finished saving model to resnet50_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 83s 613ms/step - accuracy: 0.7735 - loss: 0.6789 - val_accuracy: 0.8125 - val_loss: 0.6088 - learning_rate: 5.0000e-06
# Epoch 3/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 527ms/step - accuracy: 0.7719 - loss: 0.6661
# Epoch 3: val_accuracy improved from 0.81250 to 0.81944, saving model to resnet50_best.keras
#
# Epoch 3: finished saving model to resnet50_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 89s 655ms/step - accuracy: 0.7762 - loss: 0.6614 - val_accuracy: 0.8194 - val_loss: 0.5839 - learning_rate: 5.0000e-06
# Epoch 4/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - accuracy: 0.7823 - loss: 0.6381
# Epoch 4: val_accuracy improved from 0.81944 to 0.82176, saving model to resnet50_best.keras
#
# Epoch 4: finished saving model to resnet50_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 88s 651ms/step - accuracy: 0.7841 - loss: 0.6442 - val_accuracy: 0.8218 - val_loss: 0.5843 - learning_rate: 5.0000e-06
# Epoch 5/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - accuracy: 0.7999 - loss: 0.6197
# Epoch 5: val_accuracy did not improve from 0.82176
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 594ms/step - accuracy: 0.8029 - loss: 0.6171 - val_accuracy: 0.8171 - val_loss: 0.5850 - learning_rate: 5.0000e-06
# Epoch 6/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - accuracy: 0.8036 - loss: 0.6032
# Epoch 6: val_accuracy did not improve from 0.82176
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 592ms/step - accuracy: 0.7988 - loss: 0.6101 - val_accuracy: 0.8148 - val_loss: 0.5896 - learning_rate: 5.0000e-06
# Epoch 7/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 527ms/step - accuracy: 0.8150 - loss: 0.5536
# Epoch 7: val_accuracy did not improve from 0.82176
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 598ms/step - accuracy: 0.7997 - loss: 0.5902 - val_accuracy: 0.8218 - val_loss: 0.5822 - learning_rate: 5.0000e-06
# Epoch 8/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - accuracy: 0.7947 - loss: 0.6193
# Epoch 8: val_accuracy did not improve from 0.82176
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 83s 607ms/step - accuracy: 0.7997 - loss: 0.6036 - val_accuracy: 0.8194 - val_loss: 0.5793 - learning_rate: 5.0000e-06
# Epoch 9/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - accuracy: 0.7973 - loss: 0.5952
# Epoch 9: val_accuracy improved from 0.82176 to 0.82407, saving model to resnet50_best.keras
#
# Epoch 9: finished saving model to resnet50_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 90s 662ms/step - accuracy: 0.8085 - loss: 0.5941 - val_accuracy: 0.8241 - val_loss: 0.5640 - learning_rate: 5.0000e-06
# Epoch 10/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 526ms/step - accuracy: 0.8200 - loss: 0.5537
# Epoch 10: val_accuracy did not improve from 0.82407
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 598ms/step - accuracy: 0.8089 - loss: 0.5762 - val_accuracy: 0.8241 - val_loss: 0.5729 - learning_rate: 5.0000e-06
# Epoch 11/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 525ms/step - accuracy: 0.8264 - loss: 0.5536
# Epoch 11: val_accuracy improved from 0.82407 to 0.82870, saving model to resnet50_best.keras
#
# Epoch 11: finished saving model to resnet50_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 87s 642ms/step - accuracy: 0.8195 - loss: 0.5691 - val_accuracy: 0.8287 - val_loss: 0.5624 - learning_rate: 5.0000e-06
# Epoch 12/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 530ms/step - accuracy: 0.8263 - loss: 0.5551
# Epoch 12: val_accuracy improved from 0.82870 to 0.83565, saving model to resnet50_best.keras
#
# Epoch 12: finished saving model to resnet50_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 88s 645ms/step - accuracy: 0.8191 - loss: 0.5726 - val_accuracy: 0.8356 - val_loss: 0.5621 - learning_rate: 5.0000e-06
# Epoch 13/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 551ms/step - accuracy: 0.8227 - loss: 0.5371
# Epoch 13: val_accuracy did not improve from 0.83565
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 86s 630ms/step - accuracy: 0.8264 - loss: 0.5372 - val_accuracy: 0.8356 - val_loss: 0.5576 - learning_rate: 5.0000e-06
# Epoch 14/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - accuracy: 0.8311 - loss: 0.5422
# Epoch 14: val_accuracy did not improve from 0.83565
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 83s 609ms/step - accuracy: 0.8191 - loss: 0.5571 - val_accuracy: 0.8356 - val_loss: 0.5510 - learning_rate: 5.0000e-06
# Epoch 15/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - accuracy: 0.8338 - loss: 0.5460
# Epoch 15: val_accuracy did not improve from 0.83565
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 143s 617ms/step - accuracy: 0.8361 - loss: 0.5452 - val_accuracy: 0.8333 - val_loss: 0.5485 - learning_rate: 5.0000e-06
# Epoch 16/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 537ms/step - accuracy: 0.8355 - loss: 0.5555
# Epoch 16: val_accuracy did not improve from 0.83565
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 83s 607ms/step - accuracy: 0.8278 - loss: 0.5472 - val_accuracy: 0.8333 - val_loss: 0.5694 - learning_rate: 5.0000e-06
# Epoch 17/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 538ms/step - accuracy: 0.8337 - loss: 0.5399
# Epoch 17: val_accuracy did not improve from 0.83565
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 84s 616ms/step - accuracy: 0.8407 - loss: 0.5336 - val_accuracy: 0.8287 - val_loss: 0.5490 - learning_rate: 5.0000e-06
# Epoch 18/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - accuracy: 0.8289 - loss: 0.5360
# Epoch 18: val_accuracy did not improve from 0.83565
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 84s 615ms/step - accuracy: 0.8273 - loss: 0.5518 - val_accuracy: 0.8287 - val_loss: 0.5581 - learning_rate: 5.0000e-06
# Epoch 19/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - accuracy: 0.8318 - loss: 0.5218
# Epoch 19: val_accuracy improved from 0.83565 to 0.84259, saving model to resnet50_best.keras
#
# Epoch 19: finished saving model to resnet50_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 89s 654ms/step - accuracy: 0.8402 - loss: 0.5261 - val_accuracy: 0.8426 - val_loss: 0.5443 - learning_rate: 5.0000e-06
# Epoch 20/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 538ms/step - accuracy: 0.8315 - loss: 0.5274
# Epoch 20: val_accuracy did not improve from 0.84259
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 83s 612ms/step - accuracy: 0.8370 - loss: 0.5172 - val_accuracy: 0.8426 - val_loss: 0.5418 - learning_rate: 5.0000e-06
# Epoch 21/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - accuracy: 0.8459 - loss: 0.5069
# Epoch 21: val_accuracy did not improve from 0.84259
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 84s 618ms/step - accuracy: 0.8430 - loss: 0.5120 - val_accuracy: 0.8380 - val_loss: 0.5420 - learning_rate: 5.0000e-06
# Epoch 22/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 546ms/step - accuracy: 0.8239 - loss: 0.5461
# Epoch 22: val_accuracy improved from 0.84259 to 0.84954, saving model to resnet50_best.keras
#
# Epoch 22: finished saving model to resnet50_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 91s 668ms/step - accuracy: 0.8333 - loss: 0.5144 - val_accuracy: 0.8495 - val_loss: 0.5369 - learning_rate: 5.0000e-06
# Epoch 23/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - accuracy: 0.8544 - loss: 0.4804
# Epoch 23: val_accuracy did not improve from 0.84954
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 83s 604ms/step - accuracy: 0.8444 - loss: 0.5058 - val_accuracy: 0.8449 - val_loss: 0.5397 - learning_rate: 5.0000e-06
# Epoch 24/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 537ms/step - accuracy: 0.8502 - loss: 0.4889
# Epoch 24: val_accuracy did not improve from 0.84954
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 83s 611ms/step - accuracy: 0.8527 - loss: 0.4975 - val_accuracy: 0.8356 - val_loss: 0.5349 - learning_rate: 5.0000e-06
# Epoch 25/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 548ms/step - accuracy: 0.8414 - loss: 0.5069
# Epoch 25: val_accuracy improved from 0.84954 to 0.85185, saving model to resnet50_best.keras
#
# Epoch 25: finished saving model to resnet50_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 86s 635ms/step - accuracy: 0.8448 - loss: 0.5104 - val_accuracy: 0.8519 - val_loss: 0.5174 - learning_rate: 5.0000e-06
# Epoch 26/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - accuracy: 0.8472 - loss: 0.5124
# Epoch 26: val_accuracy did not improve from 0.85185
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 84s 619ms/step - accuracy: 0.8430 - loss: 0.5032 - val_accuracy: 0.8519 - val_loss: 0.5258 - learning_rate: 5.0000e-06
# Epoch 27/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 543ms/step - accuracy: 0.8435 - loss: 0.5059
# Epoch 27: val_accuracy improved from 0.85185 to 0.85648, saving model to resnet50_best.keras
#
# Epoch 27: finished saving model to resnet50_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 90s 662ms/step - accuracy: 0.8564 - loss: 0.4818 - val_accuracy: 0.8565 - val_loss: 0.5274 - learning_rate: 5.0000e-06
# Epoch 28/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - accuracy: 0.8411 - loss: 0.4782
# Epoch 28: val_accuracy did not improve from 0.85648
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 84s 618ms/step - accuracy: 0.8481 - loss: 0.4732 - val_accuracy: 0.8519 - val_loss: 0.5268 - learning_rate: 5.0000e-06
# Epoch 29/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - accuracy: 0.8527 - loss: 0.4744
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.4999999621068127e-06.
#
# Epoch 29: val_accuracy did not improve from 0.85648
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 83s 610ms/step - accuracy: 0.8550 - loss: 0.4805 - val_accuracy: 0.8565 - val_loss: 0.5254 - learning_rate: 5.0000e-06
# Epoch 30/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - accuracy: 0.8694 - loss: 0.4650
# Epoch 30: val_accuracy did not improve from 0.85648
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 83s 609ms/step - accuracy: 0.8633 - loss: 0.4726 - val_accuracy: 0.8542 - val_loss: 0.5192 - learning_rate: 1.5000e-06
# Epoch 31/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 530ms/step - accuracy: 0.8746 - loss: 0.4562
# Epoch 31: val_accuracy improved from 0.85648 to 0.86111, saving model to resnet50_best.keras
#
# Epoch 31: finished saving model to resnet50_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 84s 615ms/step - accuracy: 0.8633 - loss: 0.4648 - val_accuracy: 0.8611 - val_loss: 0.5128 - learning_rate: 1.5000e-06
# Epoch 32/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - accuracy: 0.8618 - loss: 0.4813
# Epoch 32: val_accuracy did not improve from 0.86111
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 82s 605ms/step - accuracy: 0.8623 - loss: 0.4849 - val_accuracy: 0.8542 - val_loss: 0.5248 - learning_rate: 1.5000e-06
# Epoch 33/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 526ms/step - accuracy: 0.8802 - loss: 0.4439
# Epoch 33: val_accuracy did not improve from 0.86111
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 599ms/step - accuracy: 0.8697 - loss: 0.4591 - val_accuracy: 0.8565 - val_loss: 0.5187 - learning_rate: 1.5000e-06
# Epoch 34/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 528ms/step - accuracy: 0.8496 - loss: 0.4886
# Epoch 34: val_accuracy did not improve from 0.86111
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 82s 603ms/step - accuracy: 0.8499 - loss: 0.4914 - val_accuracy: 0.8495 - val_loss: 0.5150 - learning_rate: 1.5000e-06
# Epoch 35/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - accuracy: 0.8730 - loss: 0.4544
# Epoch 35: ReduceLROnPlateau reducing learning rate to 4.4999998181083353e-07.
#
# Epoch 35: val_accuracy did not improve from 0.86111
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 600ms/step - accuracy: 0.8665 - loss: 0.4684 - val_accuracy: 0.8519 - val_loss: 0.5140 - learning_rate: 1.5000e-06
# Epoch 36/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - accuracy: 0.8723 - loss: 0.4319
# Epoch 36: val_accuracy did not improve from 0.86111
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 83s 611ms/step - accuracy: 0.8669 - loss: 0.4428 - val_accuracy: 0.8588 - val_loss: 0.5132 - learning_rate: 4.5000e-07
# Epoch 37/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 543ms/step - accuracy: 0.8623 - loss: 0.4605
# Epoch 37: val_accuracy did not improve from 0.86111
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 84s 620ms/step - accuracy: 0.8605 - loss: 0.4606 - val_accuracy: 0.8542 - val_loss: 0.5121 - learning_rate: 4.5000e-07
# Epoch 38/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - accuracy: 0.8628 - loss: 0.4548
# Epoch 38: val_accuracy did not improve from 0.86111
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 83s 607ms/step - accuracy: 0.8642 - loss: 0.4586 - val_accuracy: 0.8542 - val_loss: 0.5087 - learning_rate: 4.5000e-07
# Epoch 39/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - accuracy: 0.8636 - loss: 0.4709
# Epoch 39: val_accuracy did not improve from 0.86111
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 83s 609ms/step - accuracy: 0.8683 - loss: 0.4636 - val_accuracy: 0.8565 - val_loss: 0.5111 - learning_rate: 4.5000e-07
# Epoch 40/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 524ms/step - accuracy: 0.8736 - loss: 0.4329
# Epoch 40: val_accuracy did not improve from 0.86111
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 596ms/step - accuracy: 0.8646 - loss: 0.4557 - val_accuracy: 0.8542 - val_loss: 0.5123 - learning_rate: 4.5000e-07
# Restoring model weights from the end of the best epoch: 38.
#
# ResNet50 Best Val Accuracy: 0.8611

# %%
print("=" * 50)
print("TRAINING MODEL 3: EfficientNetB0")
print("=" * 50)

preprocess_eff = tf.keras.applications.efficientnet.preprocess_input
train_gen_e, val_gen_e, test_gen_e = make_generators(preprocess_eff)

eff_base = tf.keras.applications.EfficientNetB0(
    include_top=False, weights='imagenet', input_shape=(224, 224, 3))
model_eff = build_model(eff_base, 'efficientnet')

# Stage 1
model_eff.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss='categorical_crossentropy', metrics=['accuracy'])

cb_e1 = [
    EarlyStopping(monitor='val_loss', patience=8,
                  restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.3,
                      patience=3, min_lr=1e-7, verbose=1),
    ModelCheckpoint("effnet_stage1.keras", monitor='val_accuracy',
                    save_best_only=True, verbose=1)
]
print("\nEfficientNetB0 Stage 1...")
h_eff1 = model_eff.fit(train_gen_e, validation_data=val_gen_e,
                        epochs=20, callbacks=cb_e1,
                        class_weight=class_weights)

# Stage 2 — unfreeze top 30%
eff_base.trainable = True
freeze_until = int(len(eff_base.layers) * 0.7)
for layer in eff_base.layers[:freeze_until]:
    layer.trainable = False

model_eff.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=5e-6),
    loss='categorical_crossentropy', metrics=['accuracy'])

cb_e2 = [
    EarlyStopping(monitor='val_loss', patience=8,
                  restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.3,
                      patience=4, min_lr=1e-9, verbose=1),
    ModelCheckpoint("effnet_best.keras", monitor='val_accuracy',
                    save_best_only=True, verbose=1)
]
print("\nEfficientNetB0 Stage 2...")
h_eff2 = model_eff.fit(train_gen_e, validation_data=val_gen_e,
                        epochs=40, callbacks=cb_e2,
                        class_weight=class_weights)

print(f"\nEfficientNetB0 Best Val Accuracy: {max(h_eff2.history['val_accuracy']):.4f}")
# Out:
# ==================================================
# TRAINING MODEL 3: EfficientNetB0
# ==================================================
# Found 2172 images belonging to 3 classes.
# Found 432 images belonging to 3 classes.
# Found 294 images belonging to 3 classes.
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
# EfficientNetB0 Stage 1...
# Epoch 1/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 643ms/step - accuracy: 0.5755 - loss: 1.2455
# Epoch 1: val_accuracy improved from None to 0.67361, saving model to effnet_stage1.keras
#
# Epoch 1: finished saving model to effnet_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 138s 777ms/step - accuracy: 0.6423 - loss: 1.0574 - val_accuracy: 0.6736 - val_loss: 0.7772 - learning_rate: 0.0010
# Epoch 2/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - accuracy: 0.6931 - loss: 0.8907
# Epoch 2: val_accuracy improved from 0.67361 to 0.76157, saving model to effnet_stage1.keras
#
# Epoch 2: finished saving model to effnet_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 584ms/step - accuracy: 0.7040 - loss: 0.8605 - val_accuracy: 0.7616 - val_loss: 0.6774 - learning_rate: 0.0010
# Epoch 3/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step - accuracy: 0.7051 - loss: 0.8177
# Epoch 3: val_accuracy improved from 0.76157 to 0.76852, saving model to effnet_stage1.keras
#
# Epoch 3: finished saving model to effnet_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 78s 573ms/step - accuracy: 0.7127 - loss: 0.7953 - val_accuracy: 0.7685 - val_loss: 0.6715 - learning_rate: 0.0010
# Epoch 4/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - accuracy: 0.7338 - loss: 0.7666
# Epoch 4: val_accuracy did not improve from 0.76852
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 588ms/step - accuracy: 0.7219 - loss: 0.7744 - val_accuracy: 0.7593 - val_loss: 0.7098 - learning_rate: 0.0010
# Epoch 5/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - accuracy: 0.7626 - loss: 0.7280
# Epoch 5: val_accuracy did not improve from 0.76852
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 79s 580ms/step - accuracy: 0.7472 - loss: 0.7476 - val_accuracy: 0.7523 - val_loss: 0.6580 - learning_rate: 0.0010
# Epoch 6/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 508ms/step - accuracy: 0.7555 - loss: 0.7193
# Epoch 6: val_accuracy improved from 0.76852 to 0.77083, saving model to effnet_stage1.keras
#
# Epoch 6: finished saving model to effnet_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 586ms/step - accuracy: 0.7597 - loss: 0.7161 - val_accuracy: 0.7708 - val_loss: 0.6298 - learning_rate: 0.0010
# Epoch 7/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step - accuracy: 0.7612 - loss: 0.6741
# Epoch 7: val_accuracy improved from 0.77083 to 0.78935, saving model to effnet_stage1.keras
#
# Epoch 7: finished saving model to effnet_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 78s 575ms/step - accuracy: 0.7657 - loss: 0.6841 - val_accuracy: 0.7894 - val_loss: 0.6253 - learning_rate: 0.0010
# Epoch 8/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.7473 - loss: 0.6885
# Epoch 8: val_accuracy did not improve from 0.78935
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 586ms/step - accuracy: 0.7505 - loss: 0.6911 - val_accuracy: 0.7639 - val_loss: 0.6757 - learning_rate: 0.0010
# Epoch 9/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step - accuracy: 0.7569 - loss: 0.7024
# Epoch 9: val_accuracy did not improve from 0.78935
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 77s 567ms/step - accuracy: 0.7680 - loss: 0.6683 - val_accuracy: 0.7894 - val_loss: 0.6601 - learning_rate: 0.0010
# Epoch 10/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step - accuracy: 0.7645 - loss: 0.6665
# Epoch 10: val_accuracy improved from 0.78935 to 0.80787, saving model to effnet_stage1.keras
#
# Epoch 10: finished saving model to effnet_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 77s 562ms/step - accuracy: 0.7749 - loss: 0.6594 - val_accuracy: 0.8079 - val_loss: 0.5996 - learning_rate: 0.0010
# Epoch 11/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - accuracy: 0.7562 - loss: 0.6648
# Epoch 11: val_accuracy did not improve from 0.80787
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 79s 582ms/step - accuracy: 0.7624 - loss: 0.6724 - val_accuracy: 0.7801 - val_loss: 0.6514 - learning_rate: 0.0010
# Epoch 12/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 503ms/step - accuracy: 0.7545 - loss: 0.6649
# Epoch 12: val_accuracy did not improve from 0.80787
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 78s 573ms/step - accuracy: 0.7574 - loss: 0.6772 - val_accuracy: 0.7708 - val_loss: 0.6340 - learning_rate: 0.0010
# Epoch 13/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - accuracy: 0.7955 - loss: 0.6340
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
#
# Epoch 13: val_accuracy did not improve from 0.80787
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 79s 580ms/step - accuracy: 0.7790 - loss: 0.6434 - val_accuracy: 0.7454 - val_loss: 0.6124 - learning_rate: 0.0010
# Epoch 14/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 502ms/step - accuracy: 0.7930 - loss: 0.6284
# Epoch 14: val_accuracy did not improve from 0.80787
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 78s 572ms/step - accuracy: 0.7818 - loss: 0.6420 - val_accuracy: 0.7894 - val_loss: 0.6022 - learning_rate: 3.0000e-04
# Epoch 15/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step - accuracy: 0.7920 - loss: 0.6064
# Epoch 15: val_accuracy did not improve from 0.80787
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 77s 567ms/step - accuracy: 0.7781 - loss: 0.6293 - val_accuracy: 0.7755 - val_loss: 0.6164 - learning_rate: 3.0000e-04
# Epoch 16/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - accuracy: 0.8022 - loss: 0.5915
# Epoch 16: val_accuracy did not improve from 0.80787
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 79s 585ms/step - accuracy: 0.7983 - loss: 0.5825 - val_accuracy: 0.8032 - val_loss: 0.5856 - learning_rate: 3.0000e-04
# Epoch 17/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step - accuracy: 0.7815 - loss: 0.6157
# Epoch 17: val_accuracy did not improve from 0.80787
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 78s 575ms/step - accuracy: 0.7836 - loss: 0.6169 - val_accuracy: 0.7940 - val_loss: 0.5858 - learning_rate: 3.0000e-04
# Epoch 18/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - accuracy: 0.7838 - loss: 0.6094
# Epoch 18: val_accuracy did not improve from 0.80787
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 586ms/step - accuracy: 0.7873 - loss: 0.6013 - val_accuracy: 0.7986 - val_loss: 0.5920 - learning_rate: 3.0000e-04
# Epoch 19/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step - accuracy: 0.7818 - loss: 0.6046
# Epoch 19: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
#
# Epoch 19: val_accuracy did not improve from 0.80787
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 78s 570ms/step - accuracy: 0.7785 - loss: 0.6068 - val_accuracy: 0.7986 - val_loss: 0.5942 - learning_rate: 3.0000e-04
# Epoch 20/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.8117 - loss: 0.5957
# Epoch 20: val_accuracy did not improve from 0.80787
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 78s 574ms/step - accuracy: 0.8112 - loss: 0.5765 - val_accuracy: 0.7940 - val_loss: 0.5807 - learning_rate: 9.0000e-05
# Restoring model weights from the end of the best epoch: 20.
#
# EfficientNetB0 Stage 2...
# Epoch 1/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 655ms/step - accuracy: 0.7091 - loss: 0.8347
# Epoch 1: val_accuracy improved from None to 0.77083, saving model to effnet_best.keras
#
# Epoch 1: finished saving model to effnet_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 148s 791ms/step - accuracy: 0.6961 - loss: 0.8450 - val_accuracy: 0.7708 - val_loss: 0.6900 - learning_rate: 5.0000e-06
# Epoch 2/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - accuracy: 0.7011 - loss: 0.8090
# Epoch 2: val_accuracy did not improve from 0.77083
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 589ms/step - accuracy: 0.7090 - loss: 0.8138 - val_accuracy: 0.7685 - val_loss: 0.6949 - learning_rate: 5.0000e-06
# Epoch 3/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.7211 - loss: 0.7613
# Epoch 3: val_accuracy improved from 0.77083 to 0.77546, saving model to effnet_best.keras
#
# Epoch 3: finished saving model to effnet_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 593ms/step - accuracy: 0.7228 - loss: 0.7629 - val_accuracy: 0.7755 - val_loss: 0.6829 - learning_rate: 5.0000e-06
# Epoch 4/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 510ms/step - accuracy: 0.7329 - loss: 0.7771
# Epoch 4: val_accuracy improved from 0.77546 to 0.77778, saving model to effnet_best.keras
#
# Epoch 4: finished saving model to effnet_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 593ms/step - accuracy: 0.7270 - loss: 0.7641 - val_accuracy: 0.7778 - val_loss: 0.6775 - learning_rate: 5.0000e-06
# Epoch 5/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - accuracy: 0.7570 - loss: 0.6803
# Epoch 5: val_accuracy improved from 0.77778 to 0.78241, saving model to effnet_best.keras
#
# Epoch 5: finished saving model to effnet_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 83s 607ms/step - accuracy: 0.7551 - loss: 0.6985 - val_accuracy: 0.7824 - val_loss: 0.6675 - learning_rate: 5.0000e-06
# Epoch 6/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 526ms/step - accuracy: 0.7306 - loss: 0.7620
# Epoch 6: val_accuracy did not improve from 0.78241
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 597ms/step - accuracy: 0.7472 - loss: 0.7331 - val_accuracy: 0.7824 - val_loss: 0.6545 - learning_rate: 5.0000e-06
# Epoch 7/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - accuracy: 0.7516 - loss: 0.7021
# Epoch 7: val_accuracy did not improve from 0.78241
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 78s 576ms/step - accuracy: 0.7564 - loss: 0.7049 - val_accuracy: 0.7801 - val_loss: 0.6544 - learning_rate: 5.0000e-06
# Epoch 8/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - accuracy: 0.7487 - loss: 0.7048
# Epoch 8: val_accuracy did not improve from 0.78241
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 586ms/step - accuracy: 0.7546 - loss: 0.6994 - val_accuracy: 0.7824 - val_loss: 0.6497 - learning_rate: 5.0000e-06
# Epoch 9/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 530ms/step - accuracy: 0.7456 - loss: 0.7143
# Epoch 9: val_accuracy improved from 0.78241 to 0.78472, saving model to effnet_best.keras
#
# Epoch 9: finished saving model to effnet_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 83s 608ms/step - accuracy: 0.7551 - loss: 0.7036 - val_accuracy: 0.7847 - val_loss: 0.6448 - learning_rate: 5.0000e-06
# Epoch 10/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - accuracy: 0.7355 - loss: 0.7231
# Epoch 10: val_accuracy did not improve from 0.78472
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 598ms/step - accuracy: 0.7403 - loss: 0.7020 - val_accuracy: 0.7824 - val_loss: 0.6369 - learning_rate: 5.0000e-06
# Epoch 11/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 504ms/step - accuracy: 0.7822 - loss: 0.6437
# Epoch 11: val_accuracy did not improve from 0.78472
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 78s 573ms/step - accuracy: 0.7592 - loss: 0.6879 - val_accuracy: 0.7778 - val_loss: 0.6414 - learning_rate: 5.0000e-06
# Epoch 12/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 510ms/step - accuracy: 0.7574 - loss: 0.7066
# Epoch 12: val_accuracy improved from 0.78472 to 0.78704, saving model to effnet_best.keras
#
# Epoch 12: finished saving model to effnet_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 592ms/step - accuracy: 0.7597 - loss: 0.6984 - val_accuracy: 0.7870 - val_loss: 0.6316 - learning_rate: 5.0000e-06
# Epoch 13/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 524ms/step - accuracy: 0.7622 - loss: 0.6613
# Epoch 13: val_accuracy did not improve from 0.78704
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 587ms/step - accuracy: 0.7537 - loss: 0.6867 - val_accuracy: 0.7847 - val_loss: 0.6342 - learning_rate: 5.0000e-06
# Epoch 14/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step - accuracy: 0.7566 - loss: 0.6859
# Epoch 14: val_accuracy improved from 0.78704 to 0.78935, saving model to effnet_best.keras
#
# Epoch 14: finished saving model to effnet_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 78s 576ms/step - accuracy: 0.7629 - loss: 0.6747 - val_accuracy: 0.7894 - val_loss: 0.6255 - learning_rate: 5.0000e-06
# Epoch 15/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step - accuracy: 0.7801 - loss: 0.6456
# Epoch 15: val_accuracy did not improve from 0.78935
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 77s 564ms/step - accuracy: 0.7735 - loss: 0.6555 - val_accuracy: 0.7824 - val_loss: 0.6272 - learning_rate: 5.0000e-06
# Epoch 16/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - accuracy: 0.7713 - loss: 0.6636
# Epoch 16: val_accuracy improved from 0.78935 to 0.79167, saving model to effnet_best.keras
#
# Epoch 16: finished saving model to effnet_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 83s 611ms/step - accuracy: 0.7670 - loss: 0.6579 - val_accuracy: 0.7917 - val_loss: 0.6187 - learning_rate: 5.0000e-06
# Epoch 17/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - accuracy: 0.7715 - loss: 0.6353
# Epoch 17: val_accuracy improved from 0.79167 to 0.79630, saving model to effnet_best.keras
#
# Epoch 17: finished saving model to effnet_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 586ms/step - accuracy: 0.7739 - loss: 0.6489 - val_accuracy: 0.7963 - val_loss: 0.6166 - learning_rate: 5.0000e-06
# Epoch 18/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - accuracy: 0.7614 - loss: 0.6710
# Epoch 18: val_accuracy improved from 0.79630 to 0.80324, saving model to effnet_best.keras
#
# Epoch 18: finished saving model to effnet_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 587ms/step - accuracy: 0.7703 - loss: 0.6487 - val_accuracy: 0.8032 - val_loss: 0.6132 - learning_rate: 5.0000e-06
# Epoch 19/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step - accuracy: 0.7870 - loss: 0.6197
# Epoch 19: val_accuracy did not improve from 0.80324
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 78s 571ms/step - accuracy: 0.7684 - loss: 0.6638 - val_accuracy: 0.8032 - val_loss: 0.6122 - learning_rate: 5.0000e-06
# Epoch 20/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 510ms/step - accuracy: 0.7786 - loss: 0.6385
# Epoch 20: val_accuracy did not improve from 0.80324
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 79s 580ms/step - accuracy: 0.7776 - loss: 0.6411 - val_accuracy: 0.7986 - val_loss: 0.6093 - learning_rate: 5.0000e-06
# Epoch 21/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - accuracy: 0.7729 - loss: 0.6351
# Epoch 21: val_accuracy did not improve from 0.80324
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 590ms/step - accuracy: 0.7822 - loss: 0.6165 - val_accuracy: 0.8032 - val_loss: 0.6064 - learning_rate: 5.0000e-06
# Epoch 22/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - accuracy: 0.7913 - loss: 0.6148
# Epoch 22: val_accuracy did not improve from 0.80324
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 589ms/step - accuracy: 0.7859 - loss: 0.6263 - val_accuracy: 0.8032 - val_loss: 0.6002 - learning_rate: 5.0000e-06
# Epoch 23/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - accuracy: 0.7684 - loss: 0.6372
# Epoch 23: val_accuracy improved from 0.80324 to 0.80556, saving model to effnet_best.keras
#
# Epoch 23: finished saving model to effnet_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 587ms/step - accuracy: 0.7785 - loss: 0.6289 - val_accuracy: 0.8056 - val_loss: 0.5994 - learning_rate: 5.0000e-06
# Epoch 24/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - accuracy: 0.7977 - loss: 0.6159
# Epoch 24: val_accuracy did not improve from 0.80556
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 586ms/step - accuracy: 0.7841 - loss: 0.6296 - val_accuracy: 0.8032 - val_loss: 0.5971 - learning_rate: 5.0000e-06
# Epoch 25/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step - accuracy: 0.7742 - loss: 0.6352
# Epoch 25: val_accuracy did not improve from 0.80556
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 77s 570ms/step - accuracy: 0.7891 - loss: 0.6151 - val_accuracy: 0.8056 - val_loss: 0.5940 - learning_rate: 5.0000e-06
# Epoch 26/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - accuracy: 0.7916 - loss: 0.6074
# Epoch 26: val_accuracy improved from 0.80556 to 0.80787, saving model to effnet_best.keras
#
# Epoch 26: finished saving model to effnet_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 85s 627ms/step - accuracy: 0.7937 - loss: 0.5989 - val_accuracy: 0.8079 - val_loss: 0.5930 - learning_rate: 5.0000e-06
# Epoch 27/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 552ms/step - accuracy: 0.7898 - loss: 0.5963
# Epoch 27: val_accuracy improved from 0.80787 to 0.81019, saving model to effnet_best.keras
#
# Epoch 27: finished saving model to effnet_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 86s 633ms/step - accuracy: 0.7901 - loss: 0.6022 - val_accuracy: 0.8102 - val_loss: 0.5896 - learning_rate: 5.0000e-06
# Epoch 28/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 525ms/step - accuracy: 0.7893 - loss: 0.6038
# Epoch 28: val_accuracy did not improve from 0.81019
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 595ms/step - accuracy: 0.7804 - loss: 0.6242 - val_accuracy: 0.8079 - val_loss: 0.5908 - learning_rate: 5.0000e-06
# Epoch 29/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step - accuracy: 0.7928 - loss: 0.5887
# Epoch 29: val_accuracy did not improve from 0.81019
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 77s 569ms/step - accuracy: 0.7822 - loss: 0.6296 - val_accuracy: 0.8079 - val_loss: 0.5848 - learning_rate: 5.0000e-06
# Epoch 30/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - accuracy: 0.7959 - loss: 0.6012
# Epoch 30: val_accuracy did not improve from 0.81019
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 79s 586ms/step - accuracy: 0.7901 - loss: 0.6028 - val_accuracy: 0.8056 - val_loss: 0.5881 - learning_rate: 5.0000e-06
# Epoch 31/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 525ms/step - accuracy: 0.7806 - loss: 0.6109
# Epoch 31: val_accuracy improved from 0.81019 to 0.81250, saving model to effnet_best.keras
#
# Epoch 31: finished saving model to effnet_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 600ms/step - accuracy: 0.7831 - loss: 0.6079 - val_accuracy: 0.8125 - val_loss: 0.5847 - learning_rate: 5.0000e-06
# Epoch 32/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - accuracy: 0.7820 - loss: 0.6067
# Epoch 32: val_accuracy did not improve from 0.81250
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 79s 578ms/step - accuracy: 0.7841 - loss: 0.6052 - val_accuracy: 0.8102 - val_loss: 0.5809 - learning_rate: 5.0000e-06
# Epoch 33/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step - accuracy: 0.7897 - loss: 0.5953
# Epoch 33: val_accuracy improved from 0.81250 to 0.81481, saving model to effnet_best.keras
#
# Epoch 33: finished saving model to effnet_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 78s 573ms/step - accuracy: 0.7983 - loss: 0.5919 - val_accuracy: 0.8148 - val_loss: 0.5758 - learning_rate: 5.0000e-06
# Epoch 34/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - accuracy: 0.7908 - loss: 0.5922
# Epoch 34: val_accuracy improved from 0.81481 to 0.81713, saving model to effnet_best.keras
#
# Epoch 34: finished saving model to effnet_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 591ms/step - accuracy: 0.7813 - loss: 0.6017 - val_accuracy: 0.8171 - val_loss: 0.5758 - learning_rate: 5.0000e-06
# Epoch 35/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 519ms/step - accuracy: 0.7837 - loss: 0.5888
# Epoch 35: val_accuracy did not improve from 0.81713
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 590ms/step - accuracy: 0.7891 - loss: 0.5846 - val_accuracy: 0.8079 - val_loss: 0.5780 - learning_rate: 5.0000e-06
# Epoch 36/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - accuracy: 0.7942 - loss: 0.5957
# Epoch 36: val_accuracy did not improve from 0.81713
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 79s 584ms/step - accuracy: 0.7942 - loss: 0.6015 - val_accuracy: 0.8125 - val_loss: 0.5764 - learning_rate: 5.0000e-06
# Epoch 37/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step - accuracy: 0.7915 - loss: 0.6183
# Epoch 37: val_accuracy did not improve from 0.81713
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 79s 576ms/step - accuracy: 0.7937 - loss: 0.5966 - val_accuracy: 0.8102 - val_loss: 0.5740 - learning_rate: 5.0000e-06
# Epoch 38/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 519ms/step - accuracy: 0.8042 - loss: 0.5950
# Epoch 38: val_accuracy did not improve from 0.81713
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 79s 584ms/step - accuracy: 0.8006 - loss: 0.6000 - val_accuracy: 0.8102 - val_loss: 0.5726 - learning_rate: 5.0000e-06
# Epoch 39/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - accuracy: 0.7917 - loss: 0.5903
# Epoch 39: val_accuracy did not improve from 0.81713
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 586ms/step - accuracy: 0.7993 - loss: 0.5838 - val_accuracy: 0.8125 - val_loss: 0.5732 - learning_rate: 5.0000e-06
# Epoch 40/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - accuracy: 0.8106 - loss: 0.5938
# Epoch 40: val_accuracy did not improve from 0.81713
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 79s 579ms/step - accuracy: 0.8048 - loss: 0.5905 - val_accuracy: 0.8102 - val_loss: 0.5696 - learning_rate: 5.0000e-06
# Restoring model weights from the end of the best epoch: 40.
#
# EfficientNetB0 Best Val Accuracy: 0.8171

# %%
print("=" * 50)
print("TRAINING MODEL 4: ResNet50V2")
print("=" * 50)

preprocess_res2 = tf.keras.applications.resnet_v2.preprocess_input
train_gen_r2, val_gen_r2, test_gen_r2 = make_generators(preprocess_res2)

res_base_v2 = tf.keras.applications.ResNet50V2(
    include_top=False, weights='imagenet', input_shape=(224, 224, 3))
model_res2 = build_model(res_base_v2, 'resnet50v2')

# Stage 1
model_res2.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss='categorical_crossentropy', metrics=['accuracy'])

cb_r2s1 = [
    EarlyStopping(monitor='val_loss', patience=8,
                  restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.3,
                      patience=3, min_lr=1e-7, verbose=1),
    ModelCheckpoint("resnet50v2_stage1.keras", monitor='val_accuracy',
                    save_best_only=True, verbose=1)
]
print("\nResNet50V2 Stage 1...")
h_res2s1 = model_res2.fit(train_gen_r2, validation_data=val_gen_r2,
                           epochs=20, callbacks=cb_r2s1,
                           class_weight=class_weights)

# Stage 2 — unfreeze last 40 layers
res_base_v2.trainable = True
for layer in res_base_v2.layers[:-40]:
    layer.trainable = False

print(f"Trainable layers: {sum(1 for l in res_base_v2.layers if l.trainable)}")

model_res2.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=5e-6),
    loss='categorical_crossentropy', metrics=['accuracy'])

cb_r2s2 = [
    EarlyStopping(monitor='val_loss', patience=8,
                  restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.3,
                      patience=4, min_lr=1e-9, verbose=1),
    ModelCheckpoint("resnet50v2_best.keras", monitor='val_accuracy',
                    save_best_only=True, verbose=1)
]
print("\nResNet50V2 Stage 2...")
h_res2s2 = model_res2.fit(train_gen_r2, validation_data=val_gen_r2,
                           epochs=40, callbacks=cb_r2s2,
                           class_weight=class_weights)

print(f"\nResNet50V2 Best Val Accuracy: {max(h_res2s2.history['val_accuracy']):.4f}")
# Out:
# ==================================================
# TRAINING MODEL 4: ResNet50V2
# ==================================================
# Found 2172 images belonging to 3 classes.
# Found 432 images belonging to 3 classes.
# Found 294 images belonging to 3 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
#
# ResNet50V2 Stage 1...
# Epoch 1/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 555ms/step - accuracy: 0.5912 - loss: 1.3000
# Epoch 1: val_accuracy improved from None to 0.72454, saving model to resnet50v2_stage1.keras
#
# Epoch 1: finished saving model to resnet50v2_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 106s 671ms/step - accuracy: 0.6459 - loss: 1.1326 - val_accuracy: 0.7245 - val_loss: 0.7787 - learning_rate: 0.0010
# Epoch 2/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - accuracy: 0.6681 - loss: 0.9787
# Epoch 2: val_accuracy improved from 0.72454 to 0.72685, saving model to resnet50v2_stage1.keras
#
# Epoch 2: finished saving model to resnet50v2_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 589ms/step - accuracy: 0.6782 - loss: 0.9294 - val_accuracy: 0.7269 - val_loss: 0.7312 - learning_rate: 0.0010
# Epoch 3/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - accuracy: 0.6853 - loss: 0.8840
# Epoch 3: val_accuracy improved from 0.72685 to 0.73148, saving model to resnet50v2_stage1.keras
#
# Epoch 3: finished saving model to resnet50v2_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 591ms/step - accuracy: 0.6924 - loss: 0.8667 - val_accuracy: 0.7315 - val_loss: 0.7363 - learning_rate: 0.0010
# Epoch 4/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - accuracy: 0.6778 - loss: 0.8700
# Epoch 4: val_accuracy did not improve from 0.73148
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 588ms/step - accuracy: 0.6998 - loss: 0.8124 - val_accuracy: 0.7199 - val_loss: 0.7641 - learning_rate: 0.0010
# Epoch 5/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 524ms/step - accuracy: 0.7461 - loss: 0.7442
# Epoch 5: val_accuracy did not improve from 0.73148
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 598ms/step - accuracy: 0.7307 - loss: 0.7829 - val_accuracy: 0.7245 - val_loss: 0.7154 - learning_rate: 0.0010
# Epoch 6/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.7342 - loss: 0.7550
# Epoch 6: val_accuracy improved from 0.73148 to 0.73380, saving model to resnet50v2_stage1.keras
#
# Epoch 6: finished saving model to resnet50v2_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 79s 585ms/step - accuracy: 0.7302 - loss: 0.7518 - val_accuracy: 0.7338 - val_loss: 0.7177 - learning_rate: 0.0010
# Epoch 7/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - accuracy: 0.7611 - loss: 0.7271
# Epoch 7: val_accuracy did not improve from 0.73380
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 587ms/step - accuracy: 0.7551 - loss: 0.7317 - val_accuracy: 0.7338 - val_loss: 0.7223 - learning_rate: 0.0010
# Epoch 8/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 525ms/step - accuracy: 0.7451 - loss: 0.7268
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
#
# Epoch 8: val_accuracy did not improve from 0.73380
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 592ms/step - accuracy: 0.7330 - loss: 0.7504 - val_accuracy: 0.7315 - val_loss: 0.7183 - learning_rate: 0.0010
# Epoch 9/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 527ms/step - accuracy: 0.7586 - loss: 0.6889
# Epoch 9: val_accuracy did not improve from 0.73380
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 597ms/step - accuracy: 0.7509 - loss: 0.7049 - val_accuracy: 0.7338 - val_loss: 0.7217 - learning_rate: 3.0000e-04
# Epoch 10/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 519ms/step - accuracy: 0.7532 - loss: 0.7132
# Epoch 10: val_accuracy improved from 0.73380 to 0.74306, saving model to resnet50v2_stage1.keras
#
# Epoch 10: finished saving model to resnet50v2_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 594ms/step - accuracy: 0.7712 - loss: 0.6861 - val_accuracy: 0.7431 - val_loss: 0.7044 - learning_rate: 3.0000e-04
# Epoch 11/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 525ms/step - accuracy: 0.7591 - loss: 0.6997
# Epoch 11: val_accuracy improved from 0.74306 to 0.74537, saving model to resnet50v2_stage1.keras
#
# Epoch 11: finished saving model to resnet50v2_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 83s 607ms/step - accuracy: 0.7680 - loss: 0.6835 - val_accuracy: 0.7454 - val_loss: 0.7121 - learning_rate: 3.0000e-04
# Epoch 12/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 538ms/step - accuracy: 0.7584 - loss: 0.6818
# Epoch 12: val_accuracy did not improve from 0.74537
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 83s 612ms/step - accuracy: 0.7597 - loss: 0.6902 - val_accuracy: 0.7431 - val_loss: 0.6796 - learning_rate: 3.0000e-04
# Epoch 13/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - accuracy: 0.7827 - loss: 0.6570
# Epoch 13: val_accuracy improved from 0.74537 to 0.77315, saving model to resnet50v2_stage1.keras
#
# Epoch 13: finished saving model to resnet50v2_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 83s 608ms/step - accuracy: 0.7716 - loss: 0.6691 - val_accuracy: 0.7731 - val_loss: 0.6765 - learning_rate: 3.0000e-04
# Epoch 14/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.7802 - loss: 0.6672
# Epoch 14: val_accuracy did not improve from 0.77315
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 586ms/step - accuracy: 0.7753 - loss: 0.6593 - val_accuracy: 0.7616 - val_loss: 0.6687 - learning_rate: 3.0000e-04
# Epoch 15/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 522ms/step - accuracy: 0.7851 - loss: 0.6626
# Epoch 15: val_accuracy did not improve from 0.77315
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 592ms/step - accuracy: 0.7785 - loss: 0.6608 - val_accuracy: 0.7685 - val_loss: 0.6773 - learning_rate: 3.0000e-04
# Epoch 16/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - accuracy: 0.7575 - loss: 0.6736
# Epoch 16: val_accuracy did not improve from 0.77315
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 590ms/step - accuracy: 0.7790 - loss: 0.6449 - val_accuracy: 0.7731 - val_loss: 0.6818 - learning_rate: 3.0000e-04
# Epoch 17/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - accuracy: 0.7696 - loss: 0.6603
# Epoch 17: val_accuracy improved from 0.77315 to 0.78009, saving model to resnet50v2_stage1.keras
#
# Epoch 17: finished saving model to resnet50v2_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 599ms/step - accuracy: 0.7712 - loss: 0.6742 - val_accuracy: 0.7801 - val_loss: 0.6661 - learning_rate: 3.0000e-04
# Epoch 18/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - accuracy: 0.7682 - loss: 0.6739
# Epoch 18: val_accuracy improved from 0.78009 to 0.78935, saving model to resnet50v2_stage1.keras
#
# Epoch 18: finished saving model to resnet50v2_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 82s 600ms/step - accuracy: 0.7790 - loss: 0.6584 - val_accuracy: 0.7894 - val_loss: 0.6751 - learning_rate: 3.0000e-04
# Epoch 19/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - accuracy: 0.7852 - loss: 0.6583
# Epoch 19: val_accuracy did not improve from 0.78935
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 80s 590ms/step - accuracy: 0.7845 - loss: 0.6502 - val_accuracy: 0.7731 - val_loss: 0.6741 - learning_rate: 3.0000e-04
# Epoch 20/20
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - accuracy: 0.7768 - loss: 0.6718
# Epoch 20: val_accuracy improved from 0.78935 to 0.79398, saving model to resnet50v2_stage1.keras
#
# Epoch 20: finished saving model to resnet50v2_stage1.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 82s 603ms/step - accuracy: 0.7831 - loss: 0.6584 - val_accuracy: 0.7940 - val_loss: 0.6497 - learning_rate: 3.0000e-04
# Restoring model weights from the end of the best epoch: 20.
# Trainable layers: 40
#
# ResNet50V2 Stage 2...
# Epoch 1/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 611ms/step - accuracy: 0.6867 - loss: 0.8519
# Epoch 1: val_accuracy improved from None to 0.78704, saving model to resnet50v2_best.keras
#
# Epoch 1: finished saving model to resnet50v2_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 127s 761ms/step - accuracy: 0.6984 - loss: 0.8106 - val_accuracy: 0.7870 - val_loss: 0.6591 - learning_rate: 5.0000e-06
# Epoch 2/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 538ms/step - accuracy: 0.7231 - loss: 0.7411
# Epoch 2: val_accuracy did not improve from 0.78704
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 82s 606ms/step - accuracy: 0.7343 - loss: 0.7330 - val_accuracy: 0.7847 - val_loss: 0.6609 - learning_rate: 5.0000e-06
# Epoch 3/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - accuracy: 0.7501 - loss: 0.7225
# Epoch 3: val_accuracy improved from 0.78704 to 0.78935, saving model to resnet50v2_best.keras
#
# Epoch 3: finished saving model to resnet50v2_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 87s 641ms/step - accuracy: 0.7408 - loss: 0.7274 - val_accuracy: 0.7894 - val_loss: 0.6528 - learning_rate: 5.0000e-06
# Epoch 4/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - accuracy: 0.7553 - loss: 0.6897
# Epoch 4: val_accuracy improved from 0.78935 to 0.80324, saving model to resnet50v2_best.keras
#
# Epoch 4: finished saving model to resnet50v2_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 89s 655ms/step - accuracy: 0.7541 - loss: 0.7032 - val_accuracy: 0.8032 - val_loss: 0.6430 - learning_rate: 5.0000e-06
# Epoch 5/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 560ms/step - accuracy: 0.7538 - loss: 0.7075
# Epoch 5: val_accuracy improved from 0.80324 to 0.80787, saving model to resnet50v2_best.keras
#
# Epoch 5: finished saving model to resnet50v2_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 91s 670ms/step - accuracy: 0.7560 - loss: 0.7188 - val_accuracy: 0.8079 - val_loss: 0.6337 - learning_rate: 5.0000e-06
# Epoch 6/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - accuracy: 0.7730 - loss: 0.6909
# Epoch 6: val_accuracy did not improve from 0.80787
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 83s 613ms/step - accuracy: 0.7657 - loss: 0.7007 - val_accuracy: 0.8032 - val_loss: 0.6282 - learning_rate: 5.0000e-06
# Epoch 7/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - accuracy: 0.7756 - loss: 0.6602
# Epoch 7: val_accuracy did not improve from 0.80787
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 82s 606ms/step - accuracy: 0.7808 - loss: 0.6561 - val_accuracy: 0.7963 - val_loss: 0.6309 - learning_rate: 5.0000e-06
# Epoch 8/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - accuracy: 0.7728 - loss: 0.6596
# Epoch 8: val_accuracy did not improve from 0.80787
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 83s 608ms/step - accuracy: 0.7698 - loss: 0.6719 - val_accuracy: 0.8032 - val_loss: 0.6189 - learning_rate: 5.0000e-06
# Epoch 9/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 556ms/step - accuracy: 0.7768 - loss: 0.6688
# Epoch 9: val_accuracy did not improve from 0.80787
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 85s 629ms/step - accuracy: 0.7785 - loss: 0.6530 - val_accuracy: 0.7986 - val_loss: 0.6155 - learning_rate: 5.0000e-06
# Epoch 10/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - accuracy: 0.7920 - loss: 0.6308
# Epoch 10: val_accuracy did not improve from 0.80787
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 83s 613ms/step - accuracy: 0.7850 - loss: 0.6448 - val_accuracy: 0.7963 - val_loss: 0.6121 - learning_rate: 5.0000e-06
# Epoch 11/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - accuracy: 0.8015 - loss: 0.6162
# Epoch 11: val_accuracy did not improve from 0.80787
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 82s 605ms/step - accuracy: 0.7928 - loss: 0.6260 - val_accuracy: 0.7940 - val_loss: 0.6068 - learning_rate: 5.0000e-06
# Epoch 12/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - accuracy: 0.8081 - loss: 0.5962
# Epoch 12: val_accuracy did not improve from 0.80787
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 82s 606ms/step - accuracy: 0.7947 - loss: 0.6197 - val_accuracy: 0.8009 - val_loss: 0.6011 - learning_rate: 5.0000e-06
# Epoch 13/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 561ms/step - accuracy: 0.7987 - loss: 0.6184
# Epoch 13: val_accuracy improved from 0.80787 to 0.81019, saving model to resnet50v2_best.keras
#
# Epoch 13: finished saving model to resnet50v2_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 92s 677ms/step - accuracy: 0.7970 - loss: 0.6161 - val_accuracy: 0.8102 - val_loss: 0.6009 - learning_rate: 5.0000e-06
# Epoch 14/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 546ms/step - accuracy: 0.7998 - loss: 0.5809
# Epoch 14: val_accuracy did not improve from 0.81019
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 84s 620ms/step - accuracy: 0.7960 - loss: 0.6103 - val_accuracy: 0.8009 - val_loss: 0.6032 - learning_rate: 5.0000e-06
# Epoch 15/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 551ms/step - accuracy: 0.7801 - loss: 0.6431
# Epoch 15: val_accuracy did not improve from 0.81019
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 85s 625ms/step - accuracy: 0.7997 - loss: 0.6071 - val_accuracy: 0.8102 - val_loss: 0.5975 - learning_rate: 5.0000e-06
# Epoch 16/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 551ms/step - accuracy: 0.8066 - loss: 0.6068
# Epoch 16: val_accuracy improved from 0.81019 to 0.81713, saving model to resnet50v2_best.keras
#
# Epoch 16: finished saving model to resnet50v2_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 93s 684ms/step - accuracy: 0.8076 - loss: 0.6027 - val_accuracy: 0.8171 - val_loss: 0.5961 - learning_rate: 5.0000e-06
# Epoch 17/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 554ms/step - accuracy: 0.8142 - loss: 0.5764
# Epoch 17: val_accuracy did not improve from 0.81713
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 85s 628ms/step - accuracy: 0.8186 - loss: 0.5783 - val_accuracy: 0.8032 - val_loss: 0.5979 - learning_rate: 5.0000e-06
# Epoch 18/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 546ms/step - accuracy: 0.8052 - loss: 0.6058
# Epoch 18: val_accuracy improved from 0.81713 to 0.81944, saving model to resnet50v2_best.keras
#
# Epoch 18: finished saving model to resnet50v2_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 101s 743ms/step - accuracy: 0.8135 - loss: 0.5868 - val_accuracy: 0.8194 - val_loss: 0.5996 - learning_rate: 5.0000e-06
# Epoch 19/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - accuracy: 0.8242 - loss: 0.5550
# Epoch 19: val_accuracy did not improve from 0.81944
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 83s 607ms/step - accuracy: 0.8223 - loss: 0.5583 - val_accuracy: 0.8171 - val_loss: 0.5868 - learning_rate: 5.0000e-06
# Epoch 20/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 543ms/step - accuracy: 0.8378 - loss: 0.5524
# Epoch 20: val_accuracy improved from 0.81944 to 0.82176, saving model to resnet50v2_best.keras
#
# Epoch 20: finished saving model to resnet50v2_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 92s 674ms/step - accuracy: 0.8292 - loss: 0.5542 - val_accuracy: 0.8218 - val_loss: 0.5834 - learning_rate: 5.0000e-06
# Epoch 21/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 559ms/step - accuracy: 0.8136 - loss: 0.5846
# Epoch 21: val_accuracy did not improve from 0.82176
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 86s 633ms/step - accuracy: 0.8273 - loss: 0.5643 - val_accuracy: 0.8218 - val_loss: 0.5823 - learning_rate: 5.0000e-06
# Epoch 22/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 548ms/step - accuracy: 0.8220 - loss: 0.5624
# Epoch 22: val_accuracy did not improve from 0.82176
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 84s 619ms/step - accuracy: 0.8352 - loss: 0.5432 - val_accuracy: 0.8079 - val_loss: 0.5882 - learning_rate: 5.0000e-06
# Epoch 23/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - accuracy: 0.8347 - loss: 0.5385
# Epoch 23: val_accuracy did not improve from 0.82176
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 81s 592ms/step - accuracy: 0.8273 - loss: 0.5556 - val_accuracy: 0.8194 - val_loss: 0.5842 - learning_rate: 5.0000e-06
# Epoch 24/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - accuracy: 0.8153 - loss: 0.5413
# Epoch 24: val_accuracy did not improve from 0.82176
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 83s 611ms/step - accuracy: 0.8158 - loss: 0.5480 - val_accuracy: 0.8194 - val_loss: 0.5776 - learning_rate: 5.0000e-06
# Epoch 25/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 548ms/step - accuracy: 0.8182 - loss: 0.5525
# Epoch 25: val_accuracy did not improve from 0.82176
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 85s 622ms/step - accuracy: 0.8297 - loss: 0.5368 - val_accuracy: 0.8218 - val_loss: 0.5747 - learning_rate: 5.0000e-06
# Epoch 26/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 541ms/step - accuracy: 0.8179 - loss: 0.5528
# Epoch 26: val_accuracy improved from 0.82176 to 0.82639, saving model to resnet50v2_best.keras
#
# Epoch 26: finished saving model to resnet50v2_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 105s 774ms/step - accuracy: 0.8246 - loss: 0.5476 - val_accuracy: 0.8264 - val_loss: 0.5642 - learning_rate: 5.0000e-06
# Epoch 27/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - accuracy: 0.8348 - loss: 0.5517
# Epoch 27: val_accuracy improved from 0.82639 to 0.83102, saving model to resnet50v2_best.keras
#
# Epoch 27: finished saving model to resnet50v2_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 91s 673ms/step - accuracy: 0.8352 - loss: 0.5384 - val_accuracy: 0.8310 - val_loss: 0.5844 - learning_rate: 5.0000e-06
# Epoch 28/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - accuracy: 0.8305 - loss: 0.5358
# Epoch 28: val_accuracy improved from 0.83102 to 0.83333, saving model to resnet50v2_best.keras
#
# Epoch 28: finished saving model to resnet50v2_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 105s 776ms/step - accuracy: 0.8329 - loss: 0.5315 - val_accuracy: 0.8333 - val_loss: 0.5748 - learning_rate: 5.0000e-06
# Epoch 29/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - accuracy: 0.8245 - loss: 0.5356
# Epoch 29: val_accuracy did not improve from 0.83333
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 84s 616ms/step - accuracy: 0.8255 - loss: 0.5378 - val_accuracy: 0.8264 - val_loss: 0.5717 - learning_rate: 5.0000e-06
# Epoch 30/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 537ms/step - accuracy: 0.8303 - loss: 0.5352
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.4999999621068127e-06.
#
# Epoch 30: val_accuracy did not improve from 0.83333
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 82s 607ms/step - accuracy: 0.8352 - loss: 0.5207 - val_accuracy: 0.8333 - val_loss: 0.5738 - learning_rate: 5.0000e-06
# Epoch 31/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 552ms/step - accuracy: 0.8239 - loss: 0.5580
# Epoch 31: val_accuracy improved from 0.83333 to 0.83565, saving model to resnet50v2_best.keras
#
# Epoch 31: finished saving model to resnet50v2_best.keras
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 92s 675ms/step - accuracy: 0.8425 - loss: 0.5212 - val_accuracy: 0.8356 - val_loss: 0.5728 - learning_rate: 1.5000e-06
# Epoch 32/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 547ms/step - accuracy: 0.8210 - loss: 0.5436
# Epoch 32: val_accuracy did not improve from 0.83565
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 84s 619ms/step - accuracy: 0.8278 - loss: 0.5416 - val_accuracy: 0.8356 - val_loss: 0.5734 - learning_rate: 1.5000e-06
# Epoch 33/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 537ms/step - accuracy: 0.8477 - loss: 0.5336
# Epoch 33: val_accuracy did not improve from 0.83565
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 82s 604ms/step - accuracy: 0.8458 - loss: 0.5260 - val_accuracy: 0.8333 - val_loss: 0.5667 - learning_rate: 1.5000e-06
# Epoch 34/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 551ms/step - accuracy: 0.8416 - loss: 0.5321
# Epoch 34: ReduceLROnPlateau reducing learning rate to 4.4999998181083353e-07.
#
# Epoch 34: val_accuracy did not improve from 0.83565
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 85s 620ms/step - accuracy: 0.8444 - loss: 0.5135 - val_accuracy: 0.8310 - val_loss: 0.5698 - learning_rate: 1.5000e-06
# Epoch 34: early stopping
# Restoring model weights from the end of the best epoch: 26.
#
# ResNet50V2 Best Val Accuracy: 0.8356

# %%
print("Loading all 4 best models...")
m_vgg  = tf.keras.models.load_model("vgg19_best.keras")
m_res  = tf.keras.models.load_model("resnet50_best.keras")
m_eff  = tf.keras.models.load_model("effnet_best.keras")
m_res2 = tf.keras.models.load_model("resnet50v2_best.keras")

class_names = ['Normal', 'Osteopenia', 'Osteoporosis']

def get_preds(model, preprocess_fn, n_tta=20):
    """Get TTA predictions from a model."""
    tta_datagen = ImageDataGenerator(
        rotation_range=5,
        horizontal_flip=True,
        zoom_range=0.03,
        preprocessing_function=preprocess_fn
    )
    # Get total test samples
    total = sum(
        len(os.listdir(os.path.join(test_dir, cls)))
        for cls in ['Normal', 'Osteopenia', 'Osteoporosis']
    )
    preds = np.zeros((total, 3))

    for i in range(n_tta):
        gen = tta_datagen.flow_from_directory(
            test_dir, target_size=(224, 224), batch_size=1,
            classes=['Normal', 'Osteopenia', 'Osteoporosis'],
            class_mode='categorical', shuffle=False)
        gen.reset()
        preds += model.predict(gen, steps=len(gen), verbose=0)
        print(f"  TTA round {i+1}/{n_tta} done")
    return preds / n_tta

# VGG-19 and ResNet50 are strongest — give them 30 TTA rounds
print("\nVGG-19 predictions (30 TTA rounds)...")
preds_vgg = get_preds(m_vgg,
                      tf.keras.applications.vgg19.preprocess_input,
                      n_tta=30)

print("\nResNet50 predictions (30 TTA rounds)...")
preds_res = get_preds(m_res,
                      tf.keras.applications.resnet50.preprocess_input,
                      n_tta=30)

# EfficientNetB0 and ResNet50V2 get 20 TTA rounds
print("\nEfficientNetB0 predictions (20 TTA rounds)...")
preds_eff = get_preds(m_eff,
                      tf.keras.applications.efficientnet.preprocess_input,
                      n_tta=20)

print("\nResNet50V2 predictions (20 TTA rounds)...")
preds_res2 = get_preds(m_res2,
                       tf.keras.applications.resnet_v2.preprocess_input,
                       n_tta=20)

# Get true labels
label_gen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.vgg19.preprocess_input
).flow_from_directory(
    test_dir, target_size=(224, 224), batch_size=1,
    classes=['Normal', 'Osteopenia', 'Osteoporosis'],
    class_mode='categorical', shuffle=False)
y_true = label_gen.classes

print("\nAll predictions done!")
# Out:
# Loading all 4 best models...
#
# VGG-19 predictions (30 TTA rounds)...
# Found 294 images belonging to 3 classes.
#   TTA round 1/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 2/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 3/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 4/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 5/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 6/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 7/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 8/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 9/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 10/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 11/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 12/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 13/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 14/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 15/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 16/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 17/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 18/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 19/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 20/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 21/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 22/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 23/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 24/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 25/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 26/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 27/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 28/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 29/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 30/30 done
#
# ResNet50 predictions (30 TTA rounds)...
# Found 294 images belonging to 3 classes.
#   TTA round 1/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 2/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 3/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 4/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 5/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 6/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 7/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 8/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 9/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 10/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 11/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 12/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 13/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 14/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 15/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 16/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 17/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 18/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 19/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 20/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 21/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 22/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 23/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 24/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 25/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 26/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 27/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 28/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 29/30 done
# Found 294 images belonging to 3 classes.
#   TTA round 30/30 done
#
# EfficientNetB0 predictions (20 TTA rounds)...
# Found 294 images belonging to 3 classes.
#   TTA round 1/20 done
# Found 294 images belonging to 3 classes.
#   TTA round 2/20 done
# Found 294 images belonging to 3 classes.
#   TTA round 3/20 done
# Found 294 images belonging to 3 classes.
#   TTA round 4/20 done
# Found 294 images belonging to 3 classes.
#   TTA round 5/20 done
# Found 294 images belonging to 3 classes.
#   TTA round 6/20 done
# Found 294 images belonging to 3 classes.
#   TTA round 7/20 done
# Found 294 images belonging to 3 classes.
#   TTA round 8/20 done
# Found 294 images belonging to 3 classes.
#   TTA round 9/20 done
# Found 294 images belonging to 3 classes.
#   TTA round 10/20 done
# Found 294 images belonging to 3 classes.
#   TTA round 11/20 done
# Found 294 images belonging to 3 classes.
#   TTA round 12/20 done
# Found 294 images belonging to 3 classes.
#   TTA round 13/20 done
# Found 294 images belonging to 3 classes.
#   TTA round 14/20 done
# Found 294 images belonging to 3 classes.
#   TTA round 15/20 done
# Found 294 images belonging to 3 classes.
#   TTA round 16/20 done
# Found 294 images belonging to 3 classes.
#   TTA round 17/20 done
# Found 294 images belonging to 3 classes.
#   TTA round 18/20 done
# Found 294 images belonging to 3 classes.
#   TTA round 19/20 done
# Found 294 images belonging to 3 classes.
#   TTA round 20/20 done
#
# ResNet50V2 predictions (20 TTA rounds)...
# Found 294 images belonging to 3 classes.
#   TTA round 1/20 done
# Found 294 images belonging to 3 classes.
#   TTA round 2/20 done
# Found 294 images belonging to 3 classes.
#   TTA round 3/20 done
# Found 294 images belonging to 3 classes.
#   TTA round 4/20 done
# Found 294 images belonging to 3 classes.
#   TTA round 5/20 done
# Found 294 images belonging to 3 classes.
#   TTA round 6/20 done
# Found 294 images belonging to 3 classes.
#   TTA round 7/20 done
# Found 294 images belonging to 3 classes.
#   TTA round 8/20 done
# Found 294 images belonging to 3 classes.
#   TTA round 9/20 done
# Found 294 images belonging to 3 classes.
#   TTA round 10/20 done
# Found 294 images belonging to 3 classes.
#   TTA round 11/20 done
# Found 294 images belonging to 3 classes.
#   TTA round 12/20 done
# Found 294 images belonging to 3 classes.
#   TTA round 13/20 done
# Found 294 images belonging to 3 classes.
#   TTA round 14/20 done
# Found 294 images belonging to 3 classes.
#   TTA round 15/20 done
# Found 294 images belonging to 3 classes.
#   TTA round 16/20 done
# Found 294 images belonging to 3 classes.
#   TTA round 17/20 done
# Found 294 images belonging to 3 classes.
#   TTA round 18/20 done
# Found 294 images belonging to 3 classes.
#   TTA round 19/20 done
# Found 294 images belonging to 3 classes.
#   TTA round 20/20 done
# Found 294 images belonging to 3 classes.
#
# All predictions done!

# %%
print("\nSearching for optimal ensemble weights...")
print("(This may take ~1 minute)")

best_acc   = 0
best_w     = (1, 1, 1, 1)
best_preds = None

# Search weight combinations for all 4 models
for w1 in np.arange(0.2, 1.3, 0.2):      # VGG-19
    for w2 in np.arange(0.2, 1.3, 0.2):   # ResNet50
        for w3 in np.arange(0.2, 1.1, 0.2): # EfficientNetB0
            for w4 in np.arange(0.2, 1.3, 0.2): # ResNet50V2
                ensemble = (w1*preds_vgg + w2*preds_res +
                            w3*preds_eff + w4*preds_res2)
                y_pred   = np.argmax(ensemble, axis=1)
                acc      = np.sum(y_pred == y_true) / len(y_true)
                if acc > best_acc:
                    best_acc   = acc
                    best_w     = (w1, w2, w3, w4)
                    best_preds = ensemble.copy()

print(f"\nBest weights:")
print(f"  VGG-19:        {best_w[0]:.1f}")
print(f"  ResNet50:      {best_w[1]:.1f}")
print(f"  EfficientNetB0:{best_w[2]:.1f}")
print(f"  ResNet50V2:    {best_w[3]:.1f}")
print(f"\nBest Ensemble Accuracy: {best_acc * 100:.2f}%")

y_pred_final = np.argmax(best_preds, axis=1)

print("\n--- Final Ensemble Classification Report ---")
print(classification_report(y_true, y_pred_final, target_names=class_names))

cm = confusion_matrix(y_true, y_pred_final)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d',
            xticklabels=class_names,
            yticklabels=class_names,
            cmap='Greens')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title(f'4-Model Ensemble — {best_acc*100:.2f}%')
plt.show()
# Out:
# Searching for optimal ensemble weights...
# (This may take ~1 minute)
#
# Best weights:
#   VGG-19:        0.6
#   ResNet50:      1.0
#   EfficientNetB0:0.2
#   ResNet50V2:    0.2
#
# Best Ensemble Accuracy: 88.78%
#
# --- Final Ensemble Classification Report ---
#               precision    recall  f1-score   support
#
#       Normal       0.93      0.88      0.91        98
#   Osteopenia       0.89      0.88      0.88        98
# Osteoporosis       0.85      0.91      0.88        98
#
#     accuracy                           0.89       294
#    macro avg       0.89      0.89      0.89       294
# weighted avg       0.89      0.89      0.89       294

# %%
print("\nFull model comparison:")
print("-" * 45)

results = {
    "VGG-19 (30 TTA)":        preds_vgg,
    "ResNet50 (30 TTA)":      preds_res,
    "EfficientNetB0 (20 TTA)":preds_eff,
    "ResNet50V2 (20 TTA)":    preds_res2,
    "Equal Ensemble (4 models)":(preds_vgg + preds_res +
                                  preds_eff + preds_res2) / 4,
    "Weighted Ensemble":       best_preds
}

for name, preds in results.items():
    y_p = np.argmax(preds, axis=1)
    acc = np.sum(y_p == y_true) / len(y_true)
    print(f"{name:30s}: {acc*100:.2f}%")

print(f"\nPrevious best (3-model ensemble): 89.46%")
print(f"New best (4-model ensemble):      {best_acc*100:.2f}%")
improvement = best_acc * 100 - 89.46
print(f"Improvement:                      +{improvement:.2f}%")
# Out:
# Full model comparison:
# ---------------------------------------------
# VGG-19 (30 TTA)               : 85.37%
# ResNet50 (30 TTA)             : 87.07%
# EfficientNetB0 (20 TTA)       : 83.33%
# ResNet50V2 (20 TTA)           : 85.37%
# Equal Ensemble (4 models)     : 87.76%
# Weighted Ensemble             : 88.78%
#
# Previous best (3-model ensemble): 89.46%
# New best (4-model ensemble):      88.78%
# Improvement:                      +-0.68%

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator

test_dir = "/tmp/osteoporosis_merged/test"

label_gen = ImageDataGenerator(
 preprocessing_function=tf.keras.applications.vgg19.preprocess_input
).flow_from_directory(
 test_dir, target_size=(224, 224), batch_size=1,
 classes=['Normal', 'Osteopenia', 'Osteoporosis'],
 class_mode='categorical', shuffle=False)
y_true_current = label_gen.classes

def quick_predict(model, preprocess_fn):
 gen = ImageDataGenerator(
  preprocessing_function=preprocess_fn
 ).flow_from_directory(
  test_dir, target_size=(224, 224), batch_size=1,
  classes=['Normal', 'Osteopenia', 'Osteoporosis'],
  class_mode='categorical', shuffle=False)
 gen.reset()
 preds = model.predict(gen, steps=len(gen), verbose=0)
 return preds

print("Getting predictions...")
p_vgg = quick_predict(m_vgg, tf.keras.applications.vgg19.preprocess_input)
p_res = quick_predict(m_res, tf.keras.applications.resnet50.preprocess_input)
p_eff = quick_predict(m_eff, tf.keras.applications.efficientnet.preprocess_input)
p_res2 = quick_predict(m_res2, tf.keras.applications.resnet_v2.preprocess_input)

old_3 = (p_vgg + p_res + p_eff) / 3
acc_old3 = np.sum(np.argmax(old_3, axis=1) == y_true_current) / len(y_true_current)

new_4 = (0.6*p_vgg + 1.0*p_res + 0.2*p_eff + 0.2*p_res2)
acc_new4 = np.sum(np.argmax(new_4, axis=1) == y_true_current) / len(y_true_current)

print(f"\nOld 3-model ensemble: {acc_old3*100:.2f}%")
print(f"New 4-model weighted: {acc_new4*100:.2f}%")

if acc_new4 > acc_old3:
 print(f"4-model is BETTER by {(acc_new4-acc_old3)*100:.2f}%")
else:
 print(f"3-model is BETTER by {(acc_old3-acc_new4)*100:.2f}%")

# %%
import kagglehub
import os

# Option 1 — Orvile (newer 2025 dataset, never used in training)
print("Downloading Orvile dataset...")
path_orvile = kagglehub.dataset_download("orvile/knee-x-ray-osteoporosis-database")
print("Orvile path:", path_orvile)

# Option 2 — Sachinkumar preprocessed dataset
print("\nDownloading Sachinkumar dataset...")
path_sach = kagglehub.dataset_download("sachinkumar413/osteoporosis-knee-dataset-preprocessed128x256")
print("Sachinkumar path:", path_sach)

# Option 3 — mohamedgobara secondary dataset
print("\nDownloading mohamedgobara secondary dataset...")
path_bmd = kagglehub.dataset_download("mohamedgobara/osteoporosis-database")
print("BMD path:", path_bmd)

def explore_folder(path, max_depth=3, current_depth=0):
 if current_depth >= max_depth:
  return
 try:
  for item in sorted(os.listdir(path)):
   print(" " * current_depth + item)
   full = os.path.join(path, item)
   if os.path.isdir(full):
    explore_folder(full, max_depth, current_depth + 1)
 except:
  pass

print("\n=== Orvile Structure ===")
explore_folder(path_orvile)

print("\n=== Sachinkumar Structure ===")
explore_folder(path_sach)

print("\n=== BMD Structure ===")
explore_folder(path_bmd)
# Out:
# Downloading Orvile dataset...
# Downloading to /root/.cache/kagglehub/datasets/orvile/knee-x-ray-osteoporosis-database/1.archive...
# 100%|██████████| 182M/182M [00:01<00:00, 165MB/s]
# Extracting files...
# Orvile path: /root/.cache/kagglehub/datasets/orvile/knee-x-ray-osteoporosis-database/versions/1
#
# Downloading Sachinkumar dataset...
# Downloading to /root/.cache/kagglehub/datasets/sachinkumar413/osteoporosis-knee-dataset-preprocessed128x256/1.archive...
# 100%|██████████| 1.94M/1.94M [00:00<00:00, 126MB/s]
# Extracting files...
# Sachinkumar path: /root/.cache/kagglehub/datasets/sachinkumar413/osteoporosis-knee-dataset-preprocessed128x256/versions/1
#
# Downloading mohamedgobara secondary dataset...
# Downloading to /root/.cache/kagglehub/datasets/mohamedgobara/osteoporosis-database/1.archive...
# 100%|██████████| 182M/182M [00:01<00:00, 170MB/s]
# Extracting files...
# BMD path: /root/.cache/kagglehub/datasets/mohamedgobara/osteoporosis-database/versions/1
#
# === Orvile Structure ===
# Osteoporosis Knee X-ray
#  README.txt
#  normal
#   N1.JPEG
#   N10.JPEG
#   N11.JPEG
#   N12.JPEG
#   N13.jpg
#   N14.jpg
#   N15.jpg
#   N16.jpg
#   N17.jpg
#   N18.jpg
#   N19.jpg
#   N2.JPEG
#   N20.jpg
#   N21.jpg
#   N22.jpg
#   N23.jpg
#   N24.jpg
#   N25.jpg
#   N26.jpg
#   N27.jpg
#   N28.jpg
#   N29.jpg
#   N3.JPEG
#   N30.jpg
#   N31.jpg
#   N32.jpg
#   N33.jpg
#   N34.jpg
#   N35.jpg
#   N36.jpg
#   N4.JPEG
#   N5.JPEG
#   N6.JPEG
#   N7.JPEG
#   N8.JPEG
#   N9.JPEG
#  osteopenia
#   OP1.JPEG
#   OP10.JPEG
#   OP100.jpg
#   OP101.jpg
#   OP102.jpg
#   OP103.jpg
#   OP104.jpg
#   OP105.jpg
#   OP106.jpg
#   OP107.jpg
#   OP108.jpg
#   OP109.jpg
#   OP11.JPEG
#   OP110.jpg
#   OP111.jpg
#   OP112.jpg
#   OP113.jpg
#   OP114.jpg
#   OP115.jpg
#   OP116.jpg
#   OP117.jpg
#   OP118.jpg
#   OP119.jpg
#   OP12.JPEG
#   OP120.jpg
#   OP121.jpg
#   OP122.jpg
#   OP123.jpg
#   OP124.jpg
#   OP125.jpg
#   OP126.jpg
#   OP127.jpg
#   OP128.jpg
#   OP129.jpg
#   OP13.JPEG
#   OP130.jpg
#   OP131.jpg
#   OP132.jpg
#   OP133.jpg
#   OP134.jpg
#   OP135.jpg
#   OP136.jpg
#   OP137.jpg
#   OP138.jpg
#   OP139.jpg
#   OP14.JPEG
#   OP140.jpg
#   OP141.jpg
#   OP142.jpg
#   OP143.jpg
#   OP144.jpg
#   OP145.jpg
#   OP146.jpg
#   OP147.jpg
#   OP148.jpg
#   OP149.jpg
#   OP15.JPEG
#   OP150.jpg
#   OP151.jpg
#   OP152.jpg
#   OP153.jpg
#   OP154.jpg
#   OP16.JPEG
#   OP17.JPEG
#   OP18.JPEG
#   OP19.JPEG
#   OP2.JPEG
#   OP20.JPEG
#   OP21.JPEG
#   OP22.JPEG
#   OP23.JPEG
#   OP24.JPEG
#   OP25.JPEG
#   OP26.JPEG
#   OP27.JPEG
#   OP28.JPEG
#   OP29.JPEG
#   OP3.JPEG
#   OP30.JPEG
#   OP31.JPEG
#   OP32.JPEG
#   OP33.JPEG
#   OP34.JPEG
#   OP35.JPEG
#   OP36.JPEG
#   OP37.JPEG
#   OP38.JPEG
#   OP39.JPEG
#   OP4.JPEG
#   OP40.JPEG
#   OP41.JPEG
#   OP42.JPEG
#   OP43.JPEG
#   OP44.JPEG
#   OP45.jpg
#   OP46.jpg
#   OP47.jpg
#   OP48.jpg
#   OP49.jpg
#   OP5.JPEG
#   OP50.jpg
#   OP51.jpg
#   OP52.jpg
#   OP53.jpg
#   OP54.jpg
#   OP55.jpg
#   OP56.jpg
#   OP57.jpg
#   OP58.jpg
#   OP59.jpg
#   OP6.JPEG
#   OP60.jpg
#   OP61.jpg
#   OP62.jpg
#   OP63.jpg
#   OP64.jpg
#   OP65.jpg
#   OP66.jpg
#   OP67.jpg
#   OP68.jpg
#   OP69.jpg
#   OP7.JPEG
#   OP70.jpg
#   OP71.jpg
#   OP72.jpg
#   OP73.jpg
#   OP74.jpg
#   OP75.jpg
#   OP76.jpg
#   OP77.jpg
#   OP78.jpg
#   OP79.jpg
#   OP8.JPEG
#   OP80.jpg
#   OP81.jpg
#   OP82.jpg
#   OP83.jpg
#   OP84.jpg
#   OP85.jpg
#   OP86.jpg
#   OP87.jpg
#   OP88.jpg
#   OP89.jpg
#   OP9.JPEG
#   OP90.jpg
#   OP91.jpg
#   OP92.jpg
#   OP93.jpg
#   OP94.jpg
#   OP95.jpg
#   OP96.jpg
#   OP97.jpg
#   OP98.jpg
#   OP99.jpg
#  osteoporosis
#   OS1.JPEG
#   OS10.jpg
#   OS11.jpg
#   OS12.jpg
#   OS13.jpg
#   OS14.jpg
#   OS15.jpg
#   OS16.jpg
#   OS17.jpg
#   OS18.jpg
#   OS19.jpg
#   OS2.JPEG
#   OS20.jpg
#   OS21.jpg
#   OS22.jpg
#   OS23.jpg
#   OS24.jpg
#   OS25.jpg
#   OS26.jpg
#   OS27.jpg
#   OS28.jpg
#   OS29.jpg
#   OS3.JPEG
#   OS30.jpg
#   OS31.jpg
#   OS32.jpg
#   OS33.jpg
#   OS34.jpg
#   OS35.jpg
#   OS36.jpg
#   OS37.jpg
#   OS38.jpg
#   OS39.jpg
#   OS4.JPEG
#   OS40.jpg
#   OS41.jpg
#   OS42.jpg
#   OS43.jpg
#   OS44.jpg
#   OS45.jpg
#   OS46.jpg
#   OS47.jpg
#   OS48.jpg
#   OS49.jpg
#   OS5.JPEG
#   OS6.JPEG
#   OS7.JPEG
#   OS8.jpg
#   OS9.jpg
#  patient details.xlsx
#
# === Sachinkumar Structure ===
# Osteoporosis Knee Dataset
#  Normal
#   Normal.jpg
#   Normal_10.jpg
#   Normal_100.jpg
#   Normal_101.jpg
#   Normal_102.jpg
#   Normal_103.jpg
#   Normal_104.jpg
#   Normal_105.jpg
#   Normal_106.jpg
#   Normal_107.jpg
#   Normal_108.jpg
#   Normal_109.jpg
#   Normal_11.jpg
#   Normal_110.jpg
#   Normal_111.jpg
#   Normal_112.jpg
#   Normal_113.jpg
#   Normal_114.jpg
#   Normal_115.jpg
#   Normal_116.jpg
#   Normal_117.jpg
#   Normal_118.jpg
#   Normal_119.jpg
#   Normal_12.jpg
#   Normal_120.jpg
#   Normal_121.jpg
#   Normal_122.jpg
#   Normal_123.jpg
#   Normal_124.jpg
#   Normal_125.jpg
#   Normal_126.jpg
#   Normal_127.jpg
#   Normal_128.jpg
#   Normal_129.jpg
#   Normal_13.jpg
#   Normal_130.jpg
#   Normal_131.jpg
#   Normal_132.jpg
#   Normal_133.jpg
#   Normal_134.jpg
#   Normal_135.jpg
#   Normal_136.jpg
#   Normal_137.jpg
#   Normal_138.jpg
#   Normal_139.jpg
#   Normal_14.jpg
#   Normal_140.jpg
#   Normal_141.jpg
#   Normal_142.jpg
#   Normal_143.jpg
#   Normal_144.jpg
#   Normal_145.jpg
#   Normal_146.jpg
#   Normal_147.jpg
#   Normal_148.jpg
#   Normal_149.jpg
#   Normal_15.jpg
#   Normal_150.jpg
#   Normal_151.jpg
#   Normal_152.jpg
#   Normal_153.jpg
#   Normal_154.jpg
#   Normal_155.jpg
#   Normal_156.jpg
#   Normal_157.jpg
#   Normal_158.jpg
#   Normal_159.jpg
#   Normal_16.jpg
#   Normal_160.jpg
#   Normal_161.jpg
#   Normal_162.jpg
#   Normal_163.jpg
#   Normal_164.jpg
#   Normal_165.jpg
#   Normal_166.jpg
#   Normal_167.jpg
#   Normal_168.jpg
#   Normal_169.jpg
#   Normal_17.jpg
#   Normal_170.jpg
#   Normal_171.jpg
#   Normal_172.jpg
#   Normal_173.jpg
#   Normal_174.jpg
#   Normal_175.jpg
#   Normal_176.jpg
#   Normal_177.jpg
#   Normal_178.jpg
#   Normal_179.jpg
#   Normal_18.jpg
#   Normal_180.jpg
#   Normal_181.jpg
#   Normal_182.jpg
#   Normal_183.jpg
#   Normal_184.jpg
#   Normal_185.jpg
#   Normal_186.jpg
#   Normal_19.jpg
#   Normal_2.jpg
#   Normal_20.jpg
#   Normal_21.jpg
#   Normal_22.jpg
#   Normal_23.jpg
#   Normal_24.jpg
#   Normal_25.jpg
#   Normal_26.jpg
#   Normal_27.jpg
#   Normal_28.jpg
#   Normal_29.jpg
#   Normal_3.jpg
#   Normal_30.jpg
#   Normal_31.jpg
#   Normal_32.jpg
#   Normal_33.jpg
#   Normal_34.jpg
#   Normal_35.jpg
#   Normal_36.jpg
#   Normal_37.jpg
#   Normal_38.jpg
#   Normal_39.jpg
#   Normal_4.jpg
#   Normal_40.jpg
#   Normal_41.jpg
#   Normal_42.jpg
#   Normal_43.jpg
#   Normal_44.jpg
#   Normal_45.jpg
#   Normal_46.jpg
#   Normal_47.jpg
#   Normal_48.jpg
#   Normal_49.jpg
#   Normal_5.jpg
#   Normal_50.jpg
#   Normal_51.jpg
#   Normal_52.jpg
#   Normal_53.jpg
#   Normal_54.jpg
#   Normal_55.jpg
#   Normal_56.jpg
#   Normal_57.jpg
#   Normal_58.jpg
#   Normal_59.jpg
#   Normal_6.jpg
#   Normal_60.jpg
#   Normal_61.jpg
#   Normal_62.jpg
#   Normal_63.jpg
#   Normal_64.jpg
#   Normal_65.jpg
#   Normal_66.jpg
#   Normal_67.jpg
#   Normal_68.jpg
#   Normal_69.jpg
#   Normal_7.jpg
#   Normal_70.jpg
#   Normal_71.jpg
#   Normal_72.jpg
#   Normal_73.jpg
#   Normal_74.jpg
#   Normal_75.jpg
#   Normal_76.jpg
#   Normal_77.jpg
#   Normal_78.jpg
#   Normal_79.jpg
#   Normal_8.jpg
#   Normal_80.jpg
#   Normal_81.jpg
#   Normal_82.jpg
#   Normal_83.jpg
#   Normal_84.jpg
#   Normal_85.jpg
#   Normal_86.jpg
#   Normal_87.jpg
#   Normal_88.jpg
#   Normal_89.jpg
#   Normal_9.jpg
#   Normal_90.jpg
#   Normal_91.jpg
#   Normal_92.jpg
#   Normal_93.jpg
#   Normal_94.jpg
#   Normal_95.jpg
#   Normal_96.jpg
#   Normal_97.jpg
#   Normal_98.jpg
#   Normal_99.jpg
#  Osteoporosis
#   Osteoporosis.jpg
#   Osteoporosis_10.jpg
#   Osteoporosis_100.jpg
#   Osteoporosis_101.jpg
#   Osteoporosis_102.jpg
#   Osteoporosis_103.jpg
#   Osteoporosis_104.jpg
#   Osteoporosis_105.jpg
#   Osteoporosis_106.jpg
#   Osteoporosis_107.jpg
#   Osteoporosis_108.jpg
#   Osteoporosis_109.jpg
#   Osteoporosis_11.jpg
#   Osteoporosis_110.jpg
#   Osteoporosis_111.jpg
#   Osteoporosis_112.jpg
#   Osteoporosis_113.jpg
#   Osteoporosis_114.jpg
#   Osteoporosis_115.jpg
#   Osteoporosis_116.jpg
#   Osteoporosis_117.jpg
#   Osteoporosis_118.jpg
#   Osteoporosis_119.jpg
#   Osteoporosis_12.jpg
#   Osteoporosis_120.jpg
#   Osteoporosis_121.jpg
#   Osteoporosis_122.jpg
#   Osteoporosis_123.jpg
#   Osteoporosis_124.jpg
#   Osteoporosis_125.jpg
#   Osteoporosis_126.jpg
#   Osteoporosis_127.jpg
#   Osteoporosis_128.jpg
#   Osteoporosis_129.jpg
#   Osteoporosis_13.jpg
#   Osteoporosis_130.jpg
#   Osteoporosis_131.jpg
#   Osteoporosis_132.jpg
#   Osteoporosis_133.jpg
#   Osteoporosis_134.jpg
#   Osteoporosis_135.jpg
#   Osteoporosis_136.jpg
#   Osteoporosis_137.jpg
#   Osteoporosis_138.jpg
#   Osteoporosis_139.jpg
#   Osteoporosis_14.jpg
#   Osteoporosis_140.jpg
#   Osteoporosis_141.jpg
#   Osteoporosis_142.jpg
#   Osteoporosis_143.jpg
#   Osteoporosis_144.jpg
#   Osteoporosis_145.jpg
#   Osteoporosis_146.jpg
#   Osteoporosis_147.jpg
#   Osteoporosis_148.jpg
#   Osteoporosis_149.jpg
#   Osteoporosis_15.jpg
#   Osteoporosis_150.jpg
#   Osteoporosis_151.jpg
#   Osteoporosis_152.jpg
#   Osteoporosis_153.jpg
#   Osteoporosis_154.jpg
#   Osteoporosis_155.jpg
#   Osteoporosis_156.jpg
#   Osteoporosis_157.jpg
#   Osteoporosis_158.jpg
#   Osteoporosis_159.jpg
#   Osteoporosis_16.jpg
#   Osteoporosis_160.jpg
#   Osteoporosis_161.jpg
#   Osteoporosis_162.jpg
#   Osteoporosis_163.jpg
#   Osteoporosis_164.jpg
#   Osteoporosis_165.jpg
#   Osteoporosis_166.jpg
#   Osteoporosis_167.jpg
#   Osteoporosis_168.jpg
#   Osteoporosis_169.jpg
#   Osteoporosis_17.jpg
#   Osteoporosis_170.jpg
#   Osteoporosis_171.jpg
#   Osteoporosis_172.jpg
#   Osteoporosis_173.jpg
#   Osteoporosis_174.jpg
#   Osteoporosis_175.jpg
#   Osteoporosis_176.jpg
#   Osteoporosis_177.jpg
#   Osteoporosis_178.jpg
#   Osteoporosis_179.jpg
#   Osteoporosis_18.jpg
#   Osteoporosis_180.jpg
#   Osteoporosis_181.jpg
#   Osteoporosis_182.jpg
#   Osteoporosis_183.jpg
#   Osteoporosis_184.jpg
#   Osteoporosis_185.jpg
#   Osteoporosis_186.jpg
#   Osteoporosis_19.jpg
#   Osteoporosis_2.jpg
#   Osteoporosis_20.jpg
#   Osteoporosis_21.jpg
#   Osteoporosis_22.jpg
#   Osteoporosis_23.jpg
#   Osteoporosis_24.jpg
#   Osteoporosis_25.jpg
#   Osteoporosis_26.jpg
#   Osteoporosis_27.jpg
#   Osteoporosis_28.jpg
#   Osteoporosis_29.jpg
#   Osteoporosis_3.jpg
#   Osteoporosis_30.jpg
#   Osteoporosis_31.jpg
#   Osteoporosis_32.jpg
#   Osteoporosis_33.jpg
#   Osteoporosis_34.jpg
#   Osteoporosis_35.jpg
#   Osteoporosis_36.jpg
#   Osteoporosis_37.jpg
#   Osteoporosis_38.jpg
#   Osteoporosis_39.jpg
#   Osteoporosis_4.jpg
#   Osteoporosis_40.jpg
#   Osteoporosis_41.jpg
#   Osteoporosis_42.jpg
#   Osteoporosis_43.jpg
#   Osteoporosis_44.jpg
#   Osteoporosis_45.jpg
#   Osteoporosis_46.jpg
#   Osteoporosis_47.jpg
#   Osteoporosis_48.jpg
#   Osteoporosis_49.jpg
#   Osteoporosis_5.jpg
#   Osteoporosis_50.jpg
#   Osteoporosis_51.jpg
#   Osteoporosis_52.jpg
#   Osteoporosis_53.jpg
#   Osteoporosis_54.jpg
#   Osteoporosis_55.jpg
#   Osteoporosis_56.jpg
#   Osteoporosis_57.jpg
#   Osteoporosis_58.jpg
#   Osteoporosis_59.jpg
#   Osteoporosis_6.jpg
#   Osteoporosis_60.jpg
#   Osteoporosis_61.jpg
#   Osteoporosis_62.jpg
#   Osteoporosis_63.jpg
#   Osteoporosis_64.jpg
#   Osteoporosis_65.jpg
#   Osteoporosis_66.jpg
#   Osteoporosis_67.jpg
#   Osteoporosis_68.jpg
#   Osteoporosis_69.jpg
#   Osteoporosis_7.jpg
#   Osteoporosis_70.jpg
#   Osteoporosis_71.jpg
#   Osteoporosis_72.jpg
#   Osteoporosis_73.jpg
#   Osteoporosis_74.jpg
#   Osteoporosis_75.jpg
#   Osteoporosis_76.jpg
#   Osteoporosis_77.jpg
#   Osteoporosis_78.jpg
#   Osteoporosis_79.jpg
#   Osteoporosis_8.jpg
#   Osteoporosis_80.jpg
#   Osteoporosis_81.jpg
#   Osteoporosis_82.jpg
#   Osteoporosis_83.jpg
#   Osteoporosis_84.jpg
#   Osteoporosis_85.jpg
#   Osteoporosis_86.jpg
#   Osteoporosis_87.jpg
#   Osteoporosis_88.jpg
#   Osteoporosis_89.jpg
#   Osteoporosis_9.jpg
#   Osteoporosis_90.jpg
#   Osteoporosis_91.jpg
#   Osteoporosis_92.jpg
#   Osteoporosis_93.jpg
#   Osteoporosis_94.jpg
#   Osteoporosis_95.jpg
#   Osteoporosis_96.jpg
#   Osteoporosis_97.jpg
#   Osteoporosis_98.jpg
#   Osteoporosis_99.jpg
#
# === BMD Structure ===
# Osteoporosis Knee X-ray
#  normal
#   N1.JPEG
#   N10.JPEG
#   N11.JPEG
#   N12.JPEG
#   N13.jpg
#   N14.jpg
#   N15.jpg
#   N16.jpg
#   N17.jpg
#   N18.jpg
#   N19.jpg
#   N2.JPEG
#   N20.jpg
#   N21.jpg
#   N22.jpg
#   N23.jpg
#   N24.jpg
#   N25.jpg
#   N26.jpg
#   N27.jpg
#   N28.jpg
#   N29.jpg
#   N3.JPEG
#   N30.jpg
#   N31.jpg
#   N32.jpg
#   N33.jpg
#   N34.jpg
#   N35.jpg
#   N36.jpg
#   N4.JPEG
#   N5.JPEG
#   N6.JPEG
#   N7.JPEG
#   N8.JPEG
#   N9.JPEG
#  osteopenia
#   OP1.JPEG
#   OP10.JPEG
#   OP100.jpg
#   OP101.jpg
#   OP102.jpg
#   OP103.jpg
#   OP104.jpg
#   OP105.jpg
#   OP106.jpg
#   OP107.jpg
#   OP108.jpg
#   OP109.jpg
#   OP11.JPEG
#   OP110.jpg
#   OP111.jpg
#   OP112.jpg
#   OP113.jpg
#   OP114.jpg
#   OP115.jpg
#   OP116.jpg
#   OP117.jpg
#   OP118.jpg
#   OP119.jpg
#   OP12.JPEG
#   OP120.jpg
#   OP121.jpg
#   OP122.jpg
#   OP123.jpg
#   OP124.jpg
#   OP125.jpg
#   OP126.jpg
#   OP127.jpg
#   OP128.jpg
#   OP129.jpg
#   OP13.JPEG
#   OP130.jpg
#   OP131.jpg
#   OP132.jpg
#   OP133.jpg
#   OP134.jpg
#   OP135.jpg
#   OP136.jpg
#   OP137.jpg
#   OP138.jpg
#   OP139.jpg
#   OP14.JPEG
#   OP140.jpg
#   OP141.jpg
#   OP142.jpg
#   OP143.jpg
#   OP144.jpg
#   OP145.jpg
#   OP146.jpg
#   OP147.jpg
#   OP148.jpg
#   OP149.jpg
#   OP15.JPEG
#   OP150.jpg
#   OP151.jpg
#   OP152.jpg
#   OP153.jpg
#   OP154.jpg
#   OP16.JPEG
#   OP17.JPEG
#   OP18.JPEG
#   OP19.JPEG
#   OP2.JPEG
#   OP20.JPEG
#   OP21.JPEG
#   OP22.JPEG
#   OP23.JPEG
#   OP24.JPEG
#   OP25.JPEG
#   OP26.JPEG
#   OP27.JPEG
#   OP28.JPEG
#   OP29.JPEG
#   OP3.JPEG
#   OP30.JPEG
#   OP31.JPEG
#   OP32.JPEG
#   OP33.JPEG
#   OP34.JPEG
#   OP35.JPEG
#   OP36.JPEG
#   OP37.JPEG
#   OP38.JPEG
#   OP39.JPEG
#   OP4.JPEG
#   OP40.JPEG
#   OP41.JPEG
#   OP42.JPEG
#   OP43.JPEG
#   OP44.JPEG
#   OP45.jpg
#   OP46.jpg
#   OP47.jpg
#   OP48.jpg
#   OP49.jpg
#   OP5.JPEG
#   OP50.jpg
#   OP51.jpg
#   OP52.jpg
#   OP53.jpg
#   OP54.jpg
#   OP55.jpg
#   OP56.jpg
#   OP57.jpg
#   OP58.jpg
#   OP59.jpg
#   OP6.JPEG
#   OP60.jpg
#   OP61.jpg
#   OP62.jpg
#   OP63.jpg
#   OP64.jpg
#   OP65.jpg
#   OP66.jpg
#   OP67.jpg
#   OP68.jpg
#   OP69.jpg
#   OP7.JPEG
#   OP70.jpg
#   OP71.jpg
#   OP72.jpg
#   OP73.jpg
#   OP74.jpg
#   OP75.jpg
#   OP76.jpg
#   OP77.jpg
#   OP78.jpg
#   OP79.jpg
#   OP8.JPEG
#   OP80.jpg
#   OP81.jpg
#   OP82.jpg
#   OP83.jpg
#   OP84.jpg
#   OP85.jpg
#   OP86.jpg
#   OP87.jpg
#   OP88.jpg
#   OP89.jpg
#   OP9.JPEG
#   OP90.jpg
#   OP91.jpg
#   OP92.jpg
#   OP93.jpg
#   OP94.jpg
#   OP95.jpg
#   OP96.jpg
#   OP97.jpg
#   OP98.jpg
#   OP99.jpg
#  osteoporosis
#   OS1.JPEG
#   OS10.jpg
#   OS11.jpg
#   OS12.jpg
#   OS13.jpg
#   OS14.jpg
#   OS15.jpg
#   OS16.jpg
#   OS17.jpg
#   OS18.jpg
#   OS19.jpg
#   OS2.JPEG
#   OS20.jpg
#   OS21.jpg
#   OS22.jpg
#   OS23.jpg
#   OS24.jpg
#   OS25.jpg
#   OS26.jpg
#   OS27.jpg
#   OS28.jpg
#   OS29.jpg
#   OS3.JPEG
#   OS30.jpg
#   OS31.jpg
#   OS32.jpg
#   OS33.jpg
#   OS34.jpg
#   OS35.jpg
#   OS36.jpg
#   OS37.jpg
#   OS38.jpg
#   OS39.jpg
#   OS4.JPEG
#   OS40.jpg
#   OS41.jpg
#   OS42.jpg
#   OS43.jpg
#   OS44.jpg
#   OS45.jpg
#   OS46.jpg
#   OS47.jpg
#   OS48.jpg
#   OS49.jpg
#   OS5.JPEG
#   OS6.JPEG
#   OS7.JPEG
#   OS8.jpg
#   OS9.jpg
#  patient details.xlsx

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import shutil

class_names = ['Normal', 'Osteopenia', 'Osteoporosis']

def ensemble_predict_from_folder(folder, preprocess_vgg, preprocess_res, preprocess_eff, n_tta=10):
 total = sum(
  len(os.listdir(os.path.join(folder, c)))
  for c in os.listdir(folder)
  if os.path.isdir(os.path.join(folder, c))
 )
 preds_vgg = np.zeros((total, 3))
 preds_res = np.zeros((total, 3))
 preds_eff = np.zeros((total, 3))
 tta_datagen_vgg = ImageDataGenerator(rotation_range=5, horizontal_flip=True, zoom_range=0.03, preprocessing_function=preprocess_vgg)
 tta_datagen_res = ImageDataGenerator(rotation_range=5, horizontal_flip=True, zoom_range=0.03, preprocessing_function=preprocess_res)
 tta_datagen_eff = ImageDataGenerator(rotation_range=5, horizontal_flip=True, zoom_range=0.03, preprocessing_function=preprocess_eff)
 classes = sorted(os.listdir(folder))
 classes = [c for c in classes if os.path.isdir(os.path.join(folder, c))]
 for i in range(n_tta):
  for datagen, preds, model in [
   (tta_datagen_vgg, preds_vgg, m_vgg),
   (tta_datagen_res, preds_res, m_res),
   (tta_datagen_eff, preds_eff, m_eff)
  ]:
   gen = datagen.flow_from_directory(
    folder, target_size=(224, 224), batch_size=1,
    classes=classes, class_mode='categorical', shuffle=False)
   gen.reset()
   preds += model.predict(gen, steps=len(gen), verbose=0)
  print(f" TTA round {i+1}/{n_tta} done")
 preds_vgg /= n_tta
 preds_res /= n_tta
 preds_eff /= n_tta
 ensemble = (preds_vgg + preds_res + preds_eff) / 3
 label_gen = ImageDataGenerator(preprocessing_function=preprocess_vgg).flow_from_directory(
  folder, target_size=(224, 224), batch_size=1,
  classes=classes, class_mode='categorical', shuffle=False)
 y_true = label_gen.classes
 return ensemble, y_true, classes

def show_results(ensemble, y_true, dataset_name, label_names):
 y_pred = np.argmax(ensemble, axis=1)
 acc = np.sum(y_pred == y_true) / len(y_true)
 print(f"\n{'='*50}")
 print(f"Dataset: {dataset_name}")
 print(f"Total images: {len(y_true)}")
 print(f"Accuracy: {acc*100:.2f}%")
 print(f"{'='*50}")
 print(classification_report(y_true, y_pred, target_names=label_names))
 cm = confusion_matrix(y_true, y_pred)
 plt.figure(figsize=(8, 6))
 sns.heatmap(cm, annot=True, fmt='d', xticklabels=label_names, yticklabels=label_names, cmap='Blues')
 plt.xlabel('Predicted')
 plt.ylabel('True')
 plt.title(f'{dataset_name} — {acc*100:.2f}%')
 plt.show()

# ── Test on Orvile dataset (3 classes) ──
print("\nTesting on Orvile dataset...")
orvile_dir = os.path.join(path_orvile, "Osteoporosis Knee X-ray")

# Rename folders to match training classes
rename_map = {
 'normal': 'Normal',
 'osteopenia': 'Osteopenia',
 'osteoporosis': 'Osteoporosis'
}
for old, new in rename_map.items():
 old_path = os.path.join(orvile_dir, old)
 new_path = os.path.join(orvile_dir, new)
 if os.path.exists(old_path) and not os.path.exists(new_path):
  os.rename(old_path, new_path)
  print(f" Renamed {old} -> {new}")

ensemble_orvile, y_true_orvile, _ = ensemble_predict_from_folder(
 orvile_dir,
 tf.keras.applications.vgg19.preprocess_input,
 tf.keras.applications.resnet50.preprocess_input,
 tf.keras.applications.efficientnet.preprocess_input,
 n_tta=10
)
show_results(ensemble_orvile, y_true_orvile, "Orvile Dataset", class_names)

# ── Test on Sachinkumar dataset (2 classes only) ──
print("\nTesting on Sachinkumar dataset (Normal vs Osteoporosis only)...")
sach_dir = os.path.join(path_sach, "Osteoporosis Knee Dataset")
sach_classes = ['Normal', 'Osteoporosis']

ensemble_sach, y_true_sach, _ = ensemble_predict_from_folder(
 sach_dir,
 tf.keras.applications.vgg19.preprocess_input,
 tf.keras.applications.resnet50.preprocess_input,
 tf.keras.applications.efficientnet.preprocess_input,
 n_tta=10
)

# For Sachinkumar remap predictions to only Normal/Osteoporosis
# Class indices from flow_from_directory will be Normal=0, Osteoporosis=1
# But our model outputs 3 classes: Normal=0, Osteopenia=1, Osteoporosis=2
# So we combine Osteopenia predictions into Osteoporosis
sach_ensemble_2class = np.zeros((len(y_true_sach), 2))
sach_ensemble_2class[:, 0] = ensemble_sach[:, 0]  # Normal
sach_ensemble_2class[:, 1] = ensemble_sach[:, 1] + ensemble_sach[:, 2]  # Osteopenia+Osteoporosis -> Osteoporosis

y_pred_sach = np.argmax(sach_ensemble_2class, axis=1)
acc_sach = np.sum(y_pred_sach == y_true_sach) / len(y_true_sach)

print(f"\n{'='*50}")
print(f"Dataset: Sachinkumar (2-class)")
print(f"Total images: {len(y_true_sach)}")
print(f"Accuracy: {acc_sach*100:.2f}%")
print(f"{'='*50}")
print(classification_report(y_true_sach, y_pred_sach, target_names=sach_classes))

cm_sach = confusion_matrix(y_true_sach, y_pred_sach)
plt.figure(figsize=(6, 5))
sns.heatmap(cm_sach, annot=True, fmt='d', xticklabels=sach_classes, yticklabels=sach_classes, cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title(f'Sachinkumar Dataset — {acc_sach*100:.2f}%')
plt.show()
