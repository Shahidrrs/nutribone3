# %% [markdown]
# <a href="https://colab.research.google.com/github/Shahidrrs/nutribone3/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
import matplotlib.pyplot as plt
import numpy as np
import os
import shutil
import random
import seaborn as sns

# %%
import kagglehub

print("Downloading dataset 1 (mohamedgobara)...")
path1 = kagglehub.dataset_download("mohamedgobara/multi-class-knee-osteoporosis-x-ray-dataset")
print("Dataset 1 path:", path1)

print("\nDownloading dataset 2 (stevepython)...")
path2 = kagglehub.dataset_download("stevepython/osteoporosis-knee-xray-dataset")
print("Dataset 2 path:", path2)
# Out:
# Downloading dataset 1 (mohamedgobara)...
# Using Colab cache for faster access to the 'multi-class-knee-osteoporosis-x-ray-dataset' dataset.
# Dataset 1 path: /kaggle/input/multi-class-knee-osteoporosis-x-ray-dataset
#
# Downloading dataset 2 (stevepython)...
# Dataset 2 path: /root/.cache/kagglehub/datasets/stevepython/osteoporosis-knee-xray-dataset/versions/2

# %%
random.seed(42)
import cv2
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img

merged_dir = "/tmp/osteoporosis_merged"
splits     = ['train', 'val', 'test']
classes    = ['Normal', 'Osteopenia', 'Osteoporosis']

# Create folder structure
for split in splits:
    for cls in classes:
        os.makedirs(os.path.join(merged_dir, split, cls), exist_ok=True)

def collect_images(src_dir):
    if not os.path.exists(src_dir):
        print(f"  WARNING: Not found: {src_dir}")
        return []
    return [
        os.path.join(src_dir, f)
        for f in os.listdir(src_dir)
        if f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp'))
    ]

def split_and_copy(image_paths, dst_class_dirs, label_prefix, train=0.75, val=0.15):
    random.shuffle(image_paths)
    n       = len(image_paths)
    n_train = int(n * train)
    n_val   = int(n * val)
    splits_map = {
        'train': image_paths[:n_train],
        'val':   image_paths[n_train:n_train + n_val],
        'test':  image_paths[n_train + n_val:]
    }
    counts = {}
    for split_name, paths in splits_map.items():
        dst = dst_class_dirs[split_name]
        for i, src in enumerate(paths):
            ext = os.path.splitext(src)[1]
            shutil.copy2(src, os.path.join(dst, f"{label_prefix}_{i}{ext}"))
        counts[split_name] = len(paths)
    return counts

def augment_to_target(src_dir, target_count, label_prefix='aug'):
    """
    Augment images in src_dir until target_count is reached.
    Returns list of augmented image arrays saved as files.
    """
    existing = [
        os.path.join(src_dir, f)
        for f in os.listdir(src_dir)
        if f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp'))
    ]
    current = len(existing)
    if current >= target_count:
        return

    aug = ImageDataGenerator(
        rotation_range=15,
        width_shift_range=0.1,
        height_shift_range=0.1,
        zoom_range=0.1,
        horizontal_flip=True,
        brightness_range=[0.85, 1.15],
        fill_mode='nearest'
    )

    needed = target_count - current
    idx    = 0
    print(f"  Augmenting {current} → {target_count} images ({needed} new)...")

    while idx < needed:
        # Pick a random existing image to augment
        src_img_path = random.choice(existing)
        img = load_img(src_img_path, target_size=(224, 224))
        x   = img_to_array(img)
        x   = x.reshape((1,) + x.shape)

        for batch in aug.flow(x, batch_size=1):
            aug_img = batch[0].astype(np.uint8)
            save_path = os.path.join(src_dir, f"{label_prefix}_{idx}.jpg")
            # Save using PIL
            from PIL import Image
            Image.fromarray(aug_img).save(save_path)
            idx += 1
            break  # one augmented image per loop

        if idx >= needed:
            break

    print(f"  Done. Total now: {len(os.listdir(src_dir))} images")

# ── Dataset 1 source paths ──
d1_base    = os.path.join(path1, "OS Collected Data")
d1_sources = {
    'Normal':       os.path.join(d1_base, "Normal"),
    'Osteopenia':   os.path.join(d1_base, "Osteopenia"),
    'Osteoporosis': os.path.join(d1_base, "Osteoporosis"),
}

# ── Dataset 2 source paths ──
d2_sources = {
    'Normal':       os.path.join(path2, "normal", "normal"),
    'Osteoporosis': os.path.join(path2, "osteoporosis", "osteoporosis"),
}

print("=" * 50)
print("Merging and splitting datasets...")
print("=" * 50)

for cls in classes:
    dst_dirs = {s: os.path.join(merged_dir, s, cls) for s in splits}

    imgs_d1 = collect_images(d1_sources.get(cls, ""))
    counts1 = split_and_copy(imgs_d1, dst_dirs, label_prefix="d1")

    imgs_d2 = collect_images(d2_sources.get(cls, ""))
    counts2 = split_and_copy(imgs_d2, dst_dirs, label_prefix="d2")

    total = len(imgs_d1) + len(imgs_d2)
    print(f"\n{cls}: {len(imgs_d1)} from D1 + {len(imgs_d2)} from D2 = {total} total")
    for s in splits:
        n = counts1.get(s, 0) + counts2.get(s, 0)
        print(f"  {s}: {n} images")

# ── Balance Osteopenia by augmenting to match Normal/Osteoporosis ──
print("\n" + "=" * 50)
print("Balancing Osteopenia class via augmentation...")
print("=" * 50)

# Target: match roughly the average of Normal and Osteoporosis in each split
targets = {
    'train': 724,   # match Normal train count
    'val':   144,   # match Normal val count
    'test':  98     # match Normal test count
}

for split_name, target in targets.items():
    osteopenia_dir = os.path.join(merged_dir, split_name, 'Osteopenia')
    print(f"\n{split_name}/Osteopenia:")
    augment_to_target(osteopenia_dir, target, label_prefix='aug')

# ── Final summary ──
print("\n" + "=" * 50)
print("Final balanced dataset summary:")
for split in splits:
    print(f"\n{split}/")
    for cls in classes:
        n = len(os.listdir(os.path.join(merged_dir, split, cls)))
        print(f"  {cls}: {n} images")
# Out:
# ==================================================
# Merging and splitting datasets...
# ==================================================
#
# Normal: 780 from D1 + 186 from D2 = 966 total
#   train: 724 images
#   val: 144 images
#   test: 98 images
#   WARNING: Not found:
#
# Osteopenia: 374 from D1 + 0 from D2 = 374 total
#   train: 280 images
#   val: 56 images
#   test: 38 images
#
# Osteoporosis: 793 from D1 + 186 from D2 = 979 total
#   train: 733 images
#   val: 145 images
#   test: 101 images
#
# ==================================================
# Balancing Osteopenia class via augmentation...
# ==================================================
#
# train/Osteopenia:
#
# val/Osteopenia:
#
# test/Osteopenia:
#
# ==================================================
# Final balanced dataset summary:
#
# train/
#   Normal: 950 images
#   Osteopenia: 779 images
#   Osteoporosis: 984 images
#
# val/
#   Normal: 194 images
#   Osteopenia: 153 images
#   Osteoporosis: 204 images
#
# test/
#   Normal: 135 images
#   Osteopenia: 106 images
#   Osteoporosis: 125 images

# %%
train_dir = os.path.join(merged_dir, 'train')
val_dir   = os.path.join(merged_dir, 'val')
test_dir  = os.path.join(merged_dir, 'test')

train_datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    brightness_range=[0.85, 1.15],
    fill_mode='nearest',
    preprocessing_function=tf.keras.applications.vgg19.preprocess_input
)

val_datagen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.vgg19.preprocess_input
)

test_datagen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.vgg19.preprocess_input
)

train_gen = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=16,
    classes=['Normal', 'Osteopenia', 'Osteoporosis'],
    class_mode='categorical',
    shuffle=True
)

val_gen = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=16,
    classes=['Normal', 'Osteopenia', 'Osteoporosis'],
    class_mode='categorical',
    shuffle=False
)

test_gen = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=1,
    classes=['Normal', 'Osteopenia', 'Osteoporosis'],
    class_mode='categorical',
    shuffle=False
)

print(f"Train : {train_gen.samples} images")
print(f"Val   : {val_gen.samples} images")
print(f"Test  : {test_gen.samples} images")
print(f"Classes: {train_gen.class_indices}")
# Out:
# Found 2713 images belonging to 3 classes.
# Found 551 images belonging to 3 classes.
# Found 366 images belonging to 3 classes.
# Train : 2713 images
# Val   : 551 images
# Test  : 366 images
# Classes: {'Normal': 0, 'Osteopenia': 1, 'Osteoporosis': 2}

# %%
print("\nBuilding VGG-19 model...")

inputs = layers.Input(shape=(224, 224, 3))

base_model = tf.keras.applications.VGG19(
    include_top=False,
    weights='imagenet',
    input_shape=(224, 224, 3)
)

# Stage 1: freeze entire backbone
base_model.trainable = False

x = base_model(inputs, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.5)(x)

x = layers.Dense(512, activation='relu',
                  kernel_regularizer=tf.keras.regularizers.l2(1e-4))(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.4)(x)

x = layers.Dense(256, activation='relu',
                  kernel_regularizer=tf.keras.regularizers.l2(1e-4))(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.3)(x)

outputs = layers.Dense(3, activation='softmax')(x)

model = models.Model(inputs, outputs)
model.summary()
print("\nStage 1 ready — VGG-19 backbone frozen.")
# Out:
# Building VGG-19 model...
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ vgg19 (Functional)              │ (None, 7, 7, 512)      │    20,024,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 3)              │           771 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,424,259 (77.91 MB)
#  Trainable params: 397,315 (1.52 MB)
#  Non-trainable params: 20,026,944 (76.40 MB)
# Stage 1 ready — VGG-19 backbone frozen.

# %%
# Compute class weights
class_weights_array = compute_class_weight(
    class_weight='balanced',
    classes=np.array([0, 1, 2]),
    y=train_gen.classes
)
class_weights = dict(enumerate(class_weights_array))
print("Class weights:", class_weights)

callbacks_s1 = [
    EarlyStopping(monitor='val_loss', patience=6,
                  restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.3,
                      patience=3, min_lr=1e-7, verbose=1),
    ModelCheckpoint("best_stage1.keras", monitor='val_accuracy',
                    save_best_only=True, verbose=1)
]

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

print("\nStage 1: Training head with frozen backbone...")
history1 = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=20,
    callbacks=callbacks_s1,
    class_weight=class_weights
)

print(f"\nBest Stage 1 Val Accuracy: {max(history1.history['val_accuracy']):.4f}")
# Out:
# Class weights: {0: np.float64(0.9519298245614035), 1: np.float64(1.160890029952931), 2: np.float64(0.9190379403794038)}
#
# Stage 1: Training head with frozen backbone...
# Epoch 1/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 586ms/step - accuracy: 0.5224 - loss: 1.3350
# Epoch 1: val_accuracy improved from None to 0.75318, saving model to best_stage1.keras
#
# Epoch 1: finished saving model to best_stage1.keras
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 126s 701ms/step - accuracy: 0.5850 - loss: 1.1739 - val_accuracy: 0.7532 - val_loss: 0.7328 - learning_rate: 0.0010
# Epoch 2/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - accuracy: 0.6677 - loss: 0.9150
# Epoch 2: val_accuracy did not improve from 0.75318
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 103s 606ms/step - accuracy: 0.6587 - loss: 0.8967 - val_accuracy: 0.7368 - val_loss: 0.7064 - learning_rate: 0.0010
# Epoch 3/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 525ms/step - accuracy: 0.6706 - loss: 0.8460
# Epoch 3: val_accuracy improved from 0.75318 to 0.76225, saving model to best_stage1.keras
#
# Epoch 3: finished saving model to best_stage1.keras
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 103s 603ms/step - accuracy: 0.6874 - loss: 0.8150 - val_accuracy: 0.7623 - val_loss: 0.6608 - learning_rate: 0.0010
# Epoch 4/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 530ms/step - accuracy: 0.6957 - loss: 0.7742
# Epoch 4: val_accuracy improved from 0.76225 to 0.81307, saving model to best_stage1.keras
#
# Epoch 4: finished saving model to best_stage1.keras
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 103s 606ms/step - accuracy: 0.6841 - loss: 0.7840 - val_accuracy: 0.8131 - val_loss: 0.6384 - learning_rate: 0.0010
# Epoch 5/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - accuracy: 0.7121 - loss: 0.7397
# Epoch 5: val_accuracy did not improve from 0.81307
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 103s 604ms/step - accuracy: 0.7014 - loss: 0.7577 - val_accuracy: 0.7677 - val_loss: 0.6279 - learning_rate: 0.0010
# Epoch 6/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - accuracy: 0.7276 - loss: 0.7234
# Epoch 6: val_accuracy did not improve from 0.81307
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 104s 610ms/step - accuracy: 0.7147 - loss: 0.7356 - val_accuracy: 0.7858 - val_loss: 0.6319 - learning_rate: 0.0010
# Epoch 7/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - accuracy: 0.7392 - loss: 0.6891
# Epoch 7: val_accuracy improved from 0.81307 to 0.82033, saving model to best_stage1.keras
#
# Epoch 7: finished saving model to best_stage1.keras
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 103s 608ms/step - accuracy: 0.7335 - loss: 0.7007 - val_accuracy: 0.8203 - val_loss: 0.5983 - learning_rate: 0.0010
# Epoch 8/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 525ms/step - accuracy: 0.7055 - loss: 0.7316
# Epoch 8: val_accuracy did not improve from 0.82033
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 102s 597ms/step - accuracy: 0.7177 - loss: 0.7105 - val_accuracy: 0.7677 - val_loss: 0.6181 - learning_rate: 0.0010
# Epoch 9/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 528ms/step - accuracy: 0.7320 - loss: 0.6790
# Epoch 9: val_accuracy did not improve from 0.82033
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 102s 602ms/step - accuracy: 0.7261 - loss: 0.6951 - val_accuracy: 0.7877 - val_loss: 0.5976 - learning_rate: 0.0010
# Epoch 10/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - accuracy: 0.7424 - loss: 0.6638
# Epoch 10: val_accuracy did not improve from 0.82033
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 104s 610ms/step - accuracy: 0.7306 - loss: 0.6855 - val_accuracy: 0.8203 - val_loss: 0.5816 - learning_rate: 0.0010
# Epoch 11/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - accuracy: 0.7336 - loss: 0.6831
# Epoch 11: val_accuracy did not improve from 0.82033
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 104s 613ms/step - accuracy: 0.7247 - loss: 0.7018 - val_accuracy: 0.7858 - val_loss: 0.6237 - learning_rate: 0.0010
# Epoch 12/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 522ms/step - accuracy: 0.7491 - loss: 0.6700
# Epoch 12: val_accuracy did not improve from 0.82033
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 101s 596ms/step - accuracy: 0.7442 - loss: 0.6766 - val_accuracy: 0.8040 - val_loss: 0.5967 - learning_rate: 0.0010
# Epoch 13/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 546ms/step - accuracy: 0.7393 - loss: 0.6892
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
#
# Epoch 13: val_accuracy did not improve from 0.82033
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 107s 628ms/step - accuracy: 0.7390 - loss: 0.6867 - val_accuracy: 0.8040 - val_loss: 0.5986 - learning_rate: 0.0010
# Epoch 14/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 551ms/step - accuracy: 0.7498 - loss: 0.6629
# Epoch 14: val_accuracy did not improve from 0.82033
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 107s 628ms/step - accuracy: 0.7497 - loss: 0.6549 - val_accuracy: 0.8022 - val_loss: 0.5753 - learning_rate: 3.0000e-04
# Epoch 15/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - accuracy: 0.7480 - loss: 0.6479
# Epoch 15: val_accuracy did not improve from 0.82033
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 104s 607ms/step - accuracy: 0.7475 - loss: 0.6513 - val_accuracy: 0.8113 - val_loss: 0.5769 - learning_rate: 3.0000e-04
# Epoch 16/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - accuracy: 0.7461 - loss: 0.6636
# Epoch 16: val_accuracy did not improve from 0.82033
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 103s 607ms/step - accuracy: 0.7545 - loss: 0.6568 - val_accuracy: 0.7804 - val_loss: 0.5914 - learning_rate: 3.0000e-04
# Epoch 17/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - accuracy: 0.7472 - loss: 0.6466
# Epoch 17: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
#
# Epoch 17: val_accuracy did not improve from 0.82033
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 103s 605ms/step - accuracy: 0.7556 - loss: 0.6464 - val_accuracy: 0.7949 - val_loss: 0.5863 - learning_rate: 3.0000e-04
# Epoch 18/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 537ms/step - accuracy: 0.7403 - loss: 0.6592
# Epoch 18: val_accuracy did not improve from 0.82033
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 104s 612ms/step - accuracy: 0.7460 - loss: 0.6555 - val_accuracy: 0.8076 - val_loss: 0.5810 - learning_rate: 9.0000e-05
# Epoch 19/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 525ms/step - accuracy: 0.7561 - loss: 0.6495
# Epoch 19: val_accuracy did not improve from 0.82033
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 102s 600ms/step - accuracy: 0.7619 - loss: 0.6443 - val_accuracy: 0.8113 - val_loss: 0.5742 - learning_rate: 9.0000e-05
# Epoch 20/20
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - accuracy: 0.7746 - loss: 0.6163
# Epoch 20: val_accuracy did not improve from 0.82033
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 103s 608ms/step - accuracy: 0.7674 - loss: 0.6330 - val_accuracy: 0.8113 - val_loss: 0.5630 - learning_rate: 9.0000e-05
# Restoring model weights from the end of the best epoch: 20.
#
# Best Stage 1 Val Accuracy: 0.8203

# %%
print("\nStage 2: Unfreezing block4 + block5 of VGG-19...")

base_model.trainable = True
for layer in base_model.layers:
    layer.trainable = ('block5' in layer.name or
                       'block4' in layer.name)

print("Trainable layers:", [l.name for l in base_model.layers if l.trainable])

callbacks_s2 = [
    EarlyStopping(monitor='val_loss', patience=8,
                  restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.3,
                      patience=4, min_lr=1e-9, verbose=1),
    ModelCheckpoint("best_stage2.keras", monitor='val_accuracy',
                    save_best_only=True, verbose=1)
]

# Lower LR since we're unfreezing more layers
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=2e-6),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=['accuracy']
)


print("\nStage 2: Fine-tuning block4 + block5...")
history2 = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=40,
    callbacks=callbacks_s2,
    class_weight=class_weights
)

model.save("nutribone_vgg19_3class_final.keras")
print(f"\nBest Stage 2 Val Accuracy: {max(history2.history['val_accuracy']):.4f}")
# Out:
# Stage 2: Unfreezing block4 + block5 of VGG-19...
# Trainable layers: ['block4_conv1', 'block4_conv2', 'block4_conv3', 'block4_conv4', 'block4_pool', 'block5_conv1', 'block5_conv2', 'block5_conv3', 'block5_conv4', 'block5_pool']
#
# Stage 2: Fine-tuning block4 + block5...
# Epoch 1/40
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 590ms/step - accuracy: 0.7717 - loss: 0.8072
# Epoch 1: val_accuracy improved from None to 0.81670, saving model to best_stage2.keras
#
# Epoch 1: finished saving model to best_stage2.keras
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 133s 712ms/step - accuracy: 0.7678 - loss: 0.8098 - val_accuracy: 0.8167 - val_loss: 0.7540 - learning_rate: 2.0000e-06
# Epoch 2/40
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 563ms/step - accuracy: 0.7555 - loss: 0.8122
# Epoch 2: val_accuracy did not improve from 0.81670
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 109s 639ms/step - accuracy: 0.7693 - loss: 0.8036 - val_accuracy: 0.8040 - val_loss: 0.7788 - learning_rate: 2.0000e-06
# Epoch 3/40
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 561ms/step - accuracy: 0.7867 - loss: 0.7917
# Epoch 3: val_accuracy improved from 0.81670 to 0.82396, saving model to best_stage2.keras
#
# Epoch 3: finished saving model to best_stage2.keras
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 115s 674ms/step - accuracy: 0.7818 - loss: 0.8000 - val_accuracy: 0.8240 - val_loss: 0.7552 - learning_rate: 2.0000e-06
# Epoch 4/40
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 561ms/step - accuracy: 0.7886 - loss: 0.7894
# Epoch 4: val_accuracy did not improve from 0.82396
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 108s 635ms/step - accuracy: 0.7866 - loss: 0.7865 - val_accuracy: 0.8149 - val_loss: 0.7622 - learning_rate: 2.0000e-06
# Epoch 5/40
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 567ms/step - accuracy: 0.7899 - loss: 0.7822
# Epoch 5: val_accuracy improved from 0.82396 to 0.84211, saving model to best_stage2.keras
#
# Epoch 5: finished saving model to best_stage2.keras
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 113s 666ms/step - accuracy: 0.7785 - loss: 0.7909 - val_accuracy: 0.8421 - val_loss: 0.7322 - learning_rate: 2.0000e-06
# Epoch 6/40
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 575ms/step - accuracy: 0.7950 - loss: 0.7592
# Epoch 6: val_accuracy did not improve from 0.84211
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 111s 654ms/step - accuracy: 0.7917 - loss: 0.7781 - val_accuracy: 0.8240 - val_loss: 0.7500 - learning_rate: 2.0000e-06
# Epoch 7/40
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 573ms/step - accuracy: 0.7937 - loss: 0.7537
# Epoch 7: val_accuracy did not improve from 0.84211
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 110s 647ms/step - accuracy: 0.7995 - loss: 0.7534 - val_accuracy: 0.8185 - val_loss: 0.7413 - learning_rate: 2.0000e-06
# Epoch 8/40
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 572ms/step - accuracy: 0.8034 - loss: 0.7640
# Epoch 8: val_accuracy improved from 0.84211 to 0.85299, saving model to best_stage2.keras
#
# Epoch 8: finished saving model to best_stage2.keras
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 113s 662ms/step - accuracy: 0.7987 - loss: 0.7699 - val_accuracy: 0.8530 - val_loss: 0.7307 - learning_rate: 2.0000e-06
# Epoch 9/40
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 579ms/step - accuracy: 0.7911 - loss: 0.7603
# Epoch 9: val_accuracy did not improve from 0.85299
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 112s 657ms/step - accuracy: 0.8065 - loss: 0.7497 - val_accuracy: 0.8457 - val_loss: 0.7475 - learning_rate: 2.0000e-06
# Epoch 10/40
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 572ms/step - accuracy: 0.8139 - loss: 0.7398
# Epoch 10: val_accuracy did not improve from 0.85299
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 110s 646ms/step - accuracy: 0.8153 - loss: 0.7443 - val_accuracy: 0.8167 - val_loss: 0.7656 - learning_rate: 2.0000e-06
# Epoch 11/40
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 568ms/step - accuracy: 0.8090 - loss: 0.7513
# Epoch 11: val_accuracy did not improve from 0.85299
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 109s 643ms/step - accuracy: 0.8153 - loss: 0.7457 - val_accuracy: 0.8403 - val_loss: 0.7434 - learning_rate: 2.0000e-06
# Epoch 12/40
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 563ms/step - accuracy: 0.8097 - loss: 0.7519
# Epoch 12: val_accuracy improved from 0.85299 to 0.85662, saving model to best_stage2.keras
#
# Epoch 12: finished saving model to best_stage2.keras
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 115s 676ms/step - accuracy: 0.8153 - loss: 0.7369 - val_accuracy: 0.8566 - val_loss: 0.7176 - learning_rate: 2.0000e-06
# Epoch 13/40
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 566ms/step - accuracy: 0.8236 - loss: 0.7243
# Epoch 13: val_accuracy did not improve from 0.85662
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 109s 640ms/step - accuracy: 0.8282 - loss: 0.7242 - val_accuracy: 0.8385 - val_loss: 0.7336 - learning_rate: 2.0000e-06
# Epoch 14/40
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 570ms/step - accuracy: 0.8143 - loss: 0.7365
# Epoch 14: val_accuracy did not improve from 0.85662
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 110s 645ms/step - accuracy: 0.8198 - loss: 0.7297 - val_accuracy: 0.8294 - val_loss: 0.7659 - learning_rate: 2.0000e-06
# Epoch 15/40
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 557ms/step - accuracy: 0.8359 - loss: 0.7253
# Epoch 15: val_accuracy did not improve from 0.85662
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 108s 632ms/step - accuracy: 0.8231 - loss: 0.7250 - val_accuracy: 0.8348 - val_loss: 0.7586 - learning_rate: 2.0000e-06
# Epoch 16/40
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 567ms/step - accuracy: 0.8225 - loss: 0.7237
# Epoch 16: ReduceLROnPlateau reducing learning rate to 5.999999984851456e-07.
#
# Epoch 16: val_accuracy did not improve from 0.85662
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 109s 639ms/step - accuracy: 0.8220 - loss: 0.7247 - val_accuracy: 0.8367 - val_loss: 0.7430 - learning_rate: 2.0000e-06
# Epoch 17/40
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 567ms/step - accuracy: 0.8275 - loss: 0.7173
# Epoch 17: val_accuracy did not improve from 0.85662
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 109s 641ms/step - accuracy: 0.8363 - loss: 0.7111 - val_accuracy: 0.8530 - val_loss: 0.7309 - learning_rate: 6.0000e-07
# Epoch 18/40
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 585ms/step - accuracy: 0.8263 - loss: 0.7236
# Epoch 18: val_accuracy did not improve from 0.85662
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 112s 661ms/step - accuracy: 0.8341 - loss: 0.7179 - val_accuracy: 0.8494 - val_loss: 0.7334 - learning_rate: 6.0000e-07
# Epoch 19/40
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 568ms/step - accuracy: 0.8232 - loss: 0.7072
# Epoch 19: val_accuracy did not improve from 0.85662
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 109s 643ms/step - accuracy: 0.8330 - loss: 0.7052 - val_accuracy: 0.8530 - val_loss: 0.7333 - learning_rate: 6.0000e-07
# Epoch 20/40
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 0s 561ms/step - accuracy: 0.8277 - loss: 0.7405
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1.8000000636675396e-07.
#
# Epoch 20: val_accuracy did not improve from 0.85662
# 170/170 ━━━━━━━━━━━━━━━━━━━━ 109s 636ms/step - accuracy: 0.8334 - loss: 0.7236 - val_accuracy: 0.8385 - val_loss: 0.7365 - learning_rate: 6.0000e-07
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 12.
#
# Best Stage 2 Val Accuracy: 0.8566

# %%
total_train_loss = history1.history['loss'] + history2.history['loss']
total_val_loss   = history1.history['val_loss'] + history2.history['val_loss']
total_train_acc  = history1.history['accuracy'] + history2.history['accuracy']
total_val_acc    = history1.history['val_accuracy'] + history2.history['val_accuracy']
split_point      = len(history1.history['loss']) - 1

plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(total_train_loss, label='Train Loss', color='royalblue')
plt.plot(total_val_loss, label='Val Loss', color='orange', linestyle='--')
plt.axvline(x=split_point, color='gray', linestyle=':', label='Fine-Tune Split')
plt.legend()
plt.title('Loss (Stage 1 + Stage 2)')
plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.subplot(1, 2, 2)
plt.plot(total_train_acc, label='Train Accuracy', color='royalblue')
plt.plot(total_val_acc, label='Val Accuracy', color='orange', linestyle='--')
plt.axvline(x=split_point, color='gray', linestyle=':', label='Fine-Tune Split')
plt.legend()
plt.title('Accuracy (Stage 1 + Stage 2)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

plt.tight_layout()
plt.show()

# %%
print("\nLoading best model...")
eval_model = tf.keras.models.load_model("best_stage2.keras")

test_gen.reset()
preds  = eval_model.predict(test_gen, steps=len(test_gen), verbose=1)
y_pred = np.argmax(preds, axis=1)
y_true = test_gen.classes
class_names = ['Normal', 'Osteopenia', 'Osteoporosis']

print("\n--- Classification Report ---")
print(classification_report(y_true, y_pred, target_names=class_names))

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d',
            xticklabels=class_names,
            yticklabels=class_names,
            cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix — Test Set')
plt.show()

print(f"\nFinal Test Accuracy: {np.sum(y_pred == y_true) / len(y_true) * 100:.2f}%")
# Out:
# Loading best model...
# 366/366 ━━━━━━━━━━━━━━━━━━━━ 11s 27ms/step
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#       Normal       0.90      0.84      0.87       135
#   Osteopenia       0.92      0.75      0.82       106
# Osteoporosis       0.74      0.91      0.81       125
#
#     accuracy                           0.84       366
#    macro avg       0.85      0.83      0.84       366
# weighted avg       0.85      0.84      0.84       366
# Final Test Accuracy: 83.61%

# %%
print("\nApplying TTA (20 rounds)...")

tta_datagen = ImageDataGenerator(
    rotation_range=5,
    horizontal_flip=True,
    zoom_range=0.03,
    preprocessing_function=tf.keras.applications.vgg19.preprocess_input
)

tta_rounds = 20
tta_preds  = np.zeros((test_gen.samples, 3))

for i in range(tta_rounds):
    tta_gen = tta_datagen.flow_from_directory(
        test_dir,
        target_size=(224, 224),
        batch_size=1,
        classes=['Normal', 'Osteopenia', 'Osteoporosis'],
        class_mode='categorical',
        shuffle=False
    )
    tta_gen.reset()
    tta_preds += eval_model.predict(tta_gen, steps=len(tta_gen), verbose=0)
    print(f"TTA round {i+1}/{tta_rounds} done")

tta_preds /= tta_rounds
y_pred_tta = np.argmax(tta_preds, axis=1)

print("\n--- TTA Classification Report ---")
print(classification_report(y_true, y_pred_tta, target_names=class_names))

cm_tta = confusion_matrix(y_true, y_pred_tta)
plt.figure(figsize=(8, 6))
sns.heatmap(cm_tta, annot=True, fmt='d',
            xticklabels=class_names,
            yticklabels=class_names,
            cmap='Greens')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix — With TTA (20 rounds)')
plt.show()

print(f"\nFinal TTA Accuracy: {np.sum(y_pred_tta == y_true) / len(y_true) * 100:.2f}%")
# Out:
# Applying TTA (20 rounds)...
# Found 366 images belonging to 3 classes.
# TTA round 1/20 done
# Found 366 images belonging to 3 classes.
# TTA round 2/20 done
# Found 366 images belonging to 3 classes.
# TTA round 3/20 done
# Found 366 images belonging to 3 classes.
# TTA round 4/20 done
# Found 366 images belonging to 3 classes.
# TTA round 5/20 done
# Found 366 images belonging to 3 classes.
# TTA round 6/20 done
# Found 366 images belonging to 3 classes.
# TTA round 7/20 done
# Found 366 images belonging to 3 classes.
# TTA round 8/20 done
# Found 366 images belonging to 3 classes.
# TTA round 9/20 done
# Found 366 images belonging to 3 classes.
# TTA round 10/20 done
# Found 366 images belonging to 3 classes.
# TTA round 11/20 done
# Found 366 images belonging to 3 classes.
# TTA round 12/20 done
# Found 366 images belonging to 3 classes.
# TTA round 13/20 done
# Found 366 images belonging to 3 classes.
# TTA round 14/20 done
# Found 366 images belonging to 3 classes.
# TTA round 15/20 done
# Found 366 images belonging to 3 classes.
# TTA round 16/20 done
# Found 366 images belonging to 3 classes.
# TTA round 17/20 done
# Found 366 images belonging to 3 classes.
# TTA round 18/20 done
# Found 366 images belonging to 3 classes.
# TTA round 19/20 done
# Found 366 images belonging to 3 classes.
# TTA round 20/20 done
#
# --- TTA Classification Report ---
#               precision    recall  f1-score   support
#
#       Normal       0.92      0.82      0.87       135
#   Osteopenia       0.86      0.86      0.86       106
# Osteoporosis       0.79      0.88      0.83       125
#
#     accuracy                           0.85       366
#    macro avg       0.86      0.85      0.85       366
# weighted avg       0.86      0.85      0.85       366
# Final TTA Accuracy: 85.25%
