# %% [markdown]
# <a href="https://colab.research.google.com/github/Shahidrrs/nutribone3/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
import matplotlib.pyplot as plt
import numpy as np
import os
import shutil
import random
import seaborn as sns

# %%
import kagglehub

print("Downloading dataset 1 (mohamedgobara)...")
path1 = kagglehub.dataset_download("mohamedgobara/multi-class-knee-osteoporosis-x-ray-dataset")
print("Dataset 1 path:", path1)

print("\nDownloading dataset 2 (stevepython)...")
path2 = kagglehub.dataset_download("stevepython/osteoporosis-knee-xray-dataset")
print("Dataset 2 path:", path2)
# Out:
# Downloading dataset 1 (mohamedgobara)...
# Using Colab cache for faster access to the 'multi-class-knee-osteoporosis-x-ray-dataset' dataset.
# Dataset 1 path: /kaggle/input/multi-class-knee-osteoporosis-x-ray-dataset
#
# Downloading dataset 2 (stevepython)...
# Using Colab cache for faster access to the 'osteoporosis-knee-xray-dataset' dataset.
# Dataset 2 path: /kaggle/input/osteoporosis-knee-xray-dataset

# %%
random.seed(42)
import cv2
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img

merged_dir = "/tmp/osteoporosis_merged"
splits     = ['train', 'val', 'test']
classes    = ['Normal', 'Osteopenia', 'Osteoporosis']

# Create folder structure
for split in splits:
    for cls in classes:
        os.makedirs(os.path.join(merged_dir, split, cls), exist_ok=True)

def collect_images(src_dir):
    if not os.path.exists(src_dir):
        print(f"  WARNING: Not found: {src_dir}")
        return []
    return [
        os.path.join(src_dir, f)
        for f in os.listdir(src_dir)
        if f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp'))
    ]

def split_and_copy(image_paths, dst_class_dirs, label_prefix, train=0.75, val=0.15):
    random.shuffle(image_paths)
    n       = len(image_paths)
    n_train = int(n * train)
    n_val   = int(n * val)
    splits_map = {
        'train': image_paths[:n_train],
        'val':   image_paths[n_train:n_train + n_val],
        'test':  image_paths[n_train + n_val:]
    }
    counts = {}
    for split_name, paths in splits_map.items():
        dst = dst_class_dirs[split_name]
        for i, src in enumerate(paths):
            ext = os.path.splitext(src)[1]
            shutil.copy2(src, os.path.join(dst, f"{label_prefix}_{i}{ext}"))
        counts[split_name] = len(paths)
    return counts

def augment_to_target(src_dir, target_count, label_prefix='aug'):
    """
    Augment images in src_dir until target_count is reached.
    Returns list of augmented image arrays saved as files.
    """
    existing = [
        os.path.join(src_dir, f)
        for f in os.listdir(src_dir)
        if f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp'))
    ]
    current = len(existing)
    if current >= target_count:
        return

    aug = ImageDataGenerator(
        rotation_range=15,
        width_shift_range=0.1,
        height_shift_range=0.1,
        zoom_range=0.1,
        horizontal_flip=True,
        brightness_range=[0.85, 1.15],
        fill_mode='nearest'
    )

    needed = target_count - current
    idx    = 0
    print(f"  Augmenting {current} → {target_count} images ({needed} new)...")

    while idx < needed:
        # Pick a random existing image to augment
        src_img_path = random.choice(existing)
        img = load_img(src_img_path, target_size=(224, 224))
        x   = img_to_array(img)
        x   = x.reshape((1,) + x.shape)

        for batch in aug.flow(x, batch_size=1):
            aug_img = batch[0].astype(np.uint8)
            save_path = os.path.join(src_dir, f"{label_prefix}_{idx}.jpg")
            # Save using PIL
            from PIL import Image
            Image.fromarray(aug_img).save(save_path)
            idx += 1
            break  # one augmented image per loop

        if idx >= needed:
            break

    print(f"  Done. Total now: {len(os.listdir(src_dir))} images")

# ── Dataset 1 source paths ──
d1_base    = os.path.join(path1, "OS Collected Data")
d1_sources = {
    'Normal':       os.path.join(d1_base, "Normal"),
    'Osteopenia':   os.path.join(d1_base, "Osteopenia"),
    'Osteoporosis': os.path.join(d1_base, "Osteoporosis"),
}

# ── Dataset 2 source paths ──
d2_sources = {
    'Normal':       os.path.join(path2, "normal", "normal"),
    'Osteoporosis': os.path.join(path2, "osteoporosis", "osteoporosis"),
}

print("=" * 50)
print("Merging and splitting datasets...")
print("=" * 50)

for cls in classes:
    dst_dirs = {s: os.path.join(merged_dir, s, cls) for s in splits}

    imgs_d1 = collect_images(d1_sources.get(cls, ""))
    counts1 = split_and_copy(imgs_d1, dst_dirs, label_prefix="d1")

    imgs_d2 = collect_images(d2_sources.get(cls, ""))
    counts2 = split_and_copy(imgs_d2, dst_dirs, label_prefix="d2")

    total = len(imgs_d1) + len(imgs_d2)
    print(f"\n{cls}: {len(imgs_d1)} from D1 + {len(imgs_d2)} from D2 = {total} total")
    for s in splits:
        n = counts1.get(s, 0) + counts2.get(s, 0)
        print(f"  {s}: {n} images")

# ── Balance Osteopenia by augmenting to match Normal/Osteoporosis ──
print("\n" + "=" * 50)
print("Balancing Osteopenia class via augmentation...")
print("=" * 50)

# Target: match roughly the average of Normal and Osteoporosis in each split
targets = {
    'train': 724,   # match Normal train count
    'val':   144,   # match Normal val count
    'test':  98     # match Normal test count
}

for split_name, target in targets.items():
    osteopenia_dir = os.path.join(merged_dir, split_name, 'Osteopenia')
    print(f"\n{split_name}/Osteopenia:")
    augment_to_target(osteopenia_dir, target, label_prefix='aug')

# ── Final summary ──
print("\n" + "=" * 50)
print("Final balanced dataset summary:")
for split in splits:
    print(f"\n{split}/")
    for cls in classes:
        n = len(os.listdir(os.path.join(merged_dir, split, cls)))
        print(f"  {cls}: {n} images")
# Out:
# ==================================================
# Merging and splitting datasets...
# ==================================================
#
# Normal: 780 from D1 + 186 from D2 = 966 total
#   train: 724 images
#   val: 144 images
#   test: 98 images
#   WARNING: Not found:
#
# Osteopenia: 374 from D1 + 0 from D2 = 374 total
#   train: 280 images
#   val: 56 images
#   test: 38 images
#
# Osteoporosis: 793 from D1 + 186 from D2 = 979 total
#   train: 733 images
#   val: 145 images
#   test: 101 images
#
# ==================================================
# Balancing Osteopenia class via augmentation...
# ==================================================
#
# train/Osteopenia:
#
# val/Osteopenia:
#
# test/Osteopenia:
#
# ==================================================
# Final balanced dataset summary:
#
# train/
#   Normal: 1037 images
#   Osteopenia: 779 images
#   Osteoporosis: 1078 images
#
# val/
#   Normal: 207 images
#   Osteopenia: 153 images
#   Osteoporosis: 220 images
#
# test/
#   Normal: 147 images
#   Osteopenia: 106 images
#   Osteoporosis: 137 images

# %%
train_dir = os.path.join(merged_dir, 'train')
val_dir   = os.path.join(merged_dir, 'val')
test_dir  = os.path.join(merged_dir, 'test')

train_datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    brightness_range=[0.85, 1.15],
    fill_mode='nearest',
    preprocessing_function=tf.keras.applications.vgg19.preprocess_input
)

val_datagen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.vgg19.preprocess_input
)

test_datagen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.vgg19.preprocess_input
)

train_gen = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=16,
    classes=['Normal', 'Osteopenia', 'Osteoporosis'],
    class_mode='categorical',
    shuffle=True
)

val_gen = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=16,
    classes=['Normal', 'Osteopenia', 'Osteoporosis'],
    class_mode='categorical',
    shuffle=False
)

test_gen = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=1,
    classes=['Normal', 'Osteopenia', 'Osteoporosis'],
    class_mode='categorical',
    shuffle=False
)

print(f"Train : {train_gen.samples} images")
print(f"Val   : {val_gen.samples} images")
print(f"Test  : {test_gen.samples} images")
print(f"Classes: {train_gen.class_indices}")
# Out:
# Found 2894 images belonging to 3 classes.
# Found 580 images belonging to 3 classes.
# Found 390 images belonging to 3 classes.
# Train : 2894 images
# Val   : 580 images
# Test  : 390 images
# Classes: {'Normal': 0, 'Osteopenia': 1, 'Osteoporosis': 2}

# %%
print("\nBuilding VGG-19 model...")

inputs = layers.Input(shape=(224, 224, 3))

base_model = tf.keras.applications.VGG19(
    include_top=False,
    weights='imagenet',
    input_shape=(224, 224, 3)
)

# Stage 1: freeze entire backbone
base_model.trainable = False

x = base_model(inputs, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.5)(x)

x = layers.Dense(512, activation='relu',
                  kernel_regularizer=tf.keras.regularizers.l2(1e-4))(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.4)(x)

x = layers.Dense(256, activation='relu',
                  kernel_regularizer=tf.keras.regularizers.l2(1e-4))(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.3)(x)

outputs = layers.Dense(3, activation='softmax')(x)

model = models.Model(inputs, outputs)
model.summary()
print("\nStage 1 ready — VGG-19 backbone frozen.")
# Out:
# Building VGG-19 model...
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ vgg19 (Functional)              │ (None, 7, 7, 512)      │    20,024,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 3)              │           771 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,424,259 (77.91 MB)
#  Trainable params: 397,315 (1.52 MB)
#  Non-trainable params: 20,026,944 (76.40 MB)
# Stage 1 ready — VGG-19 backbone frozen.

# %%
# Compute class weights
class_weights_array = compute_class_weight(
    class_weight='balanced',
    classes=np.array([0, 1, 2]),
    y=train_gen.classes
)
class_weights = dict(enumerate(class_weights_array))
print("Class weights:", class_weights)

callbacks_s1 = [
    EarlyStopping(monitor='val_loss', patience=6,
                  restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.3,
                      patience=3, min_lr=1e-7, verbose=1),
    ModelCheckpoint("best_stage1.keras", monitor='val_accuracy',
                    save_best_only=True, verbose=1)
]

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

print("\nStage 1: Training head with frozen backbone...")
history1 = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=20,
    callbacks=callbacks_s1,
    class_weight=class_weights
)

print(f"\nBest Stage 1 Val Accuracy: {max(history1.history['val_accuracy']):.4f}")
# Out:
# Class weights: {0: np.float64(0.9302475088396014), 1: np.float64(1.2383397518185708), 2: np.float64(0.8948670377241806)}
#
# Stage 1: Training head with frozen backbone...
# Epoch 1/20
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 573ms/step - accuracy: 0.5399 - loss: 1.3452
# Epoch 1: val_accuracy improved from None to 0.74483, saving model to best_stage1.keras
#
# Epoch 1: finished saving model to best_stage1.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 129s 677ms/step - accuracy: 0.5950 - loss: 1.1719 - val_accuracy: 0.7448 - val_loss: 0.6967 - learning_rate: 0.0010
# Epoch 2/20
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - accuracy: 0.6593 - loss: 0.9001
# Epoch 2: val_accuracy improved from 0.74483 to 0.76724, saving model to best_stage1.keras
#
# Epoch 2: finished saving model to best_stage1.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 117s 647ms/step - accuracy: 0.6603 - loss: 0.8879 - val_accuracy: 0.7672 - val_loss: 0.6809 - learning_rate: 0.0010
# Epoch 3/20
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - accuracy: 0.6689 - loss: 0.8310
# Epoch 3: val_accuracy improved from 0.76724 to 0.77931, saving model to best_stage1.keras
#
# Epoch 3: finished saving model to best_stage1.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 109s 604ms/step - accuracy: 0.6856 - loss: 0.8108 - val_accuracy: 0.7793 - val_loss: 0.6594 - learning_rate: 0.0010
# Epoch 4/20
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - accuracy: 0.6863 - loss: 0.7797
# Epoch 4: val_accuracy did not improve from 0.77931
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 109s 603ms/step - accuracy: 0.6987 - loss: 0.7517 - val_accuracy: 0.7776 - val_loss: 0.6527 - learning_rate: 0.0010
# Epoch 5/20
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 545ms/step - accuracy: 0.6787 - loss: 0.7902
# Epoch 5: val_accuracy did not improve from 0.77931
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 112s 619ms/step - accuracy: 0.6990 - loss: 0.7594 - val_accuracy: 0.7638 - val_loss: 0.6543 - learning_rate: 0.0010
# Epoch 6/20
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - accuracy: 0.7156 - loss: 0.7327
# Epoch 6: val_accuracy improved from 0.77931 to 0.78448, saving model to best_stage1.keras
#
# Epoch 6: finished saving model to best_stage1.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 111s 613ms/step - accuracy: 0.7156 - loss: 0.7256 - val_accuracy: 0.7845 - val_loss: 0.6175 - learning_rate: 0.0010
# Epoch 7/20
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - accuracy: 0.7414 - loss: 0.6871
# Epoch 7: val_accuracy did not improve from 0.78448
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 108s 594ms/step - accuracy: 0.7319 - loss: 0.7052 - val_accuracy: 0.7534 - val_loss: 0.6488 - learning_rate: 0.0010
# Epoch 8/20
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - accuracy: 0.
20
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 528ms/step - accuracy: 0.7617 - loss: 0.6508
# Epoch 20: val_accuracy did not improve from 0.81724
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 109s 600ms/step - accuracy: 0.7554 - loss: 0.6501 - val_accuracy: 0.8017 - val_loss: 0.5535 - learning_rate: 3.0000e-04
# Restoring model weights from the end of the best epoch: 15.
#
# Best Stage 1 Val Accuracy: 0.8172

# %%
print("\nStage 2: Unfreezing block4 + block5 of VGG-19...")

base_model.trainable = True
for layer in base_model.layers:
    layer.trainable = 'block5' in layer.name or 'block4' in layer.name

print("Trainable layers:", [l.name for l in base_model.layers if l.trainable])

callbacks_s2 = [
    EarlyStopping(monitor='val_loss', patience=8,
                  restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.3,
                      patience=4, min_lr=1e-9, verbose=1),
    ModelCheckpoint("best_stage2.keras", monitor='val_accuracy',
                    save_best_only=True, verbose=1)
]

# Lower LR since we're unfreezing more layers
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=5e-6),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

print("\nStage 2: Fine-tuning block4 + block5...")
history2 = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=40,
    callbacks=callbacks_s2,
    class_weight=class_weights
)

model.save("nutribone_vgg19_3class_final.keras")
print(f"\nBest Stage 2 Val Accuracy: {max(history2.history['val_accuracy']):.4f}")
# Out:
# Stage 2: Unfreezing block4 + block5 of VGG-19...
# Trainable layers: ['block4_conv1', 'block4_conv2', 'block4_conv3', 'block4_conv4', 'block4_pool', 'block5_conv1', 'block5_conv2', 'block5_conv3', 'block5_conv4', 'block5_pool']
#
# Stage 2: Fine-tuning block4 + block5...
# Epoch 1/40
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 627ms/step - accuracy: 0.7575 - loss: 0.6452
# Epoch 1: val_accuracy improved from None to 0.82931, saving model to best_stage2.keras
#
# Epoch 1: finished saving model to best_stage2.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 144s 721ms/step - accuracy: 0.7592 - loss: 0.6431 - val_accuracy: 0.8293 - val_loss: 0.5197 - learning_rate: 5.0000e-06
# Epoch 2/40
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 571ms/step - accuracy: 0.7633 - loss: 0.6030
# Epoch 2: val_accuracy did not improve from 0.82931
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 117s 647ms/step - accuracy: 0.7678 - loss: 0.6104 - val_accuracy: 0.8276 - val_loss: 0.5228 - learning_rate: 5.0000e-06
# Epoch 3/40
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 566ms/step - accuracy: 0.7700 - loss: 0.6032
# Epoch 3: val_accuracy did not improve from 0.82931
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 140s 639ms/step - accuracy: 0.7778 - loss: 0.5921 - val_accuracy: 0.8034 - val_loss: 0.5234 - learning_rate: 5.0000e-06
# Epoch 4/40
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 568ms/step - accuracy: 0.7829 - loss: 0.5801
# Epoch 4: val_accuracy improved from 0.82931 to 0.83793, saving model to best_stage2.keras
#
# Epoch 4: finished saving model to best_stage2.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 117s 645ms/step - accuracy: 0.7878 - loss: 0.5685 - val_accuracy: 0.8379 - val_loss: 0.5161 - learning_rate: 5.0000e-06
# Epoch 5/40
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 563ms/step - accuracy: 0.8121 - loss: 0.5232
# Epoch 5: val_accuracy did not improve from 0.83793
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 115s 636ms/step - accuracy: 0.7958 - loss: 0.5546 - val_accuracy: 0.8328 - val_loss: 0.5146 - learning_rate: 5.0000e-06
# Epoch 6/40
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 570ms/step - accuracy: 0.7913 - loss: 0.5272
# Epoch 6: val_accuracy improved from 0.83793 to 0.84655, saving model to best_stage2.keras
#
# Epoch 6: finished saving model to best_stage2.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 118s 648ms/step - accuracy: 0.8006 - loss: 0.5257 - val_accuracy: 0.8466 - val_loss: 0.5012 - learning_rate: 5.0000e-06
# Epoch 7/40
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 569ms/step - accuracy: 0.8219 - loss: 0.5334
# Epoch 7: val_accuracy improved from 0.84655 to 0.85000, saving model to best_stage2.keras
#
# Epoch 7: finished saving model to best_stage2.keras
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 117s
40
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 574ms/step - accuracy: 0.8733 - loss: 0.4294
# Epoch 19: val_accuracy did not improve from 0.89655
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 118s 649ms/step - accuracy: 0.8715 - loss: 0.4267 - val_accuracy: 0.8362 - val_loss: 0.4916 - learning_rate: 5.0000e-06
# Epoch 20/40
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 575ms/step - accuracy: 0.8764 - loss: 0.3936
# Epoch 20: val_accuracy did not improve from 0.89655
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 118s 648ms/step - accuracy: 0.8704 - loss: 0.4020 - val_accuracy: 0.8914 - val_loss: 0.4025 - learning_rate: 5.0000e-06
# Epoch 21/40
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 564ms/step - accuracy: 0.8660 - loss: 0.4081
# Epoch 21: val_accuracy did not improve from 0.89655
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 115s 636ms/step - accuracy: 0.8652 - loss: 0.4142 - val_accuracy: 0.8862 - val_loss: 0.4005 - learning_rate: 5.0000e-06
# Epoch 22/40
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 574ms/step - accuracy: 0.8733 - loss: 0.4029
# Epoch 22: val_accuracy did not improve from 0.89655
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 117s 647ms/step - accuracy: 0.8701 - loss: 0.4137 - val_accuracy: 0.8759 - val_loss: 0.4260 - learning_rate: 5.0000e-06
# Epoch 23/40
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 579ms/step - accuracy: 0.8720 - loss: 0.4272
# Epoch 23: val_accuracy did not improve from 0.89655
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 119s 655ms/step - accuracy: 0.8777 - loss: 0.4078 - val_accuracy: 0.8759 - val_loss: 0.4360 - learning_rate: 5.0000e-06
# Epoch 24/40
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 570ms/step - accuracy: 0.8809 - loss: 0.4008
# Epoch 24: val_accuracy did not improve from 0.89655
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 116s 642ms/step - accuracy: 0.8780 - loss: 0.3934 - val_accuracy: 0.8672 - val_loss: 0.4371 - learning_rate: 5.0000e-06
# Epoch 25/40
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 567ms/step - accuracy: 0.8776 - loss: 0.4045
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1.4999999621068127e-06.
#
# Epoch 25: val_accuracy did not improve from 0.89655
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 116s 643ms/step - accuracy: 0.8801 - loss: 0.3912 - val_accuracy: 0.8448 - val_loss: 0.4825 - learning_rate: 5.0000e-06
# Epoch 26/40
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 571ms/step - accuracy: 0.8784 - loss: 0.3957
# Epoch 26: val_accuracy did not improve from 0.89655
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 117s 644ms/step - accuracy: 0.8822 - loss: 0.3854 - val_accuracy: 0.8845 - val_loss: 0.4196 - learning_rate: 1.5000e-06
# Epoch 27/40
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 578ms/step - accuracy: 0.8976 - loss: 0.3617
# Epoch 27: val_accuracy did not improve from 0.89655
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 118s 651ms/step - accuracy: 0.8946 - loss: 0.3626 - val_accuracy: 0.8793 - val_loss: 0.4096 - learning_rate: 1.5000e-06
# Epoch 28/40
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 581ms/step - accuracy: 0.8899 - loss: 0.3718
# Epoch 28: val_accuracy did not improve from 0.89655
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 118s 654ms/step - accuracy: 0.8905 - loss: 0.3650 - val_accuracy: 0.8690 - val_loss: 0.4393 - learning_rate: 1.5000e-06
# Epoch 29/40
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 0s 572ms/step - accuracy: 0.8916 - loss: 0.3602
# Epoch 29: ReduceLROnPlateau reducing learning rate to 4.4999998181083353e-07.
#
# Epoch 29: val_accuracy did not improve from 0.89655
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 117s 645ms/step - accuracy: 0.8825 - loss: 0.3792 - val_accuracy: 0.8845 - val_loss: 0.4122 - learning_rate: 1.5000e-06
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 21.
#
# Best Stage 2 Val Accuracy: 0.8966

# %%
total_train_loss = history1.history['loss'] + history2.history['loss']
total_val_loss   = history1.history['val_loss'] + history2.history['val_loss']
total_train_acc  = history1.history['accuracy'] + history2.history['accuracy']
total_val_acc    = history1.history['val_accuracy'] + history2.history['val_accuracy']
split_point      = len(history1.history['loss']) - 1

plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(total_train_loss, label='Train Loss', color='royalblue')
plt.plot(total_val_loss, label='Val Loss', color='orange', linestyle='--')
plt.axvline(x=split_point, color='gray', linestyle=':', label='Fine-Tune Split')
plt.legend()
plt.title('Loss (Stage 1 + Stage 2)')
plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.subplot(1, 2, 2)
plt.plot(total_train_acc, label='Train Accuracy', color='royalblue')
plt.plot(total_val_acc, label='Val Accuracy', color='orange', linestyle='--')
plt.axvline(x=split_point, color='gray', linestyle=':', label='Fine-Tune Split')
plt.legend()
plt.title('Accuracy (Stage 1 + Stage 2)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

plt.tight_layout()
plt.show()

# %%
print("\nLoading best model...")
eval_model = tf.keras.models.load_model("best_stage2.keras")

test_gen.reset()
preds  = eval_model.predict(test_gen, steps=len(test_gen), verbose=1)
y_pred = np.argmax(preds, axis=1)
y_true = test_gen.classes
class_names = ['Normal', 'Osteopenia', 'Osteoporosis']

print("\n--- Classification Report ---")
print(classification_report(y_true, y_pred, target_names=class_names))

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d',
            xticklabels=class_names,
            yticklabels=class_names,
            cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix — Test Set')
plt.show()

print(f"\nFinal Test Accuracy: {np.sum(y_pred == y_true) / len(y_true) * 100:.2f}%")
# Out:
# Loading best model...
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#       Normal       0.90      0.93      0.91       147
#   Osteopenia       0.97      0.74      0.84       106
# Osteoporosis       0.82      0.93      0.87       137
#
#     accuracy                           0.88       390
#    macro avg       0.90      0.87      0.87       390
# weighted avg       0.89      0.88      0.88       390
# Final Test Accuracy: 87.95%

# %%
print("\nApplying TTA (20 rounds)...")

tta_datagen = ImageDataGenerator(
    rotation_range=8,
    horizontal_flip=True,
    zoom_range=0.08,
    preprocessing_function=tf.keras.applications.vgg19.preprocess_input
)

tta_rounds = 20
tta_preds  = np.zeros((test_gen.samples, 3))

for i in range(tta_rounds):
    tta_gen = tta_datagen.flow_from_directory(
        test_dir,
        target_size=(224, 224),
        batch_size=1,
        classes=['Normal', 'Osteopenia', 'Osteoporosis'],
        class_mode='categorical',
        shuffle=False
    )
    tta_gen.reset()
    tta_preds += eval_model.predict(tta_gen, steps=len(tta_gen), verbose=0)
    print(f"TTA round {i+1}/{tta_rounds} done")

tta_preds /= tta_rounds
y_pred_tta = np.argmax(tta_preds, axis=1)

print("\n--- TTA Classification Report ---")
print(classification_report(y_true, y_pred_tta, target_names=class_names))

cm_tta = confusion_matrix(y_true, y_pred_tta)
plt.figure(figsize=(8, 6))
sns.heatmap(cm_tta, annot=True, fmt='d',
            xticklabels=class_names,
            yticklabels=class_names,
            cmap='Greens')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix — With TTA (20 rounds)')
plt.show()

print(f"\nFinal TTA Accuracy: {np.sum(y_pred_tta == y_true) / len(y_true) * 100:.2f}%")
# Out:
# Applying TTA (20 rounds)...
# Found 390 images belonging to 3 classes.
# TTA round 1/20 done
# Found 390 images belonging to 3 classes.
# TTA round 2/20 done
# Found 390 images belonging to 3 classes.
# TTA round 3/20 done
# Found 390 images belonging to 3 classes.
# TTA round 4/20 done
# Found 390 images belonging to 3 classes.
# TTA round 5/20 done
# Found 390 images belonging to 3 classes.
# TTA round 6/20 done
# Found 390 images belonging to 3 classes.
# TTA round 7/20 done
# Found 390 images belonging to 3 classes.
# TTA round 8/20 done
# Found 390 images belonging to 3 classes.
# TTA round 9/20 done
# Found 390 images belonging to 3 classes.
# TTA round 10/20 done
# Found 390 images belonging to 3 classes.
# TTA round 11/20 done
# Found 390 images belonging to 3 classes.
# TTA round 12/20 done
# Found 390 images belonging to 3 classes.
# TTA round 13/20 done
# Found 390 images belonging to 3 classes.
# TTA round 14/20 done
# Found 390 images belonging to 3 classes.
# TTA round 15/20 done
# Found 390 images belonging to 3 classes.
# TTA round 16/20 done
# Found 390 images belonging to 3 classes.
# TTA round 17/20 done
# Found 390 images belonging to 3 classes.
# TTA round 18/20 done
# Found 390 images belonging to 3 classes.
# TTA round 19/20 done
# Found 390 images belonging to 3 classes.
# TTA round 20/20 done
#
# --- TTA Classification Report ---
#               precision    recall  f1-score   support
#
#       Normal       0.91      0.93      0.92       147
#   Osteopenia       0.81      0.94      0.87       106
# Osteoporosis       0.93      0.79      0.85       137
#
#     accuracy                           0.88       390
#    macro avg       0.88      0.89      0.88       390
# weighted avg       0.89      0.88      0.88       390
# Final TTA Accuracy: 88.21%
