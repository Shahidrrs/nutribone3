# %% [markdown]
# <a href="https://colab.research.google.com/github/Shahidrrs/nutribone3/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
import matplotlib.pyplot as plt
import numpy as np
import os
import shutil
import random
import seaborn as sns

# %%
import kagglehub

print("Downloading dataset 1 (mohamedgobara)...")
path1 = kagglehub.dataset_download("mohamedgobara/multi-class-knee-osteoporosis-x-ray-dataset")
print("Dataset 1 path:", path1)

print("\nDownloading dataset 2 (stevepython)...")
path2 = kagglehub.dataset_download("stevepython/osteoporosis-knee-xray-dataset")
print("Dataset 2 path:", path2)
# Out:
# Downloading dataset 1 (mohamedgobara)...
# Downloading to /root/.cache/kagglehub/datasets/mohamedgobara/multi-class-knee-osteoporosis-x-ray-dataset/1.archive...
# 100%|██████████| 1.17G/1.17G [00:11<00:00, 112MB/s]
# Extracting files...
# Dataset 1 path: /root/.cache/kagglehub/datasets/mohamedgobara/multi-class-knee-osteoporosis-x-ray-dataset/versions/1
#
# Downloading dataset 2 (stevepython)...
# Downloading to /root/.cache/kagglehub/datasets/stevepython/osteoporosis-knee-xray-dataset/2.archive...
# 100%|██████████| 280M/280M [00:02<00:00, 126MB/s]
# Extracting files...
# Dataset 2 path: /root/.cache/kagglehub/datasets/stevepython/osteoporosis-knee-xray-dataset/versions/2

# %%
random.seed(42)
import cv2
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img

merged_dir = "/tmp/osteoporosis_merged"
splits     = ['train', 'val', 'test']
classes    = ['Normal', 'Osteopenia', 'Osteoporosis']

# Create folder structure
for split in splits:
    for cls in classes:
        os.makedirs(os.path.join(merged_dir, split, cls), exist_ok=True)

def collect_images(src_dir):
    if not os.path.exists(src_dir):
        print(f"  WARNING: Not found: {src_dir}")
        return []
    return [
        os.path.join(src_dir, f)
        for f in os.listdir(src_dir)
        if f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp'))
    ]

def split_and_copy(image_paths, dst_class_dirs, label_prefix, train=0.75, val=0.15):
    random.shuffle(image_paths)
    n       = len(image_paths)
    n_train = int(n * train)
    n_val   = int(n * val)
    splits_map = {
        'train': image_paths[:n_train],
        'val':   image_paths[n_train:n_train + n_val],
        'test':  image_paths[n_train + n_val:]
    }
    counts = {}
    for split_name, paths in splits_map.items():
        dst = dst_class_dirs[split_name]
        for i, src in enumerate(paths):
            ext = os.path.splitext(src)[1]
            shutil.copy2(src, os.path.join(dst, f"{label_prefix}_{i}{ext}"))
        counts[split_name] = len(paths)
    return counts

def augment_to_target(src_dir, target_count, label_prefix='aug'):
    """
    Augment images in src_dir until target_count is reached.
    Returns list of augmented image arrays saved as files.
    """
    existing = [
        os.path.join(src_dir, f)
        for f in os.listdir(src_dir)
        if f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp'))
    ]
    current = len(existing)
    if current >= target_count:
        return

    aug = ImageDataGenerator(
        rotation_range=15,
        width_shift_range=0.1,
        height_shift_range=0.1,
        zoom_range=0.1,
        horizontal_flip=True,
        brightness_range=[0.85, 1.15],
        fill_mode='nearest'
    )

    needed = target_count - current
    idx    = 0
    print(f"  Augmenting {current} → {target_count} images ({needed} new)...")

    while idx < needed:
        # Pick a random existing image to augment
        src_img_path = random.choice(existing)
        img = load_img(src_img_path, target_size=(224, 224))
        x   = img_to_array(img)
        x   = x.reshape((1,) + x.shape)

        for batch in aug.flow(x, batch_size=1):
            aug_img = batch[0].astype(np.uint8)
            save_path = os.path.join(src_dir, f"{label_prefix}_{idx}.jpg")
            # Save using PIL
            from PIL import Image
            Image.fromarray(aug_img).save(save_path)
            idx += 1
            break  # one augmented image per loop

        if idx >= needed:
            break

    print(f"  Done. Total now: {len(os.listdir(src_dir))} images")

# ── Dataset 1 source paths ──
d1_base    = os.path.join(path1, "OS Collected Data")
d1_sources = {
    'Normal':       os.path.join(d1_base, "Normal"),
    'Osteopenia':   os.path.join(d1_base, "Osteopenia"),
    'Osteoporosis': os.path.join(d1_base, "Osteoporosis"),
}

# ── Dataset 2 source paths ──
d2_sources = {
    'Normal':       os.path.join(path2, "normal", "normal"),
    'Osteoporosis': os.path.join(path2, "osteoporosis", "osteoporosis"),
}

print("=" * 50)
print("Merging and splitting datasets...")
print("=" * 50)

for cls in classes:
    dst_dirs = {s: os.path.join(merged_dir, s, cls) for s in splits}

    imgs_d1 = collect_images(d1_sources.get(cls, ""))
    counts1 = split_and_copy(imgs_d1, dst_dirs, label_prefix="d1")

    imgs_d2 = collect_images(d2_sources.get(cls, ""))
    counts2 = split_and_copy(imgs_d2, dst_dirs, label_prefix="d2")

    total = len(imgs_d1) + len(imgs_d2)
    print(f"\n{cls}: {len(imgs_d1)} from D1 + {len(imgs_d2)} from D2 = {total} total")
    for s in splits:
        n = counts1.get(s, 0) + counts2.get(s, 0)
        print(f"  {s}: {n} images")

# ── Balance Osteopenia by augmenting to match Normal/Osteoporosis ──
print("\n" + "=" * 50)
print("Balancing Osteopenia class via augmentation...")
print("=" * 50)

# Target: match roughly the average of Normal and Osteoporosis in each split
targets = {
    'train': 724,   # match Normal train count
    'val':   144,   # match Normal val count
    'test':  98     # match Normal test count
}

for split_name, target in targets.items():
    osteopenia_dir = os.path.join(merged_dir, split_name, 'Osteopenia')
    print(f"\n{split_name}/Osteopenia:")
    augment_to_target(osteopenia_dir, target, label_prefix='aug')

# ── Final summary ──
print("\n" + "=" * 50)
print("Final balanced dataset summary:")
for split in splits:
    print(f"\n{split}/")
    for cls in classes:
        n = len(os.listdir(os.path.join(merged_dir, split, cls)))
        print(f"  {cls}: {n} images")
# Out:
# ==================================================
# Merging and splitting datasets...
# ==================================================
#
# Normal: 780 from D1 + 186 from D2 = 966 total
#   train: 724 images
#   val: 144 images
#   test: 98 images
#   WARNING: Not found:
#
# Osteopenia: 374 from D1 + 0 from D2 = 374 total
#   train: 280 images
#   val: 56 images
#   test: 38 images
#
# Osteoporosis: 793 from D1 + 186 from D2 = 979 total
#   train: 733 images
#   val: 145 images
#   test: 101 images
#
# ==================================================
# Balancing Osteopenia class via augmentation...
# ==================================================
#
# train/Osteopenia:
#   Augmenting 280 → 724 images (444 new)...
#   Done. Total now: 724 images
#
# val/Osteopenia:
#   Augmenting 56 → 144 images (88 new)...
#   Done. Total now: 144 images
#
# test/Osteopenia:
#   Augmenting 38 → 98 images (60 new)...
#   Done. Total now: 98 images
#
# ==================================================
# Final balanced dataset summary:
#
# train/
#   Normal: 724 images
#   Osteopenia: 724 images
#   Osteoporosis: 733 images
#
# val/
#   Normal: 144 images
#   Osteopenia: 144 images
#   Osteoporosis: 145 images
#
# test/
#   Normal: 98 images
#   Osteopenia: 98 images
#   Osteoporosis: 101 images

# %%
train_dir = os.path.join(merged_dir, 'train')
val_dir   = os.path.join(merged_dir, 'val')
test_dir  = os.path.join(merged_dir, 'test')

train_datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    brightness_range=[0.85, 1.15],
    fill_mode='nearest',
    preprocessing_function=tf.keras.applications.vgg19.preprocess_input
)

val_datagen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.vgg19.preprocess_input
)

test_datagen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.vgg19.preprocess_input
)

train_gen = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=16,
    classes=['Normal', 'Osteopenia', 'Osteoporosis'],
    class_mode='categorical',
    shuffle=True
)

val_gen = val_datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=16,
    classes=['Normal', 'Osteopenia', 'Osteoporosis'],
    class_mode='categorical',
    shuffle=False
)

test_gen = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=1,
    classes=['Normal', 'Osteopenia', 'Osteoporosis'],
    class_mode='categorical',
    shuffle=False
)

print(f"Train : {train_gen.samples} images")
print(f"Val   : {val_gen.samples} images")
print(f"Test  : {test_gen.samples} images")
print(f"Classes: {train_gen.class_indices}")
# Out:
# Found 2181 images belonging to 3 classes.
# Found 433 images belonging to 3 classes.
# Found 297 images belonging to 3 classes.
# Train : 2181 images
# Val   : 433 images
# Test  : 297 images
# Classes: {'Normal': 0, 'Osteopenia': 1, 'Osteoporosis': 2}

# %%
print("\nBuilding VGG-19 model...")

inputs = layers.Input(shape=(224, 224, 3))

base_model = tf.keras.applications.VGG19(
    include_top=False,
    weights='imagenet',
    input_shape=(224, 224, 3)
)

# Stage 1: freeze entire backbone
base_model.trainable = False

x = base_model(inputs, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.5)(x)

x = layers.Dense(512, activation='relu',
                  kernel_regularizer=tf.keras.regularizers.l2(1e-4))(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.4)(x)

x = layers.Dense(256, activation='relu',
                  kernel_regularizer=tf.keras.regularizers.l2(1e-4))(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.3)(x)

outputs = layers.Dense(3, activation='softmax')(x)

model = models.Model(inputs, outputs)
model.summary()
print("\nStage 1 ready — VGG-19 backbone frozen.")
# Out:
# Building VGG-19 model...
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ vgg19 (Functional)              │ (None, 7, 7, 512)      │    20,024,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 3)              │           771 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,424,259 (77.91 MB)
#  Trainable params: 397,315 (1.52 MB)
#  Non-trainable params: 20,026,944 (76.40 MB)
# Stage 1 ready — VGG-19 backbone frozen.

# %%
# Compute class weights
class_weights_array = compute_class_weight(
    class_weight='balanced',
    classes=np.array([0, 1, 2]),
    y=train_gen.classes
)
class_weights = dict(enumerate(class_weights_array))
print("Class weights:", class_weights)

callbacks_s1 = [
    EarlyStopping(monitor='val_loss', patience=6,
                  restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.3,
                      patience=3, min_lr=1e-7, verbose=1),
    ModelCheckpoint("best_stage1.keras", monitor='val_accuracy',
                    save_best_only=True, verbose=1)
]

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

print("\nStage 1: Training head with frozen backbone...")
history1 = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=20,
    callbacks=callbacks_s1,
    class_weight=class_weights
)

print(f"\nBest Stage 1 Val Accuracy: {max(history1.history['val_accuracy']):.4f}")
# Out:
# Class weights: {0: np.float64(1.0041436464088398), 1: np.float64(1.0041436464088398), 2: np.float64(0.9918144611186903)}
#
# Stage 1: Training head with frozen backbone...
# Epoch 1/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 576ms/step - accuracy: 0.5311 - loss: 1.3416
# Epoch 1: val_accuracy improved from None to 0.71132, saving model to best_stage1.keras
#
# Epoch 1: finished saving model to best_stage1.keras
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 106s 680ms/step - accuracy: 0.5915 - loss: 1.1825 - val_accuracy: 0.7113 - val_loss: 0.8196 - learning_rate: 0.0010
# Epoch 2/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 541ms/step - accuracy: 0.6625 - loss: 0.9118
# Epoch 2: val_accuracy improved from 0.71132 to 0.76443, saving model to best_stage1.keras
#
# Epoch 2: finished saving model to best_stage1.keras
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 85s 616ms/step - accuracy: 0.6680 - loss: 0.9218 - val_accuracy: 0.7644 - val_loss: 0.7160 - learning_rate: 0.0010
# Epoch 3/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.6818 - loss: 0.8376
# Epoch 3: val_accuracy improved from 0.76443 to 0.77136, saving model to best_stage1.keras
#
# Epoch 3: finished saving model to best_stage1.keras
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 85s 619ms/step - accuracy: 0.6823 - loss: 0.8423 - val_accuracy: 0.7714 - val_loss: 0.6650 - learning_rate: 0.0010
# Epoch 4/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 538ms/step - accuracy: 0.7064 - loss: 0.7447
# Epoch 4: val_accuracy improved from 0.77136 to 0.77367, saving model to best_stage1.keras
#
# Epoch 4: finished saving model to best_stage1.keras
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 84s 612ms/step - accuracy: 0.7015 - loss: 0.7736 - val_accuracy: 0.7737 - val_loss: 0.6907 - learning_rate: 0.0010
# Epoch 5/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 538ms/step - accuracy: 0.6715 - loss: 0.8328
# Epoch 5: val_accuracy improved from 0.77367 to 0.78984, saving model to best_stage1.keras
#
# Epoch 5: finished saving model to best_stage1.keras
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 84s 611ms/step - accuracy: 0.6823 - loss: 0.8091 - val_accuracy: 0.7898 - val_loss: 0.6564 - learning_rate: 0.0010
# Epoch 6/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - accuracy: 0.6993 - loss: 0.7460
# Epoch 6: val_accuracy did not improve from 0.78984
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 83s 604ms/step - accuracy: 0.7093 - loss: 0.7446 - val_accuracy: 0.7829 - val_loss: 0.6497 - learning_rate: 0.0010
# Epoch 7/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 530ms/step - accuracy: 0.7135 - loss: 0.7409
# Epoch 7: val_accuracy did not improve from 0.78984
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 83s 603ms/step - accuracy: 0.7185 - loss: 0.7295 - val_accuracy: 0.7737 - val_loss: 0.6445 - learning_rate: 0.0010
# Epoch 8/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - accuracy: 0.7190 - loss: 0.7250
# Epoch 8: val_accuracy did not improve from 0.78984
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 84s 612ms/step - accuracy: 0.7208 - loss: 0.7291 - val_accuracy: 0.7621 - val_loss: 0.6564 - learning_rate: 0.0010
# Epoch 9/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - accuracy: 0.6968 - loss: 0.7498
# Epoch 9: val_accuracy did not improve from 0.78984
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 83s 607ms/step - accuracy: 0.7176 - loss: 0.7097 - val_accuracy: 0.7598 - val_loss: 0.6369 - learning_rate: 0.0010
# Epoch 10/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 549ms/step - accuracy: 0.7331 - loss: 0.7488
# Epoch 10: val_accuracy did not improve from 0.78984
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 85s 621ms/step - accuracy: 0.7295 - loss: 0.7119 - val_accuracy: 0.7852 - val_loss: 0.6279 - learning_rate: 0.0010
# Epoch 11/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 528ms/step - accuracy: 0.7414 - loss: 0.7253
# Epoch 11: val_accuracy did not improve from 0.78984
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 82s 601ms/step - accuracy: 0.7345 - loss: 0.7312 - val_accuracy: 0.7691 - val_loss: 0.6455 - learning_rate: 0.0010
# Epoch 12/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 543ms/step - accuracy: 0.7342 - loss: 0.7099
# Epoch 12: val_accuracy did not improve from 0.78984
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 84s 611ms/step - accuracy: 0.7391 - loss: 0.6919 - val_accuracy: 0.7760 - val_loss: 0.6384 - learning_rate: 0.0010
# Epoch 13/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - accuracy: 0.7485 - loss: 0.6806
# Epoch 13: val_accuracy improved from 0.78984 to 0.80600, saving model to best_stage1.keras
#
# Epoch 13: finished saving model to best_stage1.keras
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 85s 613ms/step - accuracy: 0.7400 - loss: 0.7009 - val_accuracy: 0.8060 - val_loss: 0.6166 - learning_rate: 0.0010
# Epoch 14/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 537ms/step - accuracy: 0.7311 - loss: 0.6803
# Epoch 14: val_accuracy did not improve from 0.80600
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 83s 609ms/step - accuracy: 0.7322 - loss: 0.6901 - val_accuracy: 0.7783 - val_loss: 0.6455 - learning_rate: 0.0010
# Epoch 15/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 525ms/step - accuracy: 0.7457 - loss: 0.6791
# Epoch 15: val_accuracy did not improve from 0.80600
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 81s 593ms/step - accuracy: 0.7552 - loss: 0.6707 - val_accuracy: 0.7829 - val_loss: 0.6717 - learning_rate: 0.0010
# Epoch 16/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - accuracy: 0.7490 - loss: 0.7035
# Epoch 16: val_accuracy did not improve from 0.80600
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 83s 601ms/step - accuracy: 0.7565 - loss: 0.6747 - val_accuracy: 0.7783 - val_loss: 0.6116 - learning_rate: 0.0010
# Epoch 17/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - accuracy: 0.7590 - loss: 0.6775
# Epoch 17: val_accuracy improved from 0.80600 to 0.81293, saving model to best_stage1.keras
#
# Epoch 17: finished saving model to best_stage1.keras
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 84s 613ms/step - accuracy: 0.7579 - loss: 0.6752 - val_accuracy: 0.8129 - val_loss: 0.5855 - learning_rate: 0.0010
# Epoch 18/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 551ms/step - accuracy: 0.7171 - loss: 0.7218
# Epoch 18: val_accuracy did not improve from 0.81293
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 85s 624ms/step - accuracy: 0.7359 - loss: 0.6947 - val_accuracy: 0.7968 - val_loss: 0.6152 - learning_rate: 0.0010
# Epoch 19/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - accuracy: 0.7554 - loss: 0.6862
# Epoch 19: val_accuracy did not improve from 0.81293
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 84s 614ms/step - accuracy: 0.7519 - loss: 0.6829 - val_accuracy: 0.7875 - val_loss: 0.6335 - learning_rate: 0.0010
# Epoch 20/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 545ms/step - accuracy: 0.7759 - loss: 0.6406
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
#
# Epoch 20: val_accuracy did not improve from 0.81293
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 85s 614ms/step - accuracy: 0.7556 - loss: 0.6609 - val_accuracy: 0.8037 - val_loss: 0.6186 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 17.
#
# Best Stage 1 Val Accuracy: 0.8129

# %%
print("\nStage 2: Unfreezing block4 + block5 of VGG-19...")

base_model.trainable = True
for layer in base_model.layers:
    layer.trainable = 'block5' in layer.name or 'block4' in layer.name

print("Trainable layers:", [l.name for l in base_model.layers if l.trainable])

callbacks_s2 = [
    EarlyStopping(monitor='val_loss', patience=8,
                  restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.3,
                      patience=4, min_lr=1e-9, verbose=1),
    ModelCheckpoint("best_stage2.keras", monitor='val_accuracy',
                    save_best_only=True, verbose=1)
]

# Lower LR since we're unfreezing more layers
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=5e-6),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

print("\nStage 2: Fine-tuning block4 + block5...")
history2 = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=40,
    callbacks=callbacks_s2,
    class_weight=class_weights
)

model.save("nutribone_vgg19_3class_final.keras")
print(f"\nBest Stage 2 Val Accuracy: {max(history2.history['val_accuracy']):.4f}")
# Out:
# Stage 2: Unfreezing VGG-19 block5 only...
# Trainable layers: ['block5_conv1', 'block5_conv2', 'block5_conv3', 'block5_conv4', 'block5_pool']
#
# Stage 2: Fine-tuning...
# Epoch 1/40
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 586ms/step - accuracy: 0.7532 - loss: 0.6565
# Epoch 1: val_accuracy improved from None to 0.78753, saving model to best_stage2.keras
#
# Epoch 1: finished saving model to best_stage2.keras
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 102s 681ms/step - accuracy: 0.7515 - loss: 0.6536 - val_accuracy: 0.7875 - val_loss: 0.5926 - learning_rate: 1.0000e-05
# Epoch 2/40
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 545ms/step - accuracy: 0.7627 - loss: 0.6473
# Epoch 2: val_accuracy improved from 0.78753 to 0.80139, saving model to best_stage2.keras
#
# Epoch 2: finished saving model to best_stage2.keras
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 85s 617ms/step - accuracy: 0.7607 - loss: 0.6463 - val_accuracy: 0.8014 - val_loss: 0.5723 - learning_rate: 1.0000e-05
# Epoch 3/40
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - accuracy: 0.7801 - loss: 0.6210
# Epoch 3: val_accuracy improved from 0.80139 to 0.81293, saving model to best_stage2.keras
#
# Epoch 3: finished saving model to best_stage2.keras
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 87s 630ms/step - accuracy: 0.7772 - loss: 0.6098 - val_accuracy: 0.8129 - val_loss: 0.5504 - learning_rate: 1.0000e-05
# Epoch 4/40
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 554ms/step - accuracy: 0.7989 - loss: 0.5847
# Epoch 4: val_accuracy did not improve from 0.81293
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 141s 626ms/step - accuracy: 0.7996 - loss: 0.5904 - val_accuracy: 0.7829 - val_loss: 0.5938 - learning_rate: 1.0000e-05
# Epoch 5/40
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 553ms/step - accuracy: 0.7813 - loss: 0.6019
# Epoch 5: val_accuracy did not improve from 0.81293
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 85s 624ms/step - accuracy: 0.7937 - loss: 0.5772 - val_accuracy: 0.7968 - val_loss: 0.5899 - learning_rate: 1.0000e-05
# Epoch 6/40
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 547ms/step - accuracy: 0.7983 - loss: 0.5877
# Epoch 6: val_accuracy did not improve from 0.81293
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 85s 617ms/step - accuracy: 0.8074 - loss: 0.5657 - val_accuracy: 0.8014 - val_loss: 0.5652 - learning_rate: 1.0000e-05
# Epoch 7/40
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 553ms/step - accuracy: 0.8192 - loss: 0.5206
# Epoch 7: ReduceLROnPlateau reducing learning rate to 2.9999999242136253e-06.
#
# Epoch 7: val_accuracy did not improve from 0.81293
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 86s 627ms/step - accuracy: 0.8157 - loss: 0.5273 - val_accuracy: 0.8106 - val_loss: 0.5902 - learning_rate: 1.0000e-05
# Epoch 8/40
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 551ms/step - accuracy: 0.7930 - loss: 0.5469
# Epoch 8: val_accuracy improved from 0.81293 to 0.81986, saving model to best_stage2.keras
#
# Epoch 8: finished saving model to best_stage2.keras
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 85s 623ms/step - accuracy: 0.8056 - loss: 0.5358 - val_accuracy: 0.8199 - val_loss: 0.5438 - learning_rate: 3.0000e-06
# Epoch 9/40
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - accuracy: 0.8094 - loss: 0.5238
# Epoch 9: val_accuracy did not improve from 0.81986
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 84s 610ms/step - accuracy: 0.8138 - loss: 0.5318 - val_accuracy: 0.8106 - val_loss: 0.5479 - learning_rate: 3.0000e-06
# Epoch 10/40
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 551ms/step - accuracy: 0.8237 - loss: 0.5324
# Epoch 10: val_accuracy did not improve from 0.81986
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 85s 622ms/step - accuracy: 0.8226 - loss: 0.5324 - val_accuracy: 0.8199 - val_loss: 0.5717 - learning_rate: 3.0000e-06
# Epoch 11/40
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 551ms/step - accuracy: 0.8260 - loss: 0.5147
# Epoch 11: val_accuracy did not improve from 0.81986
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 85s 621ms/step - accuracy: 0.8207 - loss: 0.5177 - val_accuracy: 0.8176 - val_loss: 0.5699 - learning_rate: 3.0000e-06
# Epoch 12/40
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 551ms/step - accuracy: 0.8273 - loss: 0.5224
# Epoch 12: ReduceLROnPlateau reducing learning rate to 8.999999636216671e-07.
#
# Epoch 12: val_accuracy improved from 0.81986 to 0.82448, saving model to best_stage2.keras
#
# Epoch 12: finished saving model to best_stage2.keras
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 86s 630ms/step - accuracy: 0.8340 - loss: 0.5165 - val_accuracy: 0.8245 - val_loss: 0.5726 - learning_rate: 3.0000e-06
# Epoch 13/40
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 555ms/step - accuracy: 0.8288 - loss: 0.5031
# Epoch 13: val_accuracy did not improve from 0.82448
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 86s 627ms/step - accuracy: 0.8235 - loss: 0.5100 - val_accuracy: 0.8222 - val_loss: 0.5649 - learning_rate: 9.0000e-07
# Epoch 14/40
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 545ms/step - accuracy: 0.8337 - loss: 0.5118
# Epoch 14: val_accuracy did not improve from 0.82448
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 84s 615ms/step - accuracy: 0.8377 - loss: 0.4964 - val_accuracy: 0.8245 - val_loss: 0.5681 - learning_rate: 9.0000e-07
# Epoch 15/40
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 552ms/step - accuracy: 0.8482 - loss: 0.4962
# Epoch 15: val_accuracy improved from 0.82448 to 0.82910, saving model to best_stage2.keras
#
# Epoch 15: finished saving model to best_stage2.keras
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 86s 625ms/step - accuracy: 0.8414 - loss: 0.4974 - val_accuracy: 0.8291 - val_loss: 0.5641 - learning_rate: 9.0000e-07
# Epoch 16/40
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - accuracy: 0.8308 - loss: 0.4971
# Epoch 16: ReduceLROnPlateau reducing learning rate to 2.6999999249710525e-07.
#
# Epoch 16: val_accuracy did not improve from 0.82910
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 84s 609ms/step - accuracy: 0.8345 - loss: 0.4954 - val_accuracy: 0.8291 - val_loss: 0.5615 - learning_rate: 9.0000e-07
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 8.
#
# Best Stage 2 Val Accuracy: 0.8291

# %%
total_train_loss = history1.history['loss'] + history2.history['loss']
total_val_loss   = history1.history['val_loss'] + history2.history['val_loss']
total_train_acc  = history1.history['accuracy'] + history2.history['accuracy']
total_val_acc    = history1.history['val_accuracy'] + history2.history['val_accuracy']
split_point      = len(history1.history['loss']) - 1

plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(total_train_loss, label='Train Loss', color='royalblue')
plt.plot(total_val_loss, label='Val Loss', color='orange', linestyle='--')
plt.axvline(x=split_point, color='gray', linestyle=':', label='Fine-Tune Split')
plt.legend()
plt.title('Loss (Stage 1 + Stage 2)')
plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.subplot(1, 2, 2)
plt.plot(total_train_acc, label='Train Accuracy', color='royalblue')
plt.plot(total_val_acc, label='Val Accuracy', color='orange', linestyle='--')
plt.axvline(x=split_point, color='gray', linestyle=':', label='Fine-Tune Split')
plt.legend()
plt.title('Accuracy (Stage 1 + Stage 2)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

plt.tight_layout()
plt.show()

# %%
print("\nLoading best model...")
eval_model = tf.keras.models.load_model("best_stage2.keras")

test_gen.reset()
preds  = eval_model.predict(test_gen, steps=len(test_gen), verbose=1)
y_pred = np.argmax(preds, axis=1)
y_true = test_gen.classes
class_names = ['Normal', 'Osteopenia', 'Osteoporosis']

print("\n--- Classification Report ---")
print(classification_report(y_true, y_pred, target_names=class_names))

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d',
            xticklabels=class_names,
            yticklabels=class_names,
            cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix — Test Set')
plt.show()

print(f"\nFinal Test Accuracy: {np.sum(y_pred == y_true) / len(y_true) * 100:.2f}%")
# Out:
# Loading best model...
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#       Normal       0.90      0.89      0.89        98
#   Osteopenia       0.94      0.68      0.79        98
# Osteoporosis       0.75      0.96      0.84       101
#
#     accuracy                           0.85       297
#    macro avg       0.86      0.84      0.84       297
# weighted avg       0.86      0.85      0.84       297
# Final Test Accuracy: 84.51%

# %%
print("\nApplying TTA (20 rounds)...")

tta_datagen = ImageDataGenerator(
    rotation_range=8,
    horizontal_flip=True,
    zoom_range=0.08,
    preprocessing_function=tf.keras.applications.vgg19.preprocess_input
)

tta_rounds = 20
tta_preds  = np.zeros((test_gen.samples, 3))

for i in range(tta_rounds):
    tta_gen = tta_datagen.flow_from_directory(
        test_dir,
        target_size=(224, 224),
        batch_size=1,
        classes=['Normal', 'Osteopenia', 'Osteoporosis'],
        class_mode='categorical',
        shuffle=False
    )
    tta_gen.reset()
    tta_preds += eval_model.predict(tta_gen, steps=len(tta_gen), verbose=0)
    print(f"TTA round {i+1}/{tta_rounds} done")

tta_preds /= tta_rounds
y_pred_tta = np.argmax(tta_preds, axis=1)

print("\n--- TTA Classification Report ---")
print(classification_report(y_true, y_pred_tta, target_names=class_names))

cm_tta = confusion_matrix(y_true, y_pred_tta)
plt.figure(figsize=(8, 6))
sns.heatmap(cm_tta, annot=True, fmt='d',
            xticklabels=class_names,
            yticklabels=class_names,
            cmap='Greens')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix — With TTA (20 rounds)')
plt.show()

print(f"\nFinal TTA Accuracy: {np.sum(y_pred_tta == y_true) / len(y_true) * 100:.2f}%")
# Out:
# Applying TTA...
# Found 297 images belonging to 3 classes.
# TTA round 1/10 done
# Found 297 images belonging to 3 classes.
# TTA round 2/10 done
# Found 297 images belonging to 3 classes.
# TTA round 3/10 done
# Found 297 images belonging to 3 classes.
# TTA round 4/10 done
# Found 297 images belonging to 3 classes.
# TTA round 5/10 done
# Found 297 images belonging to 3 classes.
# TTA round 6/10 done
# Found 297 images belonging to 3 classes.
# TTA round 7/10 done
# Found 297 images belonging to 3 classes.
# TTA round 8/10 done
# Found 297 images belonging to 3 classes.
# TTA round 9/10 done
# Found 297 images belonging to 3 classes.
# TTA round 10/10 done
#
# --- TTA Classification Report ---
#               precision    recall  f1-score   support
#
#       Normal       0.92      0.87      0.89        98
#   Osteopenia       0.90      0.87      0.89        98
# Osteoporosis       0.83      0.91      0.87       101
#
#     accuracy                           0.88       297
#    macro avg       0.89      0.88      0.88       297
# weighted avg       0.89      0.88      0.88       297
# Final TTA Accuracy: 88.22%
